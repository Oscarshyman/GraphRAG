# %%
import networkx as nx
import matplotlib.pyplot as plt

graphml_file="/Users/chenruidong/Documents/Graph Rag/ragtest/output/20240929-155654/artifacts/summarized_graph.graphml"
G=nx.read_graphml(graphml_file)
nodes=G.nodes(data=True)
edges=G.edges(data=True)
print(len(nodes))
print(len(edges))
# Out:
# 686
# 1049

# %%
list(nodes)[1]
# Out:
# ('CHARLES DICKENS',
#  {'type': 'PERSON',
#   'description': 'Charles Dickens is a renowned author best known for his classic novella, "A Christmas Carol," which was published in 1843. This work explores profound themes of redemption and the spirit of Christmas, making it a timeless piece of literature that continues to resonate with readers today.',
#   'source_id': '680dd6d2a970a49082fa4f34bf63a34e,7e0f328a83e4cab1025bc5e27fb32cc6,95f1f8f5bdbf0bee3a2c6f2f4a4907f6'})

# %%
list(edges)[1]
# Out:
# ('PROJECT GUTENBERG',
#  'FULL LICENSE',
#  {'weight': 1.0,
#   'description': 'The Full Project Gutenberg License outlines the terms of use and redistribution for works associated with Project Gutenberg',
#   'source_id': '50160bdfa976f5b946c699722c81b412'})

# %%
# Visualize the graph
plt.figure(figsize=(15, 15))
pos = nx.circular_layout(G)  # positions for all nodes

# Draw nodes and edges
nx.draw_networkx_nodes(G, pos, node_size=1000, node_color='red',alpha=0.5)
nx.draw_networkx_edges(G, pos, width=1, alpha=0.3, edge_color='lightblue')
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')

plt.title("Graph Visualization")
plt.axis('off')  # Turn off the axis
plt.show()

# %%
import numpy as np
np.random.seed(2024)

# Visualize the graph
plt.figure(figsize=(15, 15))
pos = nx.spring_layout(G,k=2.5, iterations=400,threshold=1e-4)

nx.draw_networkx_nodes(G, pos, node_size=1000, node_color='red',alpha=0.5)
nx.draw_networkx_edges(G, pos, width=1, alpha=0.8, edge_color='black')
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')

plt.title("Graph Visualization")
plt.axis('off')  # Turn off the axis
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import leidenalg
import igraph as ig
# Convert NetworkX graph to igraph
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
# Perform community detection using the Leiden algorithm
partition = leidenalg.find_partition(igraph, leidenalg.ModularityVertexPartition)

# %%
community_assignments = {}
for community_id, community in enumerate(partition):
    for node_index in community:
        node_name = list(G.nodes)[node_index]  # Map node index to node name
        community_assignments[node_name] = community_id
community_assignments
# Out:
# {'CHRISTMAS EVE': 0,
#  'HEART': 0,
#  'CAINS': 0,
#  'THE QUARTER': 0,
#  'THE CLOCK': 0,
#  'HOUR BELL': 0,
#  'CURTAINS': 0,
#  'BED': 0,
#  'UNEARTHLY VISITOR': 0,
#  'TUNIC': 0,
#  'BAND': 0,
#  'FIGURE': 0,
#  'LIGHT': 0,
#  'WINTER DAY': 0,
#  'FIELDS': 0,
#  'BRIDGE': 0,
#  'RIVER': 0,
#  'FARMERS': 0,
#  'MERRY CHRISTMAS': 0,
#  'MANSION': 0,
#  'CHILD': 0,
#  'HIGH-ROAD': 0,
#  'LANE': 0,
#  'MANSION OF DULL RED BRICK': 0,
#  'BOY': 0,
#  'POPPLAR': 0,
#  'HOUSE': 0,
#  'DAMASCUS': 0,
#  "SULTAN'S GROOM": 0,
#  'PRINCESS': 0,
#  'ORSON': 0,
#  'GENII': 0,
#  'VALENTINE': 0,
#  'ROBIN CRUSOE': 0,
#  'FRIDAY': 0,
#  'PARROT': 0,
#  'CHRISTMAS CAROL': 0,
#  'LITTLE FAN': 0,
#  'COACH': 0,
#  'FATHER': 0,
#  'SCHOOLMASTER': 0,
#  'GARDEN SWEEP': 0,
#  'CHAIS': 0,
#  'MEAGRE SERVANT': 0,
#  'POSTBOY': 0,
#  'DECANTER': 0,
#  'BLOCK OF CAKE': 0,
#  'YOUNG PEOPLE': 0,
#  'SCHOOL': 0,
#  'HIGH DESK': 0,
#  'WELSH WIG': 0,
#  'DICK': 0,
#  'EBENEZER': 0,
#  'MISS FEZZIWIG': 0,
#  'YOUNG FOLLOWERS': 0,
#  'MILKMAN': 0,
#  'WINTER BALL': 0,
#  'DANCE EVENT': 0,
#  'GIRL': 0,
#  'DANCE': 0,
#  'COLD ROAST': 0,
#  'COLD BOILED': 0,
#  'BEER': 0,
#  'PORTER': 0,
#  'CHRISTMAS BALL': 0,
#  'MOURNING DRESS': 0,
#  'FAIR YOUNG GIRL': 0,
#  'YOUNG GIRL': 0,
#  'IDOL': 0,
#  'WEALTH': 0,
#  'POVERTY': 0,
#  'CONTRACT': 0,
#  'INDUSTRY': 0,
#  'ASPIRATIONS': 0,
#  'UNKNOWN': 0,
#  'TRUTH': 0,
#  'DOWERLESS GIRL': 0,
#  'HEAVEN': 0,
#  'COMELY MATRON': 0,
#  'CHILDREN': 0,
#  'MOTHER': 0,
#  'DAUGHTER': 0,
#  'BROWN-PAPER PARCELS': 0,
#  "DOLL'S FRYING PAN": 0,
#  'WOODEN PLATTER': 0,
#  'BABY': 0,
#  'MASTER OF THE HOUSE': 0,
#  'MR. SCROOGE': 0,
#  'EXTINGUISHER-CAP': 0,
#  'ONE': 0,
#  'ADVENTURE': 0,
#  'MISTLETOE': 0,
#  'IVY': 0,
#  'THRONE': 0,
#  'GHOSTLY LIGHT': 0,
#  'POULTRY': 0,
#  'PLUM-PUDDINGS': 0,
#  'TWELFTH-CAKES': 0,
#  'CHESTNUTS': 0,
#  'PLENTY': 0,
#  'ICICLES': 0,
#  'FAMILY': 0,
#  'CITY STREETS': 0,
#  'RED BERRIES': 0,
#  'GAME': 0,
#  'SAUSAGES': 0,
#  'SNOW': 0,
#  'HOUSE-FRONTS': 0,
#  'STREETS': 0,
#  'CLIMATE': 0,
#  "POULTERERS' SHOPS": 0,
#  'FRUITERERS': 0,
#  'SNOWBALL FIGHT': 0,
#  'SPANISH ONIONS': 0,
#  'SHOPKEEPERS': 0,
#  'PEARS': 0,
#  'GRAPES': 0,
#  'ORANGES': 0,
#  'FRUITS': 0,
#  'VEGETABLES': 0,
#  'BASKETS': 0,
#  'RAISINS': 0,
#  'MARRIED SISTERS': 0,
#  'BROTHERS': 0,
#  'HARP': 0,
#  'CORPSE': 0,
#  "FEZZIWIG'S BALL": 1,
#  'HAMLET': 1,
#  'PEOPLE': 1,
#  'FOG': 1,
#  'POOR LAW': 1,
#  'CREDENTIALS': 1,
#  'TREADMILL': 1,
#  'FESTIVE SEASON': 1,
#  'FUND': 1,
#  'POPULATION': 1,
#  'DARKNESS': 1,
#  'FLOGGING LINKS': 1,
#  'ANCIENT TOWER': 1,
#  'MAIN STREET': 1,
#  'GAS-PIPES': 1,
#  'HOLLY SPRIGS': 1,
#  'BRAZIER': 1,
#  'FIRE': 1,
#  'RAGGED MEN AND BOYS': 1,
#  'LORD MAYOR': 1,
#  'MANSION HOUSE': 1,
#  'GROCERS': 1,
#  'TAILOR': 1,
#  'BELSHAZZARS': 1,
#  'APOSTLES': 1,
#  'BUTTER-BOATS': 1,
#  'BELL': 1,
#  'FIRST OF EXCHANGE': 1,
#  'FISH': 1,
#  'SAGE AND ONION': 1,
#  'COPPER': 1,
#  'ALMSHOUSE': 1,
#  'HOSPITAL': 1,
#  'BUSINESS MEN': 1,
#  'FUTURE': 1,
#  'PAST': 1,
#  'PORCH': 1,
#  'MULTITUDES': 1,
#  'SELF': 1,
#  'LOW-BROWED SHOP': 1,
#  'INFAMOUS RESORT': 1,
#  'BOTTLES': 1,
#  'BONES': 1,
#  'GREASY OFFAL': 1,
#  'KEYS': 1,
#  'NARROW ALLEYS': 1,
#  'ARCHWAYS': 1,
#  'RAGS': 1,
#  'GREY-HAIRED RASCAL': 1,
#  'WOMAN WITH HEAVY BUNDLE': 1,
#  'SECOND WOMAN': 1,
#  'MAN IN FADED BLACK': 1,
#  'CHARCOAL STOVE': 1,
#  'PENTHOUSE ROOF': 1,
#  'SHOP': 1,
#  'OLD JOE': 1,
#  'CHARWOMAN': 1,
#  'CHARLES DICKENS': 2,
#  'DICK WILKINS': 2,
#  'BELLE': 2,
#  'CAROLINE': 2,
#  'MRS. CRATCHIT': 2,
#  'BELINDA CRATCHIT': 2,
#  'MARTHA CRATCHIT': 2,
#  'MRS. DILBER': 2,
#  'FAN': 2,
#  'MRS. FEZZIWIG': 2,
#  "MARLEY'S GHOST": 2,
#  'JACOB MARLEY': 2,
#  'OLD SCRATCH': 2,
#  'BED-CURTAINS': 2,
#  'CLERK': 2,
#  'UNDERTAKER': 2,
#  'CHIEF MOURNER': 2,
#  'CLERGYMAN': 2,
#  'STAVE FOUR': 2,
#  'STAVE FIVE': 2,
#  'DOOR-NAIL': 2,
#  'COFFIN-NAIL': 2,
#  "ST. PAUL'S CHURCHYARD": 2,
#  'DEATH': 2,
#  'FUNERAL': 2,
#  'HEAVIEST RAIN': 2,
#  'HAIL': 2,
#  'SLEET': 2,
#  'CROWDED PATHS': 2,
#  'HUMAN SYMPATHY': 2,
#  'CITY': 2,
#  'COUNTING-HOUSE': 2,
#  'CANDLES': 2,
#  "SCROOGE'S NEPHEW": 2,
#  'CANDLE': 2,
#  'MASTER': 2,
#  'WORLD OF FOOLS': 2,
#  'UNCLE': 2,
#  'GENTLEMEN': 2,
#  'THE VISITATION': 2,
#  'MAN': 2,
#  'MEAT': 2,
#  'LEMONS': 2,
#  'SPICES': 2,
#  'ROLLER': 2,
#  'CANISTERS': 2,
#  'CANDIED FRUITS': 2,
#  'FRENCH PLUMS': 2,
#  "BAKERS' SHOPS": 2,
#  'CHURCH AND CHAPEL': 2,
#  'COUSINS': 2,
#  'BLAZE': 2,
#  'SEA': 2,
#  'SHIP': 2,
#  "SCROOGE'S NIECE": 2,
#  'LAUGHTER': 2,
#  'GOOD-HUMOUR': 2,
#  'WOMAN': 3,
#  'BURIAL REGISTER': 3,
#  'DOOR': 3,
#  'WAISTCOAT': 3,
#  'CHAIR': 3,
#  'WORLD': 3,
#  'SPIRIT': 3,
#  'HAPPINESS': 3,
#  'PHANTOM': 3,
#  'MONEY-CHANGING HOLE': 3,
#  'WARD': 3,
#  'MANKIND': 3,
#  'BENEVOLENCE': 3,
#  'WISE MEN': 3,
#  'POOR ABODE': 3,
#  'CROWD': 3,
#  'SPECTRE': 3,
#  'THREE SPIRITS': 3,
#  'TWELVE': 3,
#  'BLEAK, DARK NIGHT': 3,
#  'PHANTOMS': 3,
#  'GUILTY GOVERNMENTS': 3,
#  'WOMAN WITH INFANT': 3,
#  'GHOSTS': 3,
#  'INVISIBLE WORLD': 3,
#  'STAVE TWO': 3,
#  'WINDOW': 3,
#  'MIST': 3,
#  'CHAMBER': 3,
#  'CLOCK': 3,
#  'TIME': 3,
#  'APPRENTICES': 3,
#  'WINTER FIRE': 3,
#  'APPLES': 3,
#  'CLOTH': 3,
#  'CHIMNEY CORNER': 3,
#  "POOR MAN'S CHILD": 3,
#  'CHRISTMAS PARTY': 3,
#  'HOLIDAY': 3,
#  'LORD': 3,
#  'MILLINER': 3,
#  'COUNTESS': 3,
#  'MOLDY OLD OFFICE': 3,
#  'DUSKY SHROUD': 3,
#  'CHANGE': 3,
#  'MERCHANTS': 3,
#  'GOLD SEALS': 3,
#  'MONEY': 3,
#  'PROJECT GUTENBERG': 4,
#  'ARTHUR RACKHAM': 4,
#  'A CHRISTMAS CAROL': 4,
#  'PHILADELPHIA': 4,
#  'NEW YORK': 4,
#  'JANET BLENKINSHIP': 4,
#  'ONLINE DISTRIBUTED PROOFREADING TEAM': 4,
#  'SUZANNE SHELL': 4,
#  'J. B. LIPPINCOTT COMPANY': 4,
#  'EBENEZER SCROOGE': 4,
#  'GREAT BRITAIN': 4,
#  'ISBN 0-397-00033-2': 4,
#  'GHOST': 4,
#  'BOB CRATCHIT': 4,
#  'PETER CRATCHIT': 4,
#  'TIM CRATCHIT': 4,
#  'MR. FEZZIWIG': 4,
#  'FRED': 4,
#  'GHOST OF CHRISTMAS PAST': 4,
#  'GHOST OF CHRISTMAS PRESENT': 4,
#  'GHOST OF CHRISTMAS YET TO COME': 4,
#  'GHOST OF JACOB MARLEY': 4,
#  'FEZZIWIG': 4,
#  'JOE': 4,
#  'MR. TOPPER': 4,
#  'FILBERTS': 4,
#  'SPIRIT OF TINY TIM': 4,
#  'CHURCHYARD': 4,
#  'GRAVES': 4,
#  'HOUSES': 4,
#  'FURNITURE': 4,
#  'PRESENT': 4,
#  'CHRISTMAS TIME': 4,
#  'BEDPOST': 4,
#  'WANDERING SPIRITS': 4,
#  'LAOCOON': 4,
#  'CHURCHES': 4,
#  'CORNER': 4,
#  "POULTERER'S": 4,
#  'PRIZE TURKEY': 4,
#  'POULTERER': 4,
#  'ADDRESS': 4,
#  'TURKEY': 4,
#  'CAB': 4,
#  "SCROOGE AND MARLEY'S": 4,
#  'PORTLY GENTLEMAN': 4,
#  'CHRISTMAS': 5,
#  'SCROOGE': 5,
#  'WAREHOUSE': 5,
#  'NIGHT': 5,
#  'OFFICE': 5,
#  'FIFTEEN SHILLINGS': 5,
#  'BEDLAM': 5,
#  'POULTERERS': 5,
#  'CAMDEN TOWN': 5,
#  'TAVERN': 5,
#  'ABELS': 5,
#  'GREEN HOLLY': 5,
#  'SIR ROGER DE COVERLEY': 5,
#  'DOMESTIC BALL': 5,
#  'BRAIDED HAIR': 5,
#  'CHAOS': 5,
#  'GROUP': 5,
#  'PUNCH': 5,
#  'BRAWN': 5,
#  'CARTS AND WAGONS': 5,
#  'SNOWSTORMS': 5,
#  'MOOR': 5,
#  'SETTING SUN': 5,
#  'MINERS': 5,
#  'HUT': 5,
#  'CHRISTMAS SONG': 5,
#  'OLD MAN': 5,
#  'CHEERFUL COMPANY': 5,
#  'LIGHTHOUSE': 5,
#  'WATER': 5,
#  'CAVERN': 5,
#  'STORM-BIRDS': 5,
#  'HELMSMAN': 5,
#  'PARTY': 5,
#  'GAMES': 5,
#  'GUESTS': 5,
#  'SISTERS': 5,
#  'LONDON': 5,
#  'YES AND NO': 5,
#  'ANIMAL': 5,
#  'HAPPY END': 5,
#  'LAUNDRESS': 5,
#  "UNDERTAKER'S MAN": 5,
#  'COLD': 6,
#  'BERRIES': 6,
#  'LUMBER-ROOM': 6,
#  'DRESSING-GOWN': 6,
#  'SLIPPERS': 6,
#  'DUTCH MERCHANT': 6,
#  'FIREPLACE': 6,
#  "PHARAOH'S DAUGHTERS": 6,
#  'QUEENS OF SHEBA': 6,
#  'ANGELIC MESSENGERS': 6,
#  'ABRAHAMS': 6,
#  "WINE-MERCHANT'S CELLAR": 6,
#  'ROOM': 6,
#  'CHAINS': 6,
#  'HAUNTED HOUSE': 6,
#  'CHAIN': 6,
#  'THE CHIME': 6,
#  'GESE': 6,
#  'OYSTERS': 6,
#  'PIES': 6,
#  'TEA': 6,
#  'COFFEE': 6,
#  'ALMONDS': 6,
#  'CUSTOMERS': 6,
#  'GROCER': 6,
#  'RED-FACED GENTLEMAN': 6,
#  'SUGAR-TONGS': 6,
#  'BOOTS': 6,
#  'SHIRT': 6,
#  'DEBT': 6,
#  "CRATCHIT'S HOUSE": 6,
#  "CRATCHIT'S WIFE": 6,
#  'CANDLE-LIGHT': 6,
#  'SUNDAY': 6,
#  'GREEN PLACE': 6,
#  'GIRLS': 6,
#  "MR. SCROOGE'S NEPHEW": 6,
#  'GOOD WIFE': 6,
#  'CARD': 6,
#  'THE FIRST OF THE THREE SPIRITS': 7,
#  "HAMLET'S FATHER": 7,
#  'PELTING RAIN': 7,
#  'COURT': 7,
#  'CHARITY': 7,
#  'FORBEARANCE': 7,
#  'FROST': 7,
#  'ALI BABA': 7,
#  'FESTIVITIES': 7,
#  'RANGE': 7,
#  'DINNER': 7,
#  'INCENSE': 7,
#  'EARTH': 7,
#  'KITH': 7,
#  'TOWN': 7,
#  "BAKER'S": 7,
#  'CRATCHIT HOUSE': 7,
#  'FOUR-ROOMED HOUSE': 7,
#  'TINY TIM': 7,
#  'CRATCHIT FAMILY': 7,
#  'GOOSE': 7,
#  'MARTHA': 7,
#  'WASH-HOUSE': 7,
#  'PUDDING': 7,
#  'SURPLUS POPULATION': 7,
#  'GAOL': 7,
#  'TWELFTH-NIGHT PARTY': 7,
#  "SPIRIT'S ROBE": 7,
#  'AGE': 7,
#  'IGNORANCE': 7,
#  'WANT': 7,
#  'ANGELS': 7,
#  'DEVILS': 7,
#  'GLOOM': 7,
#  'WORKHOUSES': 7,
#  'MYSTERY': 7,
#  'SPIRIT OF CHRISTMAS YET TO COME': 7,
#  'SPECTRAL HAND': 7,
#  'SPOIL': 7,
#  'CORNHILL': 8,
#  'STAVE ONE': 8,
#  'SCROOGE AND MARLEY': 8,
#  'WINDOWS': 8,
#  'CHURCH': 8,
#  'BOYS': 8,
#  'GATEWAY': 8,
#  'CHAMBERS': 8,
#  'OFFICES': 8,
#  'FOG AND FROST': 8,
#  'GHOSTLY SPECTACLES': 8,
#  'DARK CELLAR': 8,
#  'KNOCKER': 8,
#  'KEY': 8,
#  'HALL': 8,
#  'STAIRS': 8,
#  'ECHOES': 8,
#  'WINE-MERCHANT': 8,
#  'GAS-LAMPS': 8,
#  'GRUEL': 8,
#  'SITTING-ROOM': 8,
#  'BEDROOM': 8,
#  'GRAVE': 8,
#  'MERCY': 8,
#  'MARKET-TOWN': 8,
#  'TRANSFORMATION': 8,
#  'NORFOLK BIFFINS': 8,
#  'WICKER BASKETS': 8,
#  'DINNERS': 8,
#  'LOOK-OUT': 8,
#  'SISTER': 8,
#  'LARGE CHAIR': 8,
#  'FOOTSTOOL': 8,
#  'GAME OF HOW, WHEN, AND WHERE': 8,
#  'BLIND MAN': 8,
#  'WHITECHAPEL': 8,
#  'WINTER WEATHER': 9,
#  'GENTLEMAN': 9,
#  'PRISONS': 9,
#  'UNION WORKHOUSES': 9,
#  'JACOB': 9,
#  'COUNTRY ROAD': 9,
#  'MASTER SCROOGE': 9,
#  'HOUSEMAID': 9,
#  'COOK': 9,
#  'MINCE-PIES': 9,
#  'FIDDLER': 9,
#  'LITTLE SHOE': 9,
#  'PUDDINGS': 9,
#  'FRUIT': 9,
#  'CHRISTMAS DAY': 9,
#  'CARVING-KNIFE': 9,
#  'CHRISTMAS PUDDING': 9,
#  'LAMPLIGHTER': 9,
#  'SCOURGE': 9,
#  'OFFICERS': 9,
#  'TWO MEN': 9,
#  'TOPPER': 9,
#  'DESSERT': 9,
#  'AROMATIC VINEGAR': 9,
#  "SCROOGE'S NIECE'S SISTER": 9,
#  'MAN WITH LARGE CHIN': 9,
#  'GREAT FAT MAN': 9,
#  'COMPANY': 9,
#  'BUSINESSMEN': 9,
#  'PANE LIGHT': 9,
#  'AWFUL LANGUAGE': 9,
#  'TERRORS': 9,
#  'BODY': 9,
#  'SHADOW': 9,
#  'THE THREE SPIRITS': 10,
#  'THE CRATCHIT FAMILY': 10,
#  'HOLLY': 10,
#  'PARLIAMENT': 10,
#  'FIFTY COOKS AND BUTLERS': 10,
#  'RAGGED MEN': 10,
#  'ST. DUNSTAN': 10,
#  "BANKER'S BOOK": 10,
#  'DECEASED PARTNER': 10,
#  'CITY OF LONDON': 10,
#  'APPEARANCE': 10,
#  'SUMMER FLOWERS': 10,
#  'BELT': 10,
#  'TURKEYS': 10,
#  'PIGS': 10,
#  'FIGS': 10,
#  'TORCH': 10,
#  'PETER': 10,
#  'BELINDA': 10,
#  'CHRISTMAS DINNER': 10,
#  'SLEEVE-BUTTONS': 10,
#  'BROOCH': 10,
#  'SHEETS': 10,
#  'TOWELS': 10,
#  'SILVER TEASPOONS': 10,
#  'SEAL': 10,
#  'FIRST WOMAN': 10,
#  'BLANKETS': 10,
#  'FLANNEL BAG': 10,
#  'DEMONS': 10,
#  'RAGGED SHEET': 10,
#  'NEPHEW': 11,
#  'HAT': 11,
#  'BEEF': 11,
#  'TRAVELLERS': 11,
#  'GEESE': 11,
#  'CINNAMON': 11,
#  'YOUNG CRATCHITS': 11,
#  'CLOSET DOOR': 11,
#  'UNCLES': 11,
#  'AUNTS': 11,
#  'GLEE': 11,
#  'CATCH': 11,
#  'MUSIC': 11,
#  'PLUMP SISTER': 11,
#  "BLIND MAN'S-BUFF": 11,
#  'FIRE-IRONS': 11,
#  'FIRST PARTING': 11,
#  'MARLEY': 12,
#  'PARTNERSHIP': 12,
#  'PIGTAIL': 12,
#  "SCROOGE'S HOUSE": 12,
#  'SENSES': 12,
#  'MUSTARD': 12,
#  'CHEESE': 12,
#  'POTATO': 12,
#  'GRAVY': 12,
#  'WELFARE': 12,
#  'STREET': 12,
#  "SCROOGE'S NIECE'S SISTERS": 12,
#  'UNITED STATES': 13,
#  'BAKER': 13,
#  'YOUNGEST CRATCHITS': 13,
#  'HEARTH': 13,
#  'LAMPLIGHT': 13,
#  'PARLOUR': 13,
#  'DECEASED MAN': 13,
#  'BUNDLE': 13,
#  'PENCIL-CASE': 13,
#  'CATS': 14,
#  'RATS': 14,
#  'GOOD DEEDS': 14,
#  'MEMORY': 14,
#  'WOUND': 14,
#  'HUSBAND': 14,
#  'DUSTY CHAMBERS': 15,
#  'POOR CLERK': 15,
#  'UNCLE SCROOGE': 15,
#  'MULLED WINE': 16,
#  'GHOST OF CHRISTMAS': 16,
#  'CHRISTMAS HOLIDAYS': 16,
#  'BOB': 17,
#  'CRATCHITS': 17,
#  'CHAIRS': 18,
#  'PIANO': 18}

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
np.random.seed(2024)

# Convert partition into a dictionary where keys are node names, not indices
community_assignments = {}
for community_id, community in enumerate(partition):
    for node_index in community:
        node_name = list(G.nodes)[node_index]  # Map node index to node name
        community_assignments[node_name] = community_id

num_communities = len(set(community_assignments.values()))

# Assign colors to each community
colors = plt.cm.rainbow(np.linspace(0, 1, num_communities))
plt.figure(figsize=(15, 15))
pos = nx.spring_layout(G, k=2.5, iterations=400, threshold=1e-4)

for node, community_id in community_assignments.items():
    if node in pos:  
        nx.draw_networkx_nodes(G, pos,
                               nodelist=[node],
                               node_size=1000,
                               node_color=[colors[community_id]],
                               alpha=0.8)

nx.draw_networkx_edges(G, pos, width=1, alpha=0.5, edge_color='black')
nx.draw_networkx_labels(G, pos, font_size=8, font_family='sans-serif')

plt.title("Graph Visualization with Communities")
plt.axis('off') 
plt.show()

# %%
community_0_nodes = [node for node, community_id in community_assignments.items() if community_id == 0]
G_community_0 = G.subgraph(community_0_nodes)
plt.figure(figsize=(15, 15))
pos_community_0 = nx.spring_layout(G_community_0, k=2.5, iterations=400, threshold=1e-4)

nx.draw_networkx_nodes(G_community_0, pos_community_0, node_size=1000, node_color='orange', alpha=0.8)
nx.draw_networkx_edges(G_community_0, pos_community_0, width=1, alpha=0.5, edge_color='black')
nx.draw_networkx_labels(G_community_0, pos_community_0, font_size=8, font_family='sans-serif')

plt.title("Graph Visualization of Community 0")
plt.axis('off') 
plt.show()

print(G_community_0)
# Out:
# Graph with 126 nodes and 60 edges

# %%
community_0_nodes = [node for node, community_id in community_assignments.items() if community_id == 0]
community_1_nodes = [node for node, community_id in community_assignments.items() if community_id == 1]

combined_community_nodes = community_0_nodes + community_1_nodes
G_combined_communities = G.subgraph(combined_community_nodes)

plt.figure(figsize=(15, 15))
pos_combined = nx.spring_layout(G_combined_communities, k=2.5, iterations=400, threshold=1e-4)

# Draw nodes for community 0
nx.draw_networkx_nodes(G_combined_communities, pos_combined, nodelist=community_0_nodes, 
                       node_size=1000, node_color='orange', alpha=0.8)
# Draw nodes for community 1
nx.draw_networkx_nodes(G_combined_communities, pos_combined, nodelist=community_1_nodes, 
                       node_size=1000, node_color='blue', alpha=0.8)

# Draw edges
nx.draw_networkx_edges(G_combined_communities, pos_combined, width=1, alpha=0.5, edge_color='black')

# Draw labels
nx.draw_networkx_labels(G_combined_communities, pos_combined, font_size=8, font_family='sans-serif')

plt.title("Graph Visualization of Communities 0 and 1")
plt.axis('off')  # Turn off the axis
plt.show()

# %%
raisin_edges = list(G.edges('RAISINS'))

# Step 2: Count connections to each community
community_0_neighbors = sum(1 for _, target in raisin_edges if community_assignments[target] == 0)
community_1_neighbors = sum(1 for _, target in raisin_edges if community_assignments[target] == 1)

print(f"Connections to Community 0: {community_0_neighbors}")
print(f"Connections to Community 1: {community_1_neighbors}")
modularity_score = (community_0_neighbors - community_1_neighbors) / len(raisin_edges)
print(f"Modularity Score Contribution: {modularity_score}")
# Out:
# Connections to Community 0: 0
# Connections to Community 1: 1
# Modularity Score Contribution: -0.5

# %% [markdown]
# ## A score that is less than 1 indicates that while there is a significant level of connectivity within the communities, there are also some connections to nodes outside of those communities. This can lead to the presence of isolated nodes that are part of a community but have limited or no internal connections.
#
# ## If the modularity score were to reach 1, it would imply a perfect community structure where every node within each community is connected exclusively to other nodes in the same community, with no edges leading to nodes in other communities. In such a case, no isolated nodes would exist within the communities because every node is connected to others within its community.

# %%
raisin_edges
# Out:
# [('RAISINS', 'GROCERS'), ('RAISINS', 'CUSTOMERS')]

# %% [markdown]
# ### When calculating contributions of individual nodes, a negative score (like -0.5) implies that the existing community assignment is not optimal for that node.
#
# ### In other words, the modularity score contribution calculated as -0.5 suggests that placing RAISINS in community 0 would decrease the modularity score. This negative value reflects that the community structure would be less optimal if RAISINS were in community 0 compared to if it were in community 1.
#
# # Characteristics of an Optimal Community Detection Model
#
# ## Dense Internal Connections:
# ### Nodes within the same community should have more edges connecting them than edges connecting to nodes in other communities.
# ## Fewer Isolated Nodes:
# ### Nodes in a community should not be isolated from each other.
# ## Balanced Edge Distribution:
# ### Nodes should not predominantly connect to nodes in other communities if they belong to a particular community.¶

# %%
print(G)
# Out:
# Graph with 686 nodes and 1049 edges

# %% [markdown]
# # Leiden Community
# # (1): ModularityVertexPartition

# %%
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition = leidenalg.find_partition(igraph, leidenalg.ModularityVertexPartition)
modularity_score_igraph = igraph.modularity(partition)  
print(f"Modularity Score from iGraph of Leiden: {modularity_score_igraph}")
# Out:
# Modularity Score from iGraph of Leiden: 0.656364361719046

# %% [markdown]
# ## If the modularity score is high but not perfect like 0.65, it can still accommodate scenarios where some nodes might not connect internally. This indicates that while the community has a strong internal structure, there may be exceptions where certain nodes connect more strongly to external communities.

# %% [markdown]
# # Louvain Community

# %%
import community as community_louvain

louvain_partition = community_louvain.best_partition(G)

louvain_community_list = {}
for node, community_id in louvain_partition.items():
    if community_id not in louvain_community_list:
        louvain_community_list[community_id] = []
    louvain_community_list[community_id].append(node)

louvain_community_list = list(louvain_community_list.values())

modularity_score_louvain = nx.algorithms.community.modularity(G, louvain_community_list)
print(f"Modularity Score from Louvain Communities: {modularity_score_louvain}")
# Out:
# Modularity Score from Louvain Communities: 0.5895086176982199

# %% [markdown]
# # Greedy Modularity Community

# %%
import networkx as nx
greedy_communities = nx.algorithms.community.greedy_modularity_communities(G)
greedy_community_list = [list(community) for community in greedy_communities]
modularity_score = nx.algorithms.community.modularity(G, greedy_community_list)

print(f"Modularity Score of Greedy: {modularity_score}")
# Out:
# Modularity Score of Greedy: 0.5237378759825437

# %%
import networkx as nx
greedy_communities2 = nx.algorithms.community.greedy_modularity_communities(G,resolution=0.5)
greedy_community_list2 = [list(community) for community in greedy_communities2]
modularity_score2 = nx.algorithms.community.modularity(G, greedy_community_list2)

print(f"Modularity Score of Greedy: {modularity_score2}")
# Out:
# Modularity Score of Greedy: 0.40505823638162114

# %%
import networkx as nx
greedy_communities3 = nx.algorithms.community.greedy_modularity_communities(G,resolution=1.5)
greedy_community_list3 = [list(community) for community in greedy_communities3]
modularity_score3 = nx.algorithms.community.modularity(G, greedy_community_list3)

print(f"Modularity Score of Greedy: {modularity_score3}")
# Out:
# Modularity Score of Greedy: 0.5163784375243562

# %%
len(greedy_communities3)
# Out:
# 100

# %% [markdown]
# ## Higher modularity scores suggest that the communities are well-defined, with more intra-community edges and fewer inter-community edges.
#
# ## Modular Score of 1: Indicates a perfect modularity score, meaning all edges are within communities, and no edges connect different communities.
#
# ## A score closer to 1 indicates better-defined communities. A score above 0.3 is generally considered good, while a score below 0.3 may suggest poorly defined communities.
#
# ## A modularity score of 0 indicates that the detected community structure is essentially equivalent to a random model. In other words, there is no significant difference between the actual connections in the communities and the expected connections under random conditions.
#
# ## In summary, a modularity score of 0 suggests that the community structure identified is random and does not provide any useful insight into the underlying relationships in the graph. I

# %%
louvain_partition
# Out:
# {'PROJECT GUTENBERG': 0,
#  'CHARLES DICKENS': 1,
#  'ARTHUR RACKHAM': 1,
#  'A CHRISTMAS CAROL': 1,
#  'PHILADELPHIA': 1,
#  'NEW YORK': 1,
#  'JANET BLENKINSHIP': 1,
#  'ONLINE DISTRIBUTED PROOFREADING TEAM': 1,
#  'SUZANNE SHELL': 1,
#  'J. B. LIPPINCOTT COMPANY': 1,
#  'EBENEZER SCROOGE': 1,
#  'GREAT BRITAIN': 2,
#  'ISBN 0-397-00033-2': 3,
#  'GHOST': 4,
#  'BOB CRATCHIT': 5,
#  'PETER CRATCHIT': 5,
#  'TIM CRATCHIT': 5,
#  'MR. FEZZIWIG': 1,
#  'FRED': 17,
#  'GHOST OF CHRISTMAS PAST': 1,
#  'GHOST OF CHRISTMAS PRESENT': 4,
#  'GHOST OF CHRISTMAS YET TO COME': 1,
#  'GHOST OF JACOB MARLEY': 1,
#  'FEZZIWIG': 7,
#  'JOE': 10,
#  'MR. TOPPER': 9,
#  'DICK WILKINS': 1,
#  'BELLE': 1,
#  'CAROLINE': 10,
#  'MRS. CRATCHIT': 5,
#  'BELINDA CRATCHIT': 5,
#  'MARTHA CRATCHIT': 5,
#  'MRS. DILBER': 10,
#  'FAN': 11,
#  'MRS. FEZZIWIG': 7,
#  "MARLEY'S GHOST": 4,
#  'THE FIRST OF THE THREE SPIRITS': 12,
#  'CHRISTMAS EVE': 7,
#  "FEZZIWIG'S BALL": 1,
#  'CORNHILL': 4,
#  'THE THREE SPIRITS': 1,
#  'CHRISTMAS': 11,
#  'THE CRATCHIT FAMILY': 17,
#  'JACOB MARLEY': 4,
#  'OLD SCRATCH': 10,
#  'BED-CURTAINS': 10,
#  'SCROOGE': 4,
#  'WOMAN': 10,
#  'MARLEY': 4,
#  'STAVE ONE': 4,
#  'CLERK': 4,
#  'UNDERTAKER': 4,
#  'CHIEF MOURNER': 4,
#  'BURIAL REGISTER': 4,
#  'CLERGYMAN': 4,
#  'STAVE FOUR': 4,
#  'STAVE FIVE': 13,
#  'DOOR-NAIL': 14,
#  'COFFIN-NAIL': 15,
#  "HAMLET'S FATHER": 4,
#  "ST. PAUL'S CHURCHYARD": 16,
#  'DEATH': 4,
#  'PARTNERSHIP': 4,
#  'FUNERAL': 17,
#  'SCROOGE AND MARLEY': 1,
#  'HAMLET': 1,
#  'WAREHOUSE': 7,
#  'NIGHT': 4,
#  'WINTER WEATHER': 4,
#  'OFFICE': 4,
#  'PELTING RAIN': 18,
#  'HEAVIEST RAIN': 19,
#  'HAIL': 20,
#  'SLEET': 21,
#  'CROWDED PATHS': 22,
#  'HUMAN SYMPATHY': 23,
#  'CITY': 4,
#  'COUNTING-HOUSE': 4,
#  'COURT': 2,
#  'CANDLES': 4,
#  'PEOPLE': 2,
#  'NEPHEW': 4,
#  'WINDOWS': 24,
#  'FOG': 4,
#  "SCROOGE'S NEPHEW": 17,
#  'CANDLE': 4,
#  'MASTER': 4,
#  'WORLD OF FOOLS': 4,
#  'UNCLE': 4,
#  'HEART': 4,
#  'HOLLY': 11,
#  'PARLIAMENT': 4,
#  'FIFTEEN SHILLINGS': 4,
#  'BEDLAM': 4,
#  'GENTLEMEN': 4,
#  'GENTLEMAN': 17,
#  'PRISONS': 4,
#  'UNION WORKHOUSES': 4,
#  'POOR LAW': 4,
#  'CREDENTIALS': 25,
#  'TREADMILL': 4,
#  'FESTIVE SEASON': 17,
#  'FUND': 17,
#  'CHURCH': 4,
#  'POPULATION': 4,
#  'DARKNESS': 4,
#  'FLOGGING LINKS': 4,
#  'ANCIENT TOWER': 26,
#  'MAIN STREET': 26,
#  'GAS-PIPES': 26,
#  'HOLLY SPRIGS': 11,
#  'BRAZIER': 5,
#  'COLD': 4,
#  'FIRE': 5,
#  'RAGGED MEN AND BOYS': 5,
#  'LORD MAYOR': 11,
#  'MANSION HOUSE': 11,
#  'POULTERERS': 11,
#  'GROCERS': 11,
#  'TAILOR': 11,
#  'BOYS': 11,
#  'BERRIES': 11,
#  'FIFTY COOKS AND BUTLERS': 11,
#  'RAGGED MEN': 11,
#  'ST. DUNSTAN': 4,
#  'HAT': 4,
#  'CAMDEN TOWN': 4,
#  'TAVERN': 4,
#  "BANKER'S BOOK": 4,
#  'DECEASED PARTNER': 4,
#  'CITY OF LONDON': 4,
#  'GATEWAY': 28,
#  'CHAMBERS': 4,
#  'OFFICES': 4,
#  'FOG AND FROST': 28,
#  'GHOSTLY SPECTACLES': 4,
#  'DARK CELLAR': 4,
#  'KNOCKER': 4,
#  'KEY': 4,
#  'HALL': 4,
#  'STAIRS': 4,
#  'ECHOES': 4,
#  'WINE-MERCHANT': 4,
#  'GAS-LAMPS': 29,
#  'GRUEL': 4,
#  'SITTING-ROOM': 4,
#  'BEDROOM': 4,
#  'LUMBER-ROOM': 4,
#  'DRESSING-GOWN': 4,
#  'SLIPPERS': 4,
#  'DUTCH MERCHANT': 4,
#  'FIREPLACE': 4,
#  'ABELS': 4,
#  "PHARAOH'S DAUGHTERS": 4,
#  'QUEENS OF SHEBA': 4,
#  'ANGELIC MESSENGERS': 4,
#  'ABRAHAMS': 4,
#  'BELSHAZZARS': 4,
#  'APOSTLES': 4,
#  'BUTTER-BOATS': 4,
#  'CAINS': 4,
#  'BELL': 4,
#  "WINE-MERCHANT'S CELLAR": 4,
#  'ROOM': 4,
#  'CHAINS': 4,
#  'HAUNTED HOUSE': 4,
#  'CHAIN': 4,
#  'DOOR': 4,
#  'WAISTCOAT': 4,
#  'PIGTAIL': 4,
#  "SCROOGE'S HOUSE": 1,
#  'SENSES': 4,
#  'MUSTARD': 4,
#  'CHEESE': 4,
#  'POTATO': 4,
#  'GRAVY': 4,
#  'GRAVE': 4,
#  'BEEF': 4,
#  'APPEARANCE': 4,
#  'CHAIR': 4,
#  'WORLD': 0,
#  'SPIRIT': 4,
#  'HAPPINESS': 4,
#  'PHANTOM': 4,
#  'MONEY-CHANGING HOLE': 1,
#  'WARD': 4,
#  'JACOB': 4,
#  'MANKIND': 4,
#  'CHARITY': 4,
#  'MERCY': 4,
#  'FORBEARANCE': 4,
#  'BENEVOLENCE': 4,
#  'WISE MEN': 4,
#  'POOR ABODE': 4,
#  'CROWD': 4,
#  'SPECTRE': 4,
#  'THREE SPIRITS': 4,
#  'TWELVE': 4,
#  'BLEAK, DARK NIGHT': 4,
#  'PHANTOMS': 4,
#  'GUILTY GOVERNMENTS': 4,
#  'WOMAN WITH INFANT': 4,
#  'GHOSTS': 4,
#  'INVISIBLE WORLD': 4,
#  'STAVE TWO': 4,
#  'WINDOW': 4,
#  'MIST': 11,
#  'CHAMBER': 4,
#  'CLOCK': 30,
#  'TIME': 4,
#  'FROST': 2,
#  'FIRST OF EXCHANGE': 1,
#  'UNITED STATES': 0,
#  'THE VISITATION': 4,
#  'THE CHIME': 4,
#  'THE QUARTER': 4,
#  'THE CLOCK': 4,
#  'HOUR BELL': 4,
#  'CURTAINS': 4,
#  'BED': 30,
#  'UNEARTHLY VISITOR': 4,
#  'TUNIC': 30,
#  'BAND': 31,
#  'SUMMER FLOWERS': 30,
#  'GREEN HOLLY': 32,
#  'FIGURE': 30,
#  'BELT': 30,
#  'LIGHT': 30,
#  'WELFARE': 4,
#  'WINTER DAY': 4,
#  'COUNTRY ROAD': 4,
#  'FIELDS': 4,
#  'MARKET-TOWN': 11,
#  'BRIDGE': 4,
#  'RIVER': 4,
#  'FARMERS': 11,
#  'MERRY CHRISTMAS': 4,
#  'MANSION': 4,
#  'CHILD': 5,
#  'HIGH-ROAD': 4,
#  'LANE': 4,
#  'MANSION OF DULL RED BRICK': 4,
#  'TRAVELLERS': 4,
#  'BOY': 4,
#  'ALI BABA': 4,
#  'POPPLAR': 4,
#  'HOUSE': 33,
#  'DAMASCUS': 4,
#  "SULTAN'S GROOM": 34,
#  'PRINCESS': 34,
#  'ORSON': 35,
#  'GENII': 34,
#  'VALENTINE': 35,
#  'ROBIN CRUSOE': 4,
#  'FRIDAY': 4,
#  'PARROT': 4,
#  'CHRISTMAS CAROL': 4,
#  'LITTLE FAN': 11,
#  'COACH': 4,
#  'FATHER': 11,
#  'MASTER SCROOGE': 11,
#  'SCHOOLMASTER': 11,
#  'GARDEN SWEEP': 11,
#  'CHAIS': 11,
#  'MEAGRE SERVANT': 36,
#  'POSTBOY': 36,
#  'DECANTER': 11,
#  'BLOCK OF CAKE': 11,
#  'YOUNG PEOPLE': 11,
#  'SCHOOL': 11,
#  'HIGH DESK': 7,
#  'WELSH WIG': 7,
#  'DICK': 7,
#  'STREET': 4,
#  'EBENEZER': 7,
#  'MISS FEZZIWIG': 7,
#  'YOUNG FOLLOWERS': 7,
#  'HOUSEMAID': 7,
#  'BAKER': 7,
#  'COOK': 7,
#  'MILKMAN': 7,
#  'WINTER BALL': 7,
#  'DANCE EVENT': 7,
#  'GIRL': 4,
#  'DANCE': 7,
#  'COLD ROAST': 7,
#  'COLD BOILED': 7,
#  'MINCE-PIES': 7,
#  'BEER': 7,
#  'FIDDLER': 7,
#  'PORTER': 33,
#  'FESTIVITIES': 7,
#  'SIR ROGER DE COVERLEY': 7,
#  'DOMESTIC BALL': 7,
#  'APPRENTICES': 7,
#  'CHRISTMAS BALL': 7,
#  'MOURNING DRESS': 37,
#  'FAIR YOUNG GIRL': 4,
#  'YOUNG GIRL': 1,
#  'IDOL': 1,
#  'WEALTH': 1,
#  'POVERTY': 1,
#  'CONTRACT': 10,
#  'MAN': 10,
#  'INDUSTRY': 10,
#  'ASPIRATIONS': 10,
#  'UNKNOWN': 30,
#  'TRUTH': 38,
#  'DOWERLESS GIRL': 4,
#  'HEAVEN': 4,
#  'COMELY MATRON': 33,
#  'WINTER FIRE': 33,
#  'CHILDREN': 33,
#  'MOTHER': 33,
#  'DAUGHTER': 33,
#  'BRAIDED HAIR': 4,
#  'LITTLE SHOE': 4,
#  'CHAOS': 33,
#  'GROUP': 39,
#  'BROWN-PAPER PARCELS': 33,
#  "DOLL'S FRYING PAN": 40,
#  'WOODEN PLATTER': 40,
#  'BABY': 40,
#  'MASTER OF THE HOUSE': 33,
#  'MR. SCROOGE': 17,
#  'EXTINGUISHER-CAP': 4,
#  'ONE': 4,
#  'ADVENTURE': 41,
#  'RANGE': 42,
#  'MISTLETOE': 11,
#  'IVY': 11,
#  'TRANSFORMATION': 4,
#  'THRONE': 11,
#  'GHOSTLY LIGHT': 4,
#  'GESE': 4,
#  'POULTRY': 11,
#  'PUNCH': 4,
#  'PLUM-PUDDINGS': 4,
#  'TWELFTH-CAKES': 4,
#  'CHESTNUTS': 2,
#  'TURKEYS': 11,
#  'PLENTY': 43,
#  'ICICLES': 44,
#  'FAMILY': 33,
#  'CITY STREETS': 4,
#  'RED BERRIES': 11,
#  'GEESE': 11,
#  'GAME': 11,
#  'BRAWN': 11,
#  'MEAT': 11,
#  'PIGS': 11,
#  'SAUSAGES': 11,
#  'OYSTERS': 11,
#  'PIES': 11,
#  'PUDDINGS': 11,
#  'FRUIT': 11,
#  'SNOW': 2,
#  'HOUSE-FRONTS': 24,
#  'STREETS': 11,
#  'CARTS AND WAGONS': 11,
#  'CLIMATE': 2,
#  'SNOWSTORMS': 2,
#  "POULTERERS' SHOPS": 2,
#  'FRUITERERS': 2,
#  'SNOWBALL FIGHT': 2,
#  'SPANISH ONIONS': 2,
#  'SHOPKEEPERS': 2,
#  'PEARS': 2,
#  'APPLES': 2,
#  'GRAPES': 2,
#  'FILBERTS': 2,
#  'NORFOLK BIFFINS': 11,
#  'ORANGES': 2,
#  'LEMONS': 2,
#  'FRUITS': 2,
#  'VEGETABLES': 2,
#  'BASKETS': 2,
#  'FISH': 11,
#  'CINNAMON': 11,
#  'RAISINS': 11,
#  'TEA': 11,
#  'COFFEE': 11,
#  'ALMONDS': 11,
#  'CUSTOMERS': 11,
#  'GROCER': 11,
#  'SPICES': 11,
#  'ROLLER': 45,
#  'CANISTERS': 11,
#  'CANDIED FRUITS': 11,
#  'FIGS': 11,
#  'FRENCH PLUMS': 11,
#  "BAKERS' SHOPS": 11,
#  'CHURCH AND CHAPEL': 4,
#  'WICKER BASKETS': 2,
#  'DINNERS': 2,
#  'CHRISTMAS DAY': 5,
#  'TORCH': 4,
#  'DINNER': 33,
#  'INCENSE': 4,
#  'EARTH': 46,
#  'KITH': 47,
#  'TOWN': 33,
#  "BAKER'S": 4,
#  'CRATCHIT HOUSE': 5,
#  'FOUR-ROOMED HOUSE': 48,
#  'TINY TIM': 5,
#  'CRATCHIT FAMILY': 5,
#  'GOOSE': 5,
#  'MARTHA': 5,
#  'YOUNG CRATCHITS': 5,
#  'CLOSET DOOR': 5,
#  'BOB': 5,
#  'CRATCHITS': 5,
#  'WASH-HOUSE': 5,
#  'PUDDING': 5,
#  'PETER': 5,
#  'BELINDA': 5,
#  'CHRISTMAS DINNER': 5,
#  'CARVING-KNIFE': 49,
#  'CHRISTMAS PUDDING': 5,
#  'SAGE AND ONION': 5,
#  'COPPER': 5,
#  'YOUNGEST CRATCHITS': 5,
#  'HEARTH': 5,
#  'CLOTH': 5,
#  'SURPLUS POPULATION': 4,
#  'CHIMNEY CORNER': 5,
#  "POOR MAN'S CHILD": 4,
#  'CHRISTMAS PARTY': 5,
#  'HOLIDAY': 5,
#  'LORD': 5,
#  'MILLINER': 5,
#  'COUNTESS': 5,
#  'MARRIED SISTERS': 33,
#  'BROTHERS': 33,
#  'COUSINS': 33,
#  'UNCLES': 33,
#  'AUNTS': 33,
#  'BLAZE': 33,
#  'LAMPLIGHTER': 33,
#  'SCOURGE': 2,
#  'MOOR': 2,
#  'SETTING SUN': 2,
#  'MINERS': 2,
#  'HUT': 2,
#  'CHRISTMAS SONG': 10,
#  'OLD MAN': 10,
#  'CHEERFUL COMPANY': 4,
#  'LIGHTHOUSE': 5,
#  'WATER': 5,
#  'CAVERN': 5,
#  'STORM-BIRDS': 5,
#  'HELMSMAN': 50,
#  'LOOK-OUT': 50,
#  'OFFICERS': 50,
#  'TWO MEN': 5,
#  'SEA': 5,
#  'SHIP': 50,
#  "SCROOGE'S NIECE": 17,
#  'LAUGHTER': 10,
#  'GOOD-HUMOUR': 17,
#  "SCROOGE'S NIECE'S SISTERS": 17,
#  'TOPPER': 17,
#  'LAMPLIGHT': 33,
#  'DESSERT': 33,
#  'AROMATIC VINEGAR': 4,
#  "SCROOGE'S NIECE'S SISTER": 17,
#  'MOLDY OLD OFFICE': 4,
#  'DUSTY CHAMBERS': 4,
#  'POOR CLERK': 4,
#  'UNCLE SCROOGE': 1,
#  'HARP': 17,
#  'GLEE': 51,
#  'CATCH': 52,
#  'MUSIC': 17,
#  'PLUMP SISTER': 17,
#  "BLIND MAN'S-BUFF": 17,
#  'FIRE-IRONS': 53,
#  'CHAIRS': 54,
#  'PIANO': 55,
#  'SISTER': 17,
#  'LARGE CHAIR': 17,
#  'FOOTSTOOL': 17,
#  'GAME OF HOW, WHEN, AND WHERE': 17,
#  'BLIND MAN': 17,
#  'WHITECHAPEL': 56,
#  'PARTY': 17,
#  'GAMES': 17,
#  'GUESTS': 57,
#  'SISTERS': 57,
#  'LONDON': 4,
#  'YES AND NO': 4,
#  'ANIMAL': 4,
#  'HAPPY END': 17,
#  'MULLED WINE': 17,
#  'GHOST OF CHRISTMAS': 17,
#  'CHRISTMAS HOLIDAYS': 4,
#  'ALMSHOUSE': 4,
#  'HOSPITAL': 4,
#  'GAOL': 4,
#  'TWELFTH-NIGHT PARTY': 4,
#  "SPIRIT'S ROBE": 4,
#  'AGE': 58,
#  'IGNORANCE': 4,
#  'WANT': 4,
#  'ANGELS': 4,
#  'DEVILS': 33,
#  'GLOOM': 4,
#  'WORKHOUSES': 4,
#  'MYSTERY': 4,
#  'SPIRIT OF CHRISTMAS YET TO COME': 2,
#  'SPECTRAL HAND': 59,
#  'DUSKY SHROUD': 60,
#  'CHANGE': 4,
#  'MERCHANTS': 4,
#  'GOLD SEALS': 4,
#  'MONEY': 4,
#  'BUSINESS MEN': 17,
#  'RED-FACED GENTLEMAN': 17,
#  'MAN WITH LARGE CHIN': 17,
#  'GREAT FAT MAN': 17,
#  'COMPANY': 17,
#  'BUSINESSMEN': 4,
#  'FUTURE': 4,
#  'PAST': 4,
#  'PORCH': 4,
#  'MULTITUDES': 30,
#  'SELF': 4,
#  'LOW-BROWED SHOP': 33,
#  'INFAMOUS RESORT': 33,
#  'BOTTLES': 33,
#  'BONES': 33,
#  'GREASY OFFAL': 33,
#  'KEYS': 33,
#  'NARROW ALLEYS': 33,
#  'ARCHWAYS': 33,
#  'RAGS': 33,
#  'GREY-HAIRED RASCAL': 10,
#  'WOMAN WITH HEAVY BUNDLE': 10,
#  'SECOND WOMAN': 10,
#  'MAN IN FADED BLACK': 10,
#  'CHARCOAL STOVE': 10,
#  'PENTHOUSE ROOF': 61,
#  'SHOP': 10,
#  'OLD JOE': 10,
#  'CHARWOMAN': 10,
#  'LAUNDRESS': 10,
#  "UNDERTAKER'S MAN": 10,
#  'PARLOUR': 10,
#  'DECEASED MAN': 10,
#  'BUNDLE': 10,
#  'PENCIL-CASE': 10,
#  'SLEEVE-BUTTONS': 10,
#  'BROOCH': 10,
#  'SHEETS': 10,
#  'TOWELS': 10,
#  'SILVER TEASPOONS': 10,
#  'SUGAR-TONGS': 10,
#  'BOOTS': 10,
#  'SEAL': 10,
#  'FIRST WOMAN': 10,
#  'SHIRT': 10,
#  'BLANKETS': 10,
#  'FLANNEL BAG': 62,
#  'CORPSE': 10,
#  'SPOIL': 10,
#  'DEMONS': 63,
#  'RAGGED SHEET': 64,
#  'PANE LIGHT': 65,
#  'AWFUL LANGUAGE': 66,
#  'TERRORS': 4,
#  'BODY': 4,
#  'SHADOW': 4,
#  'CATS': 67,
#  'RATS': 68,
#  'GOOD DEEDS': 69,
#  'MEMORY': 70,
#  'WOUND': 71,
#  'HUSBAND': 33,
#  'DEBT': 10,
#  "CRATCHIT'S HOUSE": 5,
#  "CRATCHIT'S WIFE": 5,
#  'CANDLE-LIGHT': 72,
#  'SUNDAY': 5,
#  'GREEN PLACE': 5,
#  'GIRLS': 5,
#  "MR. SCROOGE'S NEPHEW": 5,
#  'GOOD WIFE': 5,
#  'CARD': 73,
#  'FIRST PARTING': 5,
#  'SPIRIT OF TINY TIM': 5,
#  'CHURCHYARD': 4,
#  'GRAVES': 4,
#  'HOUSES': 4,
#  'FURNITURE': 4,
#  'PRESENT': 4,
#  'CHRISTMAS TIME': 4,
#  'BEDPOST': 4,
#  'WANDERING SPIRITS': 4,
#  'LAOCOON': 4,
#  'CHURCHES': 4,
#  'CORNER': 4,
#  "POULTERER'S": 4,
#  'PRIZE TURKEY': 74,
#  'POULTERER': 4,
#  'ADDRESS': 0,
#  'TURKEY': 4,
#  'CAB': 4,
#  "SCROOGE AND MARLEY'S": 4,
#  'PORTLY GENTLEMAN': 4,
#  'OLD GENTLEMAN': 17,
#  'DINING-ROOM': 17,
#  'MISTRESS': 17,
#  'YOUNG HOUSEKEEPERS': 17,
#  "NINE O'CLOCK": 5,
#  'TANK': 4,
#  'COAL-SCUTTLE': 5,
#  'TOTAL-ABSTINENCE PRINCIPLE': 5,
#  'GLOBE': 5,
#  'SPIRITS': 5,
#  'GENERAL TERMS OF USE': 75,
#  'COPYRIGHT ROYALTIES': 76,
#  'EBOOK': 0,
#  'DISTRIBUTION': 77,
#  'DERIVATIVE WORKS': 0,
#  'COPYING': 78,
#  'TRADMARK LICENSE': 79,
#  'FULL LICENSE': 0,
#  'U.S. COPYRIGHT LAW': 80,
#  'RESEARCH': 81,
#  'TERMS OF USE': 82,
#  'INTELLECTUAL PROPERTY': 83,
#  'COPYRIGHT': 0,
#  'TRADEMARK': 84,
#  'REFUND': 0,
#  'AGREEMENT': 0,
#  'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION': 0,
#  'COPYRIGHT LAW': 0,
#  'PUBLIC DOMAIN': 0,
#  'TERMS OF THIS AGREEMENT': 0,
#  'FREE ACCESS': 0,
#  'ELECTRONIC WORKS': 0,
#  'COPYRIGHT LAWS': 85,
#  'COUNTRY': 86,
#  'PROJECT GUTENBERG LICENSE': 0,
#  'COPYRIGHT HOLDER': 0,
#  'ELECTRONIC WORK': 0,
#  'PLAIN VANILLA ASCII': 0,
#  'USER': 0,
#  'ROYALTY FEE': 0,
#  'GUTENBERG LICENSE': 0,
#  'COPYRIGHT RESEARCH': 87,
#  'DEFECTS': 88,
#  'LIMITED WARRANTY': 89,
#  'LEGAL FEES': 90,
#  'PARAGRAPH 1.F.3': 0,
#  'DEFECT IN ELECTRONIC WORK': 0,
#  'PERSON': 0,
#  'WRITTEN EXPLANATION': 0,
#  'DEFECTIVE WORK': 0,
#  'ENTITY': 0,
#  'REPLACEMENT COPY': 0,
#  'PHYSICAL MEDIUM': 0,
#  'FOUNDATION': 0,
#  'PROJECT GUTENBERG™': 91,
#  'DONATIONS': 0,
#  'GENERATION': 92,
#  'COMPUTERS': 93,
#  'SECTION 2': 94,
#  'SECTION 3': 95,
#  'SECTION 4': 8,
#  'GUTENBERG LITERARY ARCHIVE FOUNDATION': 0,
#  'SALT LAKE CITY': 0,
#  'MISSISSIPPI': 0,
#  'INTERNAL REVENUE SERVICE': 0,
#  'U.S. FEDERAL LAWS': 0,
#  'TAX EXEMPT STATUS': 0,
#  'IRS': 0,
#  'WWW.GUTENBERG.ORG': 0,
#  'CHARITABLE DONATIONS': 0,
#  'COMPLIANCE REQUIREMENTS': 0,
#  'MICHAEL S. HART': 0,
#  'VOLUNTEER SUPPORT': 27,
#  'EBOOKS': 6,
#  'VOLUNTEER': 0,
#  'DONATION': 0}

# %%
len(set(louvain_partition.values()))
# Out:
# 96

# %%
greedy_communities
# Out:
# [frozenset({'ABELS',
#             'ABRAHAMS',
#             'ALI BABA',
#             'ANGELIC MESSENGERS',
#             'ANIMAL',
#             'APOSTLES',
#             'APPEARANCE',
#             'AROMATIC VINEGAR',
#             "BANKER'S BOOK",
#             'BED',
#             'BEDLAM',
#             'BEDPOST',
#             'BEDROOM',
#             'BEEF',
#             'BELSHAZZARS',
#             'BELT',
#             'BODY',
#             'BOY',
#             'BRAIDED HAIR',
#             'BRIDGE',
#             'BUSINESSMEN',
#             'BUTTER-BOATS',
#             'CAB',
#             'CAINS',
#             'CHAIR',
#             'CHAMBER',
#             'CHAMBERS',
#             'CHEESE',
#             'CHRISTMAS CAROL',
#             'CHRISTMAS TIME',
#             'CHURCH',
#             'CHURCH AND CHAPEL',
#             'CHURCHES',
#             'CITY OF LONDON',
#             'CITY STREETS',
#             'CLOCK',
#             'COACH',
#             'COLD',
#             'CORNER',
#             'CROWD',
#             'CURTAINS',
#             'DAMASCUS',
#             'DECEASED PARTNER',
#             'DINING-ROOM',
#             'DOWERLESS GIRL',
#             'DRESSING-GOWN',
#             'DUSTY CHAMBERS',
#             'EXTINGUISHER-CAP',
#             'FAIR YOUNG GIRL',
#             'FAN',
#             'FATHER',
#             'FIGURE',
#             'FOG AND FROST',
#             'FRIDAY',
#             'FURNITURE',
#             'GATEWAY',
#             'GENTLEMEN',
#             'GESE',
#             'GHOSTLY LIGHT',
#             'GIRL',
#             'GLOOM',
#             'GRAVES',
#             'GRAVY',
#             'GRUEL',
#             'GUESTS',
#             'HAT',
#             'HEART',
#             'HEAVEN',
#             'HELMSMAN',
#             'HIGH-ROAD',
#             'HOLLY',
#             'HOUR BELL',
#             'HOUSES',
#             'INCENSE',
#             'INVISIBLE WORLD',
#             'KEY',
#             'LANE',
#             'LAOCOON',
#             'LIGHT',
#             'LITTLE FAN',
#             'LITTLE SHOE',
#             'LONDON',
#             'LOOK-OUT',
#             'LUMBER-ROOM',
#             'MANSION',
#             'MANSION OF DULL RED BRICK',
#             'MISTRESS',
#             'MOLDY OLD OFFICE',
#             'MULTITUDES',
#             'MUSTARD',
#             'NEPHEW',
#             'OFFICERS',
#             'OFFICES',
#             'ONE',
#             'ORSON',
#             'PARLIAMENT',
#             'PARROT',
#             'PARTNERSHIP',
#             'PHANTOM',
#             "PHARAOH'S DAUGHTERS",
#             'PLUM-PUDDINGS',
#             'POOR ABODE',
#             'POOR CLERK',
#             "POOR MAN'S CHILD",
#             'POPPLAR',
#             'POPULATION',
#             'PORTLY GENTLEMAN',
#             'POTATO',
#             'POULTERER',
#             "POULTERER'S",
#             'PRESENT',
#             'QUEENS OF SHEBA',
#             'RIVER',
#             'ROBIN CRUSOE',
#             'ROOM',
#             'SCROOGE',
#             "SCROOGE AND MARLEY'S",
#             'SELF',
#             'SENSES',
#             'SHADOW',
#             'SHIP',
#             'SISTERS',
#             'SITTING-ROOM',
#             'SLIPPERS',
#             'ST. DUNSTAN',
#             'STAIRS',
#             'STAVE FOUR',
#             'SUMMER FLOWERS',
#             'TANK',
#             'TAVERN',
#             'TERRORS',
#             'THE CHIME',
#             'THE CLOCK',
#             'THE QUARTER',
#             'THE VISITATION',
#             'TIME',
#             'TORCH',
#             'TRANSFORMATION',
#             'TRAVELLERS',
#             'TREADMILL',
#             'TUNIC',
#             'TURKEY',
#             'TWELFTH-CAKES',
#             'UNCLE',
#             'UNEARTHLY VISITOR',
#             'UNION WORKHOUSES',
#             'UNKNOWN',
#             'VALENTINE',
#             'WANDERING SPIRITS',
#             'WARD',
#             'WELFARE',
#             'WINDOW',
#             'WINE-MERCHANT',
#             'WINTER FIRE',
#             'WINTER WEATHER',
#             'WISE MEN',
#             'WORLD OF FOOLS',
#             'YES AND NO',
#             'YOUNG HOUSEKEEPERS'}),
#  frozenset({'APPRENTICES',
#             'BAKER',
#             "BAKER'S",
#             'BEER',
#             'BLAZE',
#             'BURIAL REGISTER',
#             'CAMDEN TOWN',
#             'CANDLE',
#             'CHAIN',
#             'CHIEF MOURNER',
#             'CHRISTMAS BALL',
#             'CHRISTMAS EVE',
#             'CLERGYMAN',
#             'CLERK',
#             'COLD BOILED',
#             'COLD ROAST',
#             'COOK',
#             'CORNHILL',
#             'COUNTING-HOUSE',
#             'DANCE',
#             'DANCE EVENT',
#             'DARK CELLAR',
#             'DICK',
#             'DICK WILKINS',
#             'DOMESTIC BALL',
#             'DUTCH MERCHANT',
#             'EBENEZER',
#             'EBENEZER SCROOGE',
#             'FESTIVITIES',
#             'FEZZIWIG',
#             "FEZZIWIG'S BALL",
#             'FIDDLER',
#             'FIFTEEN SHILLINGS',
#             'FIREPLACE',
#             'FIRST OF EXCHANGE',
#             'GHOST',
#             'GHOST OF CHRISTMAS YET TO COME',
#             'GHOST OF JACOB MARLEY',
#             'GHOSTLY SPECTACLES',
#             'HAMLET',
#             'HAPPINESS',
#             'HOUSEMAID',
#             'JACOB MARLEY',
#             'KNOCKER',
#             'LAMPLIGHTER',
#             'MARLEY',
#             'MASTER',
#             'MILKMAN',
#             'MINCE-PIES',
#             'MISS FEZZIWIG',
#             'MONEY-CHANGING HOLE',
#             'MR. FEZZIWIG',
#             'MRS. FEZZIWIG',
#             'NIGHT',
#             'PIGTAIL',
#             'PORCH',
#             'SCROOGE AND MARLEY',
#             "SCROOGE'S HOUSE",
#             'SIR ROGER DE COVERLEY',
#             'SPECTRE',
#             "SPIRIT'S ROBE",
#             'STAVE ONE',
#             'STAVE TWO',
#             'SURPLUS POPULATION',
#             'THE THREE SPIRITS',
#             'THREE SPIRITS',
#             'TWELVE',
#             'UNDERTAKER',
#             'WAISTCOAT',
#             'WAREHOUSE',
#             'WELSH WIG',
#             'WINTER BALL',
#             'YOUNG FOLLOWERS'}),
#  frozenset({'ALMONDS',
#             'ANCIENT TOWER',
#             'BERRIES',
#             'BLIND MAN',
#             "BLIND MAN'S-BUFF",
#             'BOYS',
#             'BRAWN',
#             'CANDIED FRUITS',
#             'CANISTERS',
#             'CHRISTMAS',
#             'CINNAMON',
#             'COFFEE',
#             'CUSTOMERS',
#             'FARMERS',
#             'FIFTY COOKS AND BUTLERS',
#             'FIGS',
#             'FISH',
#             'FOOTSTOOL',
#             'FRED',
#             'FRENCH PLUMS',
#             'FRUIT',
#             'GAME',
#             'GAME OF HOW, WHEN, AND WHERE',
#             'GAMES',
#             'GAS-PIPES',
#             'GEESE',
#             'GHOST OF CHRISTMAS PAST',
#             'GHOST OF CHRISTMAS PRESENT',
#             'GOOD-HUMOUR',
#             'GROCER',
#             'GROCERS',
#             'HARP',
#             'HOLLY SPRIGS',
#             'IVY',
#             'LARGE CHAIR',
#             'LAUGHTER',
#             'LORD MAYOR',
#             'MAIN STREET',
#             'MANSION HOUSE',
#             'MARKET-TOWN',
#             'MEAT',
#             'MULLED WINE',
#             'MUSIC',
#             'OYSTERS',
#             'PARTY',
#             'PIES',
#             'PIGS',
#             'PLUMP SISTER',
#             'POULTERERS',
#             'POULTRY',
#             'PUDDINGS',
#             'PUNCH',
#             'RAGGED MEN',
#             'RAISINS',
#             'RED BERRIES',
#             'SAUSAGES',
#             "SCROOGE'S NEPHEW",
#             "SCROOGE'S NIECE",
#             "SCROOGE'S NIECE'S SISTER",
#             "SCROOGE'S NIECE'S SISTERS",
#             'SISTER',
#             'SPICES',
#             'TAILOR',
#             'TEA',
#             'THRONE',
#             'TOPPER',
#             'TURKEYS',
#             'UNCLE SCROOGE'}),
#  frozenset({'BELINDA',
#             'BELINDA CRATCHIT',
#             'BOB',
#             'BOB CRATCHIT',
#             'BRAZIER',
#             'CHILD',
#             'CHIMNEY CORNER',
#             'CHRISTMAS DAY',
#             'CHRISTMAS DINNER',
#             'CHRISTMAS PARTY',
#             'CHRISTMAS PUDDING',
#             'CLOSET DOOR',
#             'CLOTH',
#             'COAL-SCUTTLE',
#             'COPPER',
#             'COUNTESS',
#             'CRATCHIT FAMILY',
#             'CRATCHIT HOUSE',
#             "CRATCHIT'S HOUSE",
#             "CRATCHIT'S WIFE",
#             'CRATCHITS',
#             'FAMILY',
#             'FIRE',
#             'FIRST PARTING',
#             'GHOST OF CHRISTMAS',
#             'GIRLS',
#             'GLOBE',
#             'GOOD WIFE',
#             'GOOSE',
#             'GREEN PLACE',
#             'HAPPY END',
#             'HEARTH',
#             'HOLIDAY',
#             'LORD',
#             'MARTHA',
#             'MARTHA CRATCHIT',
#             'MERRY CHRISTMAS',
#             'MILLINER',
#             'MR. SCROOGE',
#             "MR. SCROOGE'S NEPHEW",
#             'MRS. CRATCHIT',
#             "NINE O'CLOCK",
#             'OFFICE',
#             'OLD GENTLEMAN',
#             'PETER',
#             'PETER CRATCHIT',
#             'PUDDING',
#             'RAGGED MEN AND BOYS',
#             'SAGE AND ONION',
#             'SPIRIT OF TINY TIM',
#             'SPIRITS',
#             'SUNDAY',
#             'THE CRATCHIT FAMILY',
#             'TIM CRATCHIT',
#             'TINY TIM',
#             'TOTAL-ABSTINENCE PRINCIPLE',
#             'WASH-HOUSE',
#             'YOUNG CRATCHITS',
#             'YOUNGEST CRATCHITS'}),
#  frozenset({'ALMSHOUSE',
#             'ANGELS',
#             "BAKERS' SHOPS",
#             'BELLE',
#             'CANDLES',
#             'CARTS AND WAGONS',
#             'CHANGE',
#             'CHEERFUL COMPANY',
#             'CHRISTMAS HOLIDAYS',
#             'CHRISTMAS SONG',
#             'CHURCHYARD',
#             'CITY',
#             'CLIMATE',
#             'COUNTRY ROAD',
#             'COURT',
#             'DARKNESS',
#             'DEVILS',
#             'DINNERS',
#             'FIELDS',
#             'FLOGGING LINKS',
#             'FOG',
#             'FROST',
#             'FUTURE',
#             'GAOL',
#             'GOLD SEALS',
#             'GRAVE',
#             'HIGH DESK',
#             'HOSPITAL',
#             'HOUSE',
#             'HUT',
#             'IGNORANCE',
#             'MASTER OF THE HOUSE',
#             'MERCHANTS',
#             'MINERS',
#             'MIST',
#             'MONEY',
#             'MOOR',
#             'MYSTERY',
#             'OLD MAN',
#             'PAST',
#             'PEOPLE',
#             'PRISONS',
#             'SCOURGE',
#             'SETTING SUN',
#             'SNOW',
#             'SNOWBALL FIGHT',
#             'SNOWSTORMS',
#             'SPIRIT',
#             'SPIRIT OF CHRISTMAS YET TO COME',
#             'STREET',
#             'STREETS',
#             'TWELFTH-NIGHT PARTY',
#             'WANT',
#             'WICKER BASKETS',
#             'WINTER DAY',
#             'WORKHOUSES'}),
#  frozenset({'ARCHWAYS',
#             'ASPIRATIONS',
#             'AUNTS',
#             'BLANKETS',
#             'BOOTS',
#             'BROOCH',
#             'BROTHERS',
#             'BROWN-PAPER PARCELS',
#             'BUNDLE',
#             'CAROLINE',
#             'CHAOS',
#             'CHARWOMAN',
#             'CHILDREN',
#             'COMELY MATRON',
#             'CONTRACT',
#             'CORPSE',
#             'COUSINS',
#             'DAUGHTER',
#             'DEATH',
#             'DEBT',
#             'DECEASED MAN',
#             'DESSERT',
#             'DINNER',
#             "HAMLET'S FATHER",
#             'HUSBAND',
#             'IDOL',
#             'INDUSTRY',
#             'INFAMOUS RESORT',
#             'LAMPLIGHT',
#             'LAUNDRESS',
#             'MAN',
#             'MARRIED SISTERS',
#             'MOTHER',
#             'MRS. DILBER',
#             'NARROW ALLEYS',
#             'OLD JOE',
#             'PARLOUR',
#             'PENCIL-CASE',
#             'PORTER',
#             'POVERTY',
#             'SEAL',
#             'SHEETS',
#             'SHIRT',
#             'SILVER TEASPOONS',
#             'SLEEVE-BUTTONS',
#             'SPOIL',
#             'SUGAR-TONGS',
#             'TOWELS',
#             'TOWN',
#             'UNCLES',
#             "UNDERTAKER'S MAN",
#             'WEALTH',
#             'WOMAN',
#             'YOUNG GIRL'}),
#  frozenset({'ADDRESS',
#             'AGREEMENT',
#             'CHARITABLE DONATIONS',
#             'COMPLIANCE REQUIREMENTS',
#             'COPYRIGHT',
#             'COPYRIGHT HOLDER',
#             'COPYRIGHT LAW',
#             'DEFECT IN ELECTRONIC WORK',
#             'DEFECTIVE WORK',
#             'DERIVATIVE WORKS',
#             'DONATION',
#             'DONATIONS',
#             'EBOOK',
#             'ELECTRONIC WORK',
#             'ELECTRONIC WORKS',
#             'ENTITY',
#             'FOUNDATION',
#             'FREE ACCESS',
#             'FULL LICENSE',
#             'GUTENBERG LICENSE',
#             'GUTENBERG LITERARY ARCHIVE FOUNDATION',
#             'INTERNAL REVENUE SERVICE',
#             'IRS',
#             'MICHAEL S. HART',
#             'MISSISSIPPI',
#             'PARAGRAPH 1.F.3',
#             'PERSON',
#             'PHYSICAL MEDIUM',
#             'PLAIN VANILLA ASCII',
#             'PROJECT GUTENBERG',
#             'PROJECT GUTENBERG LICENSE',
#             'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#             'PUBLIC DOMAIN',
#             'REFUND',
#             'REPLACEMENT COPY',
#             'ROYALTY FEE',
#             'SALT LAKE CITY',
#             'TAX EXEMPT STATUS',
#             'TERMS OF THIS AGREEMENT',
#             'U.S. FEDERAL LAWS',
#             'UNITED STATES',
#             'USER',
#             'VOLUNTEER',
#             'WORLD',
#             'WRITTEN EXPLANATION',
#             'WWW.GUTENBERG.ORG'}),
#  frozenset({'APPLES',
#             'BASKETS',
#             'CHESTNUTS',
#             'FILBERTS',
#             'FRUITERERS',
#             'FRUITS',
#             'GRAPES',
#             'LEMONS',
#             'MISTLETOE',
#             'NORFOLK BIFFINS',
#             'ORANGES',
#             'PEARS',
#             "POULTERERS' SHOPS",
#             'SHOPKEEPERS',
#             'SPANISH ONIONS',
#             'VEGETABLES'}),
#  frozenset({'BELL',
#             'BLEAK, DARK NIGHT',
#             'CHAINS',
#             'DOOR',
#             'GHOSTS',
#             'GUILTY GOVERNMENTS',
#             'HAUNTED HOUSE',
#             "MARLEY'S GHOST",
#             'PHANTOMS',
#             "WINE-MERCHANT'S CELLAR",
#             'WOMAN WITH INFANT'}),
#  frozenset({'A CHRISTMAS CAROL',
#             'ARTHUR RACKHAM',
#             'CHARLES DICKENS',
#             'GREAT BRITAIN',
#             'J. B. LIPPINCOTT COMPANY',
#             'JANET BLENKINSHIP',
#             'NEW YORK',
#             'ONLINE DISTRIBUTED PROOFREADING TEAM',
#             'PHILADELPHIA',
#             'SUZANNE SHELL'}),
#  frozenset({'BLOCK OF CAKE',
#             'CHAIS',
#             'DECANTER',
#             'ECHOES',
#             'GARDEN SWEEP',
#             'HALL',
#             'MASTER SCROOGE',
#             'SCHOOL',
#             'SCHOOLMASTER',
#             'YOUNG PEOPLE'}),
#  frozenset({'BUSINESS MEN',
#             'COMPANY',
#             'FESTIVE SEASON',
#             'FUND',
#             'FUNERAL',
#             'GENTLEMAN',
#             'GREAT FAT MAN',
#             'MAN WITH LARGE CHIN',
#             'POOR LAW',
#             'RED-FACED GENTLEMAN'}),
#  frozenset({'BENEVOLENCE',
#             'CHARITY',
#             'FORBEARANCE',
#             'JACOB',
#             'MANKIND',
#             'MERCY'}),
#  frozenset({'CAVERN', 'LIGHTHOUSE', 'SEA', 'STORM-BIRDS', 'TWO MEN', 'WATER'}),
#  frozenset({'BONES',
#             'BOTTLES',
#             'GREASY OFFAL',
#             'KEYS',
#             'LOW-BROWED SHOP',
#             'RAGS'}),
#  frozenset({'CHARCOAL STOVE',
#             'GREY-HAIRED RASCAL',
#             'MAN IN FADED BLACK',
#             'SECOND WOMAN',
#             'SHOP',
#             'WOMAN WITH HEAVY BUNDLE'}),
#  frozenset({'BED-CURTAINS', 'FIRST WOMAN', 'JOE', 'OLD SCRATCH'}),
#  frozenset({'GENII', 'PRINCESS', "SULTAN'S GROOM"}),
#  frozenset({'BABY', "DOLL'S FRYING PAN", 'WOODEN PLATTER'}),
#  frozenset({'HOUSE-FRONTS', 'WINDOWS'}),
#  frozenset({'MEAGRE SERVANT', 'POSTBOY'}),
#  frozenset({'ISBN 0-397-00033-2'}),
#  frozenset({'MR. TOPPER'}),
#  frozenset({'THE FIRST OF THE THREE SPIRITS'}),
#  frozenset({'STAVE FIVE'}),
#  frozenset({'DOOR-NAIL'}),
#  frozenset({'COFFIN-NAIL'}),
#  frozenset({"ST. PAUL'S CHURCHYARD"}),
#  frozenset({'PELTING RAIN'}),
#  frozenset({'HEAVIEST RAIN'}),
#  frozenset({'HAIL'}),
#  frozenset({'SLEET'}),
#  frozenset({'CROWDED PATHS'}),
#  frozenset({'HUMAN SYMPATHY'}),
#  frozenset({'CREDENTIALS'}),
#  frozenset({'GAS-LAMPS'}),
#  frozenset({'BAND'}),
#  frozenset({'GREEN HOLLY'}),
#  frozenset({'MOURNING DRESS'}),
#  frozenset({'TRUTH'}),
#  frozenset({'GROUP'}),
#  frozenset({'ADVENTURE'}),
#  frozenset({'RANGE'}),
#  frozenset({'PLENTY'}),
#  frozenset({'ICICLES'}),
#  frozenset({'ROLLER'}),
#  frozenset({'EARTH'}),
#  frozenset({'KITH'}),
#  frozenset({'FOUR-ROOMED HOUSE'}),
#  frozenset({'CARVING-KNIFE'}),
#  frozenset({'GLEE'}),
#  frozenset({'CATCH'}),
#  frozenset({'FIRE-IRONS'}),
#  frozenset({'CHAIRS'}),
#  frozenset({'PIANO'}),
#  frozenset({'WHITECHAPEL'}),
#  frozenset({'AGE'}),
#  frozenset({'SPECTRAL HAND'}),
#  frozenset({'DUSKY SHROUD'}),
#  frozenset({'PENTHOUSE ROOF'}),
#  frozenset({'FLANNEL BAG'}),
#  frozenset({'DEMONS'}),
#  frozenset({'RAGGED SHEET'}),
#  frozenset({'PANE LIGHT'}),
#  frozenset({'AWFUL LANGUAGE'}),
#  frozenset({'CATS'}),
#  frozenset({'RATS'}),
#  frozenset({'GOOD DEEDS'}),
#  frozenset({'MEMORY'}),
#  frozenset({'WOUND'}),
#  frozenset({'CANDLE-LIGHT'}),
#  frozenset({'CARD'}),
#  frozenset({'PRIZE TURKEY'}),
#  frozenset({'GENERAL TERMS OF USE'}),
#  frozenset({'COPYRIGHT ROYALTIES'}),
#  frozenset({'DISTRIBUTION'}),
#  frozenset({'COPYING'}),
#  frozenset({'TRADMARK LICENSE'}),
#  frozenset({'U.S. COPYRIGHT LAW'}),
#  frozenset({'RESEARCH'}),
#  frozenset({'TERMS OF USE'}),
#  frozenset({'INTELLECTUAL PROPERTY'}),
#  frozenset({'TRADEMARK'}),
#  frozenset({'COPYRIGHT LAWS'}),
#  frozenset({'COUNTRY'}),
#  frozenset({'COPYRIGHT RESEARCH'}),
#  frozenset({'DEFECTS'}),
#  frozenset({'LIMITED WARRANTY'}),
#  frozenset({'LEGAL FEES'}),
#  frozenset({'PROJECT GUTENBERG™'}),
#  frozenset({'GENERATION'}),
#  frozenset({'COMPUTERS'}),
#  frozenset({'SECTION 2'}),
#  frozenset({'SECTION 3'}),
#  frozenset({'SECTION 4'}),
#  frozenset({'VOLUNTEER SUPPORT'}),
#  frozenset({'EBOOKS'})]

# %%
len(greedy_communities)
# Out:
# 97

# %% [markdown]
# ## frozenset is immutable, meaning it cannot be changed after creation.

# %% [markdown]
# # Leiden Algorithm

# %% [markdown]
# ## (1): Initialization: Start with each node as its own community.
# ## (2): First Phase (Refinement):
# ### For each node, evaluate its neighborhood and consider moving the node to a neighboring community if it increases modularity.This process is repeated until no further improvements can be made.
# ## (3): Second Phase (Aggregation):
# ### Create a new graph where each community identified in the first phase is a node, and edges between communities are created based on the edges in the original graph.
# ## (4): Repeat:
# ### Apply the first phase to the new aggregated graph to identify more communities. Continue this process until no further improvements are possible.
# ## (5): Output: Final community structure and modularity score.
# ## The Leiden algorithm incorporates an aggregation step and refines communities iteratively, providing greater stability and often higher modularity scores

# %% [markdown]
# # Louvain Method

# %% [markdown]
# ## (1): Initialization: Start with each node as its own community.
# ## (2): Modularity Optimization:
# ### For each node, evaluate its community and consider moving it to neighboring communities to maximize modularity.Continue this step iteratively until no single move can increase modularity.
# ## (3): Aggregation:
# ### Form a new graph where each community is represented as a single node, with edges based on the connections between communities in the original graph.
# ## (4): Repeat:
# ### Apply the same optimization procedure to the new graph to find larger communities.Continue this process until no further improvements can be made.
# ## (5): Output: Final community structure and modularity score.
# ## The Louvain method emphasizes maximizing modularity in each step but does not necessarily ensure the same level of stability or convergence as the Leiden method.

# %% [markdown]
# # Greedy Modularity

# %% [markdown]
# ## (1): Initialization: Start with each node as its own community.
# ## (2): Greedy Optimization:
# ### Iteratively merge communities based on the maximum increase in modularity.At each step, evaluate all possible merges and choose the one that yields the highest increase in modularity.
# ## (3): Termination:
# ### Stop when no further merges can improve the modularity score.
# ## (4): Output: Final community structure and modularity score.
# ## The Greedy Modularity method is more straightforward and relies on a greedy heuristic, which can lead to local optima rather than the best global community structure. It does not incorporate the iterative refinement or aggregation steps found in the Leiden and Louvain methods.

# %% [markdown]
# # 1: Refinement Process:
# ## Leiden and Louvain algorithms involve iterative refinement of communities to maximize modularity.
# ## Greedy directly merges communities without refinement, leading to potentially suboptimal results.
# # 2: Aggregation Step:
# ## Leiden and Louvain both create a new graph based on identified communities and apply the algorithm again, while Greedy does not.
# # 3: Modularity Optimization:
# ## Both Leiden and Louvain aim to maximize modularity during community identification but may differ in the stability and efficiency of their approaches.

# %%
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition = leidenalg.find_partition(igraph, leidenalg.ModularityVertexPartition)

# %% [markdown]
# # (1): ModularityVertexPartition --20 clusters
# # modularity score: 0.6567942050216237 & 20 clusters
# ## Implements modularity. This quality function is well-defined only for positive edge weights.

# %%
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition = leidenalg.find_partition(igraph, leidenalg.ModularityVertexPartition)
modularity_score_igraph = igraph.modularity(partition)  
print(f"Modularity Score from ModularityVertexPartition: {modularity_score_igraph}")
# Out:
# Modularity Score from ModularityVertexPartition: 0.6567942050216237

# %%
print(partition)
# Out:
# Clustering with 610 elements and 20 clusters
# [ 0] SCROOGE, SHIP, HOLLY, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS,
#      HEART, PARLIAMENT, BEDLAM, GENTLEMEN, UNION WORKHOUSES, TREADMILL,
#      POPULATION, ST. DUNSTAN, HAT, TAVERN, DECEASED PARTNER, BANKER'S BOOK,
#      CITY OF LONDON, GATEWAY, CHAMBERS, KEY, WINE-MERCHANT, STAIRS, GRUEL,
#      SITTING-ROOM, BEDROOM, LUMBER-ROOM, DRESSING-GOWN, SLIPPERS, CAINS,
#      ABELS, PHARAOH'S DAUGHTERS, QUEENS OF SHEBA, ANGELIC MESSENGERS,
#      ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-BOATS, SENSES, BEEF, MUSTARD,
#      CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE, WARD, WISE MEN, POOR ABODE,
#      CROWD, INVISIBLE WORLD, WINDOW, CHAMBER, TIME, THE VISITATION, THE CLOCK,
#      THE CHIME, THE QUARTER, HOUR BELL, CURTAINS, UNEARTHLY VISITOR, WELFARE,
#      BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE, MANSION OF DULL RED
#      BRICK, ALI BABA, POPPLAR, DAMASCUS, VALENTINE, ROBIN CRUSOE, FRIDAY,
#      PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN, BRAIDED
#      HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION,
#      GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH AND CHAPEL,
#      INCENSE, TORCH, POOR MAN'S CHILD, HELMSMAN, LOOK-OUT, OFFICERS, POOR
#      CLERK, AROMATIC VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS, SISTERS,
#      LONDON, BUSINESSMEN, SHADOW, HOUSES, FURNITURE, PRESENT, CHRISTMAS TIME,
#      BEDPOST, WANDERING SPIRITS, LAOCOON, CHURCHES, CORNER, POULTERER, TURKEY,
#      CAB, SCROOGE AND MARLEY'S, PORTLY GENTLEMAN, TANK, FOG AND FROST,
#      OFFICES, ORSON, GUESTS
# [ 1] A CHRISTMAS CAROL, CHARLES DICKENS, EBENEZER SCROOGE, ARTHUR RACKHAM,
#      PHILADELPHIA, NEW YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE
#      DISTRIBUTED PROOFREADING TEAM, J. B. LIPPINCOTT COMPANY, GHOST, GHOST OF
#      CHRISTMAS YET TO COME, GHOST OF JACOB MARLEY, DICK WILKINS, MARLEY'S
#      GHOST, FEZZIWIG'S BALL, JACOB MARLEY, THE THREE SPIRITS, SCROOGE AND
#      MARLEY, HAMLET, NIGHT, SCROOGE'S HOUSE, CHAIN, MONEY-CHANGING HOLE,
#      MARLEY, BELL, FIRST OF EXCHANGE, FIREPLACE, HAPPINESS, SPECTRE, THREE
#      SPIRITS, TWELVE, STAVE TWO, MERRY CHRISTMAS, BAKER'S, SURPLUS POPULATION,
#      BLAZE, LAMPLIGHTER, SCOURGE, SPIRIT'S ROBE, WINE-MERCHANT'S CELLAR,
#      HAUNTED HOUSE, DOOR, PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS,
#      CHAINS, STAVE ONE, GHOSTS, HOUSE, SPIRIT OF CHRISTMAS YET TO COME,
#      KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL REGISTER, GHOSTLY
#      SPECTACLES, WAISTCOAT, PIGTAIL, DARK CELLAR, DUTCH MERCHANT, WOMAN WITH
#      INFANT
# [ 2] BOB CRATCHIT, TINY TIM, CHILD, MR. SCROOGE, PETER CRATCHIT, TIM CRATCHIT,
#      MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, THE CRATCHIT FAMILY,
#      CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR, CHRISTMAS
#      DINNER, CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS,
#      OFFICE, COAL-SCUTTLE, GOOSE, FIRE, BELINDA, CHRISTMAS PUDDING, BOB,
#      CHRISTMAS PARTY, OLD GENTLEMAN, BRAZIER, RAGGED MEN AND BOYS, GHOST OF
#      CHRISTMAS, HAPPY END, CRATCHITS, MARTHA, PUDDING, CHIMNEY CORNER,
#      SPIRITS, TOTAL-ABSTINENCE PRINCIPLE, GLOBE, YOUNGEST CRATCHITS, SAGE AND
#      ONION, HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY TIM, HOLIDAY,
#      MILLINER, COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S
#      NEPHEW, GOOD WIFE, NINE O'CLOCK, COPPER
# [ 3] FAN, CHRISTMAS, FATHER, BOY, LORD MAYOR, MANSION HOUSE, POULTERERS,
#      GROCERS, TAILOR, RAGGED MEN, BOYS, BERRIES, IVY, THRONE, RED BERRIES,
#      TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES, OYSTERS,
#      PIES, PUDDINGS, FRUIT, PUNCH, CUSTOMERS, GROCER, BAKERS' SHOPS, MARKET-
#      TOWN, LITTLE FAN, POULTERER'S, FIFTY COOKS AND BUTLERS, FISH, ALMONDS,
#      CINNAMON, RAISINS, TEA, COFFEE, FARMERS, COACH, SPICES, CANISTERS,
#      CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 4] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 5] DEATH, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, DINNER, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, LAMPLIGHT, CHARWOMAN,
#      UNDERTAKER'S MAN, DESSERT, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS,
#      BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 6] GHOST OF CHRISTMAS PAST, BELLE, SPIRIT, CHURCHYARD, GRAVE, TWELFTH-NIGHT
#      PARTY, CHILDREN, FAMILY, YOUNG GIRL, IDOL, MASTER OF THE HOUSE, PRISONS,
#      COUNTRY ROAD, FIELDS, COMELY MATRON, MOTHER, CHAOS, CHRISTMAS HOLIDAYS,
#      PAST, FUTURE, ALMSHOUSE, HOSPITAL, GAOL, POVERTY, IGNORANCE, WANT,
#      DEVILS, ANGELS, WORKHOUSES, MYSTERY, WEALTH, DAUGHTER, BROWN-PAPER
#      PARCELS, MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS
# [ 7] PHANTOM, PORCH, TOWN, SELF, HOLLY SPRIGS, CHURCH, ANCIENT TOWER, ROOM,
#      CLOCK, COLD, BED, FIGURE, WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN
#      STREET, GAS-PIPES, UNKNOWN, LIGHT, GLOOM, GRAVES, MULTITUDES, TUNIC,
#      SUMMER FLOWERS, BELT, LOW-BROWED SHOP, INFAMOUS RESORT, NARROW ALLEYS,
#      ARCHWAYS, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 8] FRED, GHOST OF CHRISTMAS PRESENT, SCROOGE'S NIECE, PARTY, GOOD-HUMOUR,
#      SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER, SCROOGE'S
#      NEPHEW, GENTLEMAN, POOR LAW, SCROOGE'S NIECE'S SISTERS, BUSINESS MEN,
#      FUNERAL, MAN WITH LARGE CHIN, FESTIVE SEASON, FUND, COMPANY, SCROOGE'S
#      NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND
#      WHERE, MUSIC, BLIND MAN'S-BUFF, BLIND MAN, GAMES, GREAT FAT MAN, RED-
#      FACED GENTLEMAN
# [ 9] MR. FEZZIWIG, CHRISTMAS EVE, FEZZIWIG, DICK, MRS. FEZZIWIG, WAREHOUSE,
#      HIGH DESK, WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD
#      ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY,
#      DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, PORTER, BAKER, STREET, MISS
#      FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID, COOK, MILKMAN, FIDDLER
# [10] GREAT BRITAIN, PEOPLE, MISTLETOE, CHESTNUTS, SNOW, CLIMATE, SNOWBALL
#      FIGHT, POULTERERS' SHOPS, FRUITERERS, WICKER BASKETS, DINNERS, NORFOLK
#      BIFFINS, SNOWSTORMS, SPANISH ONIONS, SHOPKEEPERS, PEARS, APPLES, GRAPES,
#      FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS, VEGETABLES
# [11] COUNTING-HOUSE, MIST, CORNHILL, CLERK, CITY, STREETS, CANDLE, DARKNESS,
#      WINTER DAY, CAMDEN TOWN, MASTER, FIFTEEN SHILLINGS, CANDLES, CHANGE,
#      MONEY, MERCHANTS, COURT, FOG, FLOGGING LINKS, CARTS AND WAGONS, GOLD
#      SEALS
# [12] MASTER SCROOGE, DINING-ROOM, NEPHEW, HALL, YES AND NO, GIRL, ANIMAL,
#      MISTRESS, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG
#      PEOPLE, DECANTER, BLOCK OF CAKE, YOUNG HOUSEKEEPERS
# [13] MOOR, FROST, OLD MAN, LIGHTHOUSE, TWO MEN, MINERS, CHEERFUL COMPANY,
#      SETTING SUN, HUT, CHRISTMAS SONG, WATER, STORM-BIRDS, SEA, CAVERN
# [14] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [15] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [16] SULTAN'S GROOM, PRINCESS, GENII
# [17] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [18] WINDOWS, HOUSE-FRONTS
# [19] MEAGRE SERVANT, POSTBOY

# %% [markdown]
# # (2): RBConfigurationVertexPartition
# # Maximum Modularity Score: 0.657676610617402 & 19 clusters
# ## Implements Reichardt and Bornholdt’s Potts model with a configuration null model. This quality function is well-defined only for positive edge weights. This quality function uses a linear resolution parameter.

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition2 = la.find_partition(igraph, la.RBConfigurationVertexPartition,resolution_parameter=1.0)
modularity_score_igraph2 = igraph.modularity(partition2)  
print(f"Modularity Score from RBConfigurationVertexPartition: {modularity_score_igraph2}")
# Out:
# Modularity Score from RBConfigurationVertexPartition: 0.6553960783387147

# %%
print(partition2)
# Out:
# Clustering with 610 elements and 20 clusters
# [ 0] SCROOGE, SHIP, HOLLY, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS,
#      HEART, PARLIAMENT, BEDLAM, GENTLEMEN, UNION WORKHOUSES, TREADMILL,
#      POPULATION, ST. DUNSTAN, HAT, TAVERN, DECEASED PARTNER, BANKER'S BOOK,
#      CITY OF LONDON, GATEWAY, CHAMBERS, KEY, WINE-MERCHANT, STAIRS, GRUEL,
#      SITTING-ROOM, BEDROOM, LUMBER-ROOM, DRESSING-GOWN, SLIPPERS, CAINS,
#      ABELS, PHARAOH'S DAUGHTERS, QUEENS OF SHEBA, ANGELIC MESSENGERS,
#      ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-BOATS, SENSES, BEEF, MUSTARD,
#      CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE, WARD, WISE MEN, POOR ABODE,
#      CROWD, INVISIBLE WORLD, WINDOW, CHAMBER, TIME, THE VISITATION, THE CLOCK,
#      THE CHIME, THE QUARTER, HOUR BELL, CURTAINS, UNEARTHLY VISITOR, WELFARE,
#      BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE, MANSION OF DULL RED
#      BRICK, ALI BABA, POPPLAR, DAMASCUS, VALENTINE, ROBIN CRUSOE, FRIDAY,
#      PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN, BRAIDED
#      HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION,
#      GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH AND CHAPEL,
#      INCENSE, TORCH, POOR MAN'S CHILD, HELMSMAN, LOOK-OUT, OFFICERS, POOR
#      CLERK, AROMATIC VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS, SISTERS,
#      LONDON, BUSINESSMEN, SHADOW, HOUSES, FURNITURE, PRESENT, CHRISTMAS TIME,
#      BEDPOST, WANDERING SPIRITS, LAOCOON, CHURCHES, CORNER, POULTERER, TURKEY,
#      CAB, SCROOGE AND MARLEY'S, PORTLY GENTLEMAN, TANK, FOG AND FROST,
#      OFFICES, ORSON, GUESTS
# [ 1] BOB CRATCHIT, TINY TIM, CHILD, MR. SCROOGE, PETER CRATCHIT, TIM CRATCHIT,
#      MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, THE CRATCHIT FAMILY,
#      CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR, CHRISTMAS
#      DINNER, CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS,
#      OFFICE, COAL-SCUTTLE, GOOSE, FIRE, BELINDA, CHRISTMAS PUDDING, BOB,
#      CHRISTMAS PARTY, OLD GENTLEMAN, BRAZIER, RAGGED MEN AND BOYS, GHOST OF
#      CHRISTMAS, HAPPY END, CRATCHITS, MARTHA, PUDDING, CHIMNEY CORNER,
#      SPIRITS, TOTAL-ABSTINENCE PRINCIPLE, GLOBE, YOUNGEST CRATCHITS, SAGE AND
#      ONION, HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY TIM, HOLIDAY,
#      MILLINER, COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S
#      NEPHEW, GOOD WIFE, NINE O'CLOCK, COPPER
# [ 2] FAN, CHRISTMAS, FATHER, BOY, LORD MAYOR, MANSION HOUSE, POULTERERS,
#      GROCERS, TAILOR, RAGGED MEN, BOYS, BERRIES, PORTER, IVY, THRONE, RED
#      BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES,
#      OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, CUSTOMERS, GROCER, BAKERS' SHOPS,
#      MARKET-TOWN, LITTLE FAN, POULTERER'S, FIFTY COOKS AND BUTLERS, FISH,
#      ALMONDS, CINNAMON, RAISINS, TEA, COFFEE, FARMERS, COACH, FIDDLER, SPICES,
#      CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 3] EBENEZER SCROOGE, GHOST, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME,
#      GHOST OF JACOB MARLEY, DICK WILKINS, CHRISTMAS EVE, FEZZIWIG'S BALL,
#      JACOB MARLEY, THE THREE SPIRITS, SCROOGE AND MARLEY, HAMLET, NIGHT,
#      SCROOGE'S HOUSE, CHAIN, MONEY-CHANGING HOLE, FIRST OF EXCHANGE, FEZZIWIG,
#      HAPPINESS, SPECTRE, THREE SPIRITS, TWELVE, STAVE TWO, MERRY CHRISTMAS,
#      DICK, BAKER'S, SURPLUS POPULATION, SPIRIT'S ROBE, MRS. FEZZIWIG,
#      WAREHOUSE, WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD
#      ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY,
#      DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, BAKER, MISS FEZZIWIG, YOUNG
#      FOLLOWERS, HOUSEMAID, COOK, MILKMAN
# [ 4] GHOST OF CHRISTMAS PAST, BELLE, SPIRIT, CHURCHYARD, GRAVE, BLAZE,
#      LAMPLIGHTER, TWELFTH-NIGHT PARTY, CHILDREN, FAMILY, YOUNG GIRL, IDOL,
#      HIGH DESK, MASTER OF THE HOUSE, PRISONS, COUNTRY ROAD, FIELDS, HOUSE,
#      COMELY MATRON, MOTHER, CHAOS, OLD MAN, CHRISTMAS HOLIDAYS, PAST, FUTURE,
#      MINERS, CHEERFUL COMPANY, ALMSHOUSE, HOSPITAL, GAOL, POVERTY, IGNORANCE,
#      WANT, DEVILS, ANGELS, WORKHOUSES, MYSTERY, STREET, WEALTH, DAUGHTER,
#      BROWN-PAPER PARCELS, MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS,
#      HUT, CHRISTMAS SONG
# [ 5] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 6] DEATH, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, DINNER, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, LAMPLIGHT, CHARWOMAN,
#      UNDERTAKER'S MAN, DESSERT, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS,
#      BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 7] PHANTOM, PORCH, TOWN, SELF, HOLLY SPRIGS, ANCIENT TOWER, ROOM, CLOCK,
#      COLD, BED, FIGURE, WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN STREET,
#      GAS-PIPES, UNKNOWN, LIGHT, GLOOM, GRAVES, MULTITUDES, TUNIC, SUMMER
#      FLOWERS, BELT, LOW-BROWED SHOP, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS,
#      RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 8] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#      YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#      TEAM, J. B. LIPPINCOTT COMPANY, GREAT BRITAIN, PEOPLE, MISTLETOE,
#      CHESTNUTS, SNOW, CLIMATE, SNOWBALL FIGHT, POULTERERS' SHOPS, FRUITERERS,
#      WICKER BASKETS, DINNERS, NORFOLK BIFFINS, SNOWSTORMS, SPANISH ONIONS,
#      SHOPKEEPERS, PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS,
#      FRUITS, VEGETABLES
# [ 9] FRED, GHOST OF CHRISTMAS PRESENT, SCROOGE'S NIECE, PARTY, GOOD-HUMOUR,
#      SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER, SCROOGE'S
#      NEPHEW, GENTLEMAN, POOR LAW, SCROOGE'S NIECE'S SISTERS, BUSINESS MEN,
#      FUNERAL, MAN WITH LARGE CHIN, FESTIVE SEASON, FUND, COMPANY, SCROOGE'S
#      NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND
#      WHERE, MUSIC, BLIND MAN'S-BUFF, BLIND MAN, GAMES, GREAT FAT MAN, RED-
#      FACED GENTLEMAN
# [10] MARLEY'S GHOST, MARLEY, BELL, FIREPLACE, WINE-MERCHANT'S CELLAR, HAUNTED
#      HOUSE, DOOR, PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS,
#      STAVE ONE, CHURCH, GHOSTS, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF MOURNER,
#      BURIAL REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, DARK CELLAR,
#      DUTCH MERCHANT, WOMAN WITH INFANT
# [11] COUNTING-HOUSE, MIST, CORNHILL, CLERK, CITY, STREETS, CANDLE, DARKNESS,
#      WINTER DAY, CAMDEN TOWN, MASTER, FIFTEEN SHILLINGS, CHANGE, MONEY,
#      MERCHANTS, FOG, FLOGGING LINKS, CARTS AND WAGONS, GOLD SEALS
# [12] MASTER SCROOGE, DINING-ROOM, NEPHEW, HALL, YES AND NO, GIRL, ANIMAL,
#      MISTRESS, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG
#      PEOPLE, DECANTER, BLOCK OF CAKE, YOUNG HOUSEKEEPERS
# [13] SCOURGE, MOOR, FROST, SPIRIT OF CHRISTMAS YET TO COME, CANDLES, COURT,
#      LIGHTHOUSE, TWO MEN, SETTING SUN, WATER, STORM-BIRDS, SEA, CAVERN
# [14] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [15] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [16] SULTAN'S GROOM, PRINCESS, GENII
# [17] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [18] WINDOWS, HOUSE-FRONTS
# [19] MEAGRE SERVANT, POSTBOY

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition2_2 = la.find_partition(igraph, la.RBConfigurationVertexPartition,resolution_parameter=3.0)
modularity_score_igraph2_2 = igraph.modularity(partition2_2)  
print(f"Modularity Score from RBConfigurationVertexPartition: {modularity_score_igraph2_2}")
# Out:
# Modularity Score from RBConfigurationVertexPartition: 0.634326032055587

# %%
print(partition2_2)
# Out:
# Clustering with 610 elements and 40 clusters
# [ 0] SCROOGE, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART,
#      PARLIAMENT, BEDLAM, GENTLEMEN, UNION WORKHOUSES, TREADMILL, POPULATION,
#      ST. DUNSTAN, HAT, TAVERN, DECEASED PARTNER, BANKER'S BOOK, CITY OF
#      LONDON, KEY, WINE-MERCHANT, STAIRS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-
#      ROOM, DRESSING-GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS
#      OF SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-
#      BOATS, SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE,
#      WARD, WISE MEN, POOR ABODE, CROWD, INVISIBLE WORLD, WINDOW, CHAMBER,
#      TIME, THE VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL,
#      CURTAINS, WELFARE, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE,
#      MANSION OF DULL RED BRICK, ALI BABA, POPPLAR, DAMASCUS, ROBIN CRUSOE,
#      FRIDAY, PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN,
#      BRAIDED HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT,
#      TRANSFORMATION, GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH
#      AND CHAPEL, INCENSE, TORCH, POOR MAN'S CHILD, POOR CLERK, AROMATIC
#      VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS, LONDON, BUSINESSMEN, SHADOW,
#      HOUSES, FURNITURE, PRESENT, CHRISTMAS TIME, BEDPOST, WANDERING SPIRITS,
#      LAOCOON, CHURCHES, CORNER, POULTERER, TURKEY, CAB, SCROOGE AND MARLEY'S,
#      PORTLY GENTLEMAN, TANK
# [ 1] BOB CRATCHIT, TINY TIM, PETER CRATCHIT, TIM CRATCHIT, MRS. CRATCHIT,
#      BELINDA CRATCHIT, MARTHA CRATCHIT, THE CRATCHIT FAMILY, CRATCHIT HOUSE,
#      CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR, CHRISTMAS DINNER,
#      CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS, COAL-
#      SCUTTLE, GOOSE, BELINDA, CHRISTMAS PUDDING, BOB, CHRISTMAS PARTY,
#      CRATCHITS, MARTHA, PUDDING, CHIMNEY CORNER, SPIRITS, TOTAL-ABSTINENCE
#      PRINCIPLE, GLOBE, YOUNGEST CRATCHITS, SAGE AND ONION, HEARTH, CLOTH,
#      FIRST PARTING, SPIRIT OF TINY TIM, HOLIDAY, MILLINER, COUNTESS, LORD,
#      WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE, NINE
#      O'CLOCK, COPPER
# [ 2] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, COPYRIGHT HOLDER, USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII,
#      COPYRIGHT, ROYALTY FEE, COPYRIGHT LAW, AGREEMENT, FOUNDATION, GUTENBERG
#      LITERARY ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK,
#      VOLUNTEER, DONATION, ADDRESS, DERIVATIVE WORKS, DONATIONS, U.S. FEDERAL
#      LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS, CHARITABLE
#      DONATIONS, COMPLIANCE REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE
#      SERVICE, MISSISSIPPI
# [ 3] DEATH, LAUGHTER, WOMAN, MAN, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, CORPSE, SPOIL, CONTRACT, ASPIRATIONS,
#      INDUSTRY, BLANKETS, SHIRT, CHARWOMAN, UNDERTAKER'S MAN, BUNDLE, SEAL,
#      PENCIL-CASE, SLEEVE-BUTTONS, BROOCH, SHEETS, TOWELS, SILVER TEASPOONS,
#      SUGAR-TONGS, BOOTS
# [ 4] CHRISTMAS, LORD MAYOR, MANSION HOUSE, POULTERERS, TAILOR, RAGGED MEN,
#      BOYS, BERRIES, IVY, THRONE, RED BERRIES, TURKEYS, GEESE, GAME, POULTRY,
#      BRAWN, MEAT, PIGS, SAUSAGES, OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH,
#      MARKET-TOWN, FIFTY COOKS AND BUTLERS, FARMERS
# [ 5] CHRISTMAS EVE, FEZZIWIG, DICK, MRS. FEZZIWIG, WAREHOUSE, WELSH WIG,
#      EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD ROAST, COLD BOILED,
#      MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY, DOMESTIC BALL,
#      APPRENTICES, CHRISTMAS BALL, BAKER, MISS FEZZIWIG, YOUNG FOLLOWERS,
#      HOUSEMAID, COOK, MILKMAN
# [ 6] FRED, GHOST OF CHRISTMAS PRESENT, SCROOGE'S NIECE, PARTY, GOOD-HUMOUR,
#      SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER, SCROOGE'S
#      NEPHEW, SCROOGE'S NIECE'S SISTERS, SCROOGE'S NIECE'S SISTER, HARP, LARGE
#      CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF,
#      BLIND MAN, GAMES
# [ 7] TOWN, CAROLINE, HUSBAND, DEBT, MOTHER, CHAOS, DINNER, DAUGHTER,
#      LAMPLIGHT, LOW-BROWED SHOP, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS,
#      DESSERT, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 8] SPIRIT, HIGH DESK, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS,
#      CHRISTMAS HOLIDAYS, PAST, FUTURE, ALMSHOUSE, HOSPITAL, GAOL, IGNORANCE,
#      WANT, DEVILS, WORKHOUSES, MYSTERY, STREET
# [ 9] FIRE, MOOR, FROST, OLD MAN, BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO
#      MEN, MINERS, CHEERFUL COMPANY, SETTING SUN, HUT, CHRISTMAS SONG, WATER,
#      STORM-BIRDS, SEA, CAVERN
# [10] MASTER SCROOGE, DINING-ROOM, NEPHEW, HALL, YES AND NO, GIRL, ANIMAL,
#      MISTRESS, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG
#      PEOPLE, DECANTER, BLOCK OF CAKE, YOUNG HOUSEKEEPERS
# [11] GHOST OF CHRISTMAS PAST, CHILDREN, FAMILY, YOUNG GIRL, IDOL, PORTER,
#      COMELY MATRON, POVERTY, ANGELS, FIDDLER, WEALTH, BROWN-PAPER PARCELS,
#      MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS
# [12] PEOPLE, SCOURGE, MASTER OF THE HOUSE, STREETS, HOUSE, SPIRIT OF CHRISTMAS
#      YET TO COME, CANDLES, COURT, SNOW, CLIMATE, SNOWBALL FIGHT, WICKER
#      BASKETS, DINNERS, SNOWSTORMS, CARTS AND WAGONS
# [13] MISTLETOE, CHESTNUTS, POULTERERS' SHOPS, FRUITERERS, SPANISH ONIONS,
#      SHOPKEEPERS, PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS,
#      FRUITS, VEGETABLES
# [14] GROCERS, CUSTOMERS, GROCER, NORFOLK BIFFINS, FISH, ALMONDS, CINNAMON,
#      RAISINS, TEA, COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH
#      PLUMS
# [15] GHOST, JACOB MARLEY, CHAIN, HAPPINESS, SPECTRE, THREE SPIRITS, TWELVE,
#      STAVE TWO, CHILD, BAKER'S, SURPLUS POPULATION, BLAZE, LAMPLIGHTER,
#      TWELFTH-NIGHT PARTY, SPIRIT'S ROBE
# [16] PHANTOM, PORCH, HOLLY SPRIGS, ANCIENT TOWER, ROOM, COLD, WINTER FIRE,
#      BODY, TERRORS, STAVE FOUR, MAIN STREET, GAS-PIPES, GLOOM, GRAVES
# [17] SCROOGE AND MARLEY, MARLEY, FIREPLACE, STAVE ONE, KNOCKER, CLERGYMAN,
#      UNDERTAKER, CHIEF MOURNER, BURIAL REGISTER, GHOSTLY SPECTACLES,
#      WAISTCOAT, PIGTAIL, DARK CELLAR, DUTCH MERCHANT
# [18] EBENEZER SCROOGE, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF
#      JACOB MARLEY, DICK WILKINS, FEZZIWIG'S BALL, THE THREE SPIRITS, HAMLET,
#      NIGHT, SCROOGE'S HOUSE, MONEY-CHANGING HOLE, FIRST OF EXCHANGE,
#      CHURCHYARD, GRAVE
# [19] SELF, HOLLY, CHURCH, CLOCK, BED, UNEARTHLY VISITOR, FIGURE, UNKNOWN,
#      LIGHT, MULTITUDES, TUNIC, SUMMER FLOWERS, BELT
# [20] COUNTING-HOUSE, MIST, CITY, DARKNESS, WINTER DAY, CHANGE, MONEY,
#      MERCHANTS, FOG, FLOGGING LINKS, GOLD SEALS
# [21] PROJECT GUTENBERG LICENSE, ELECTRONIC WORK, PARAGRAPH 1.F.3, REFUND,
#      PERSON, ENTITY, DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN
#      EXPLANATION, DEFECTIVE WORK, PHYSICAL MEDIUM
# [22] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, GHOSTS, WOMAN
#      WITH INFANT
# [23] GENTLEMAN, POOR LAW, BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN, FESTIVE
#      SEASON, FUND, COMPANY, GREAT FAT MAN, RED-FACED GENTLEMAN
# [24] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#      YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#      TEAM, J. B. LIPPINCOTT COMPANY, GREAT BRITAIN
# [25] BELLE, MERRY CHRISTMAS, MR. SCROOGE, OFFICE, OLD GENTLEMAN, GHOST OF
#      CHRISTMAS, HAPPY END
# [26] FAN, FATHER, BOY, LITTLE FAN, POULTERER'S, COACH
# [27] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [28] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [29] CORNHILL, CLERK, CANDLE, CAMDEN TOWN, MASTER, FIFTEEN SHILLINGS
# [30] JOE, OLD SCRATCH, BED-CURTAINS, FIRST WOMAN
# [31] SHIP, HELMSMAN, LOOK-OUT, OFFICERS
# [32] SULTAN'S GROOM, PRINCESS, GENII
# [33] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [34] VALENTINE, ORSON
# [35] SISTERS, GUESTS
# [36] WINDOWS, HOUSE-FRONTS
# [37] GATEWAY, FOG AND FROST
# [38] CHAMBERS, OFFICES
# [39] MEAGRE SERVANT, POSTBOY

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition2_3 = la.find_partition(igraph, la.RBConfigurationVertexPartition,resolution_parameter=6.0)
modularity_score_igraph2_3 = igraph.modularity(partition2_3)  
print(f"Modularity Score from RBConfigurationVertexPartition: {modularity_score_igraph2_3}")
# Out:
# Modularity Score from RBConfigurationVertexPartition: 0.5847045758773394

# %%
print(partition2_3)
# Out:
# Clustering with 610 elements and 59 clusters
# [ 0] SCROOGE, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART,
#      PARLIAMENT, BEDLAM, UNION WORKHOUSES, TREADMILL, ST. DUNSTAN, HAT,
#      TAVERN, DECEASED PARTNER, BANKER'S BOOK, CITY OF LONDON, KEY, WINE-
#      MERCHANT, STAIRS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-ROOM, DRESSING-
#      GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS OF SHEBA,
#      ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-BOATS,
#      SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE, WARD,
#      WISE MEN, POOR ABODE, CROWD, INVISIBLE WORLD, WINDOW, CHAMBER, TIME, THE
#      VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL, CURTAINS,
#      WELFARE, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE, MANSION OF
#      DULL RED BRICK, ALI BABA, POPPLAR, DAMASCUS, ROBIN CRUSOE, FRIDAY,
#      PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN, BRAIDED
#      HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION,
#      GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH AND CHAPEL,
#      INCENSE, TORCH, POOR MAN'S CHILD, POOR CLERK, AROMATIC VINEGAR, MOLDY OLD
#      OFFICE, DUSTY CHAMBERS, LONDON, BUSINESSMEN, SHADOW, HOUSES, FURNITURE,
#      PRESENT, CHRISTMAS TIME, BEDPOST, WANDERING SPIRITS, LAOCOON, CHURCHES,
#      CORNER, POULTERER, TURKEY, CAB, SCROOGE AND MARLEY'S, PORTLY GENTLEMAN,
#      TANK
# [ 1] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, TERMS OF THIS AGREEMENT, UNITED STATES, WORLD, COPYRIGHT
#      HOLDER, USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY
#      FEE, COPYRIGHT LAW, AGREEMENT, FOUNDATION, MICHAEL S. HART,
#      WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER, DONATION, ADDRESS, DONATIONS, U.S.
#      FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, CHARITABLE
#      DONATIONS, COMPLIANCE REQUIREMENTS
# [ 2] CHRISTMAS, LORD MAYOR, MANSION HOUSE, POULTERERS, TAILOR, RAGGED MEN,
#      BERRIES, IVY, THRONE, RED BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN,
#      MEAT, PIGS, SAUSAGES, OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, FIFTY COOKS
#      AND BUTLERS
# [ 3] CHRISTMAS EVE, FEZZIWIG, DICK, MRS. FEZZIWIG, HIGH DESK, WELSH WIG,
#      EBENEZER, DANCE, COLD ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES,
#      SIR ROGER DE COVERLEY, DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, STREET
# [ 4] PETER CRATCHIT, MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT,
#      CRATCHIT FAMILY, YOUNG CRATCHITS, CHRISTMAS DINNER, GOOSE, BELINDA,
#      CHRISTMAS PUDDING, YOUNGEST CRATCHITS, SAGE AND ONION, HEARTH, CLOTH,
#      FIRST PARTING, SPIRIT OF TINY TIM, COPPER
# [ 5] LAUGHTER, MRS. DILBER, LAUNDRESS, PARLOUR, OLD JOE, CHARWOMAN,
#      UNDERTAKER'S MAN, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS, BROOCH,
#      SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 6] SPIRIT, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS, CHRISTMAS HOLIDAYS,
#      PAST, FUTURE, ALMSHOUSE, HOSPITAL, GAOL, IGNORANCE, WANT, WORKHOUSES,
#      MYSTERY
# [ 7] GROCERS, CUSTOMERS, GROCER, FISH, ALMONDS, CINNAMON, RAISINS, TEA,
#      COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 8] GHOST, JACOB MARLEY, CHAIN, HAPPINESS, SPECTRE, THREE SPIRITS, TWELVE,
#      STAVE TWO, BAKER'S, SURPLUS POPULATION, BLAZE, LAMPLIGHTER, TWELFTH-NIGHT
#      PARTY, SPIRIT'S ROBE
# [ 9] MISTLETOE, FRUITERERS, NORFOLK BIFFINS, SPANISH ONIONS, SHOPKEEPERS,
#      PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS,
#      VEGETABLES
# [10] EBENEZER SCROOGE, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF
#      JACOB MARLEY, DICK WILKINS, FEZZIWIG'S BALL, THE THREE SPIRITS, HAMLET,
#      NIGHT, SCROOGE'S HOUSE, MONEY-CHANGING HOLE, FIRST OF EXCHANGE,
#      CHURCHYARD, GRAVE
# [11] MARLEY, FIREPLACE, STAVE ONE, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF
#      MOURNER, BURIAL REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, DARK
#      CELLAR, DUTCH MERCHANT
# [12] CHILD, WOMAN, CAROLINE, HUSBAND, MAN, DEBT, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT
# [13] PARTY, GENTLEMAN, POOR LAW, BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN,
#      FESTIVE SEASON, FUND, COMPANY, GAMES, GREAT FAT MAN, RED-FACED GENTLEMAN
# [14] SCROOGE'S NIECE, UNCLE SCROOGE, TOPPER, SCROOGE'S NEPHEW, SCROOGE'S
#      NIECE'S SISTERS, SCROOGE'S NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL,
#      GAME OF HOW, WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF
# [15] CHILDREN, FAMILY, PORTER, DEVILS, ANGELS, FIDDLER, BROWN-PAPER PARCELS,
#      MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS
# [16] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, GHOSTS, WOMAN
#      WITH INFANT
# [17] PROJECT GUTENBERG LICENSE, ELECTRONIC WORK, PARAGRAPH 1.F.3, REFUND,
#      PERSON, ENTITY, DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN
#      EXPLANATION, DEFECTIVE WORK, PHYSICAL MEDIUM
# [18] MIST, CITY, DARKNESS, WINTER DAY, CHANGE, MONEY, MERCHANTS, FOG, FLOGGING
#      LINKS, GOLD SEALS
# [19] MASTER SCROOGE, HALL, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP,
#      YOUNG PEOPLE, DECANTER, BLOCK OF CAKE
# [20] PHANTOM, PORCH, ROOM, COLD, WINTER FIRE, BODY, TERRORS, STAVE FOUR,
#      GLOOM, GRAVES
# [21] SCROOGE AND MARLEY, WAREHOUSE, WINTER BALL, DANCE EVENT, BAKER, MISS
#      FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID, COOK, MILKMAN
# [22] GREAT BRITAIN, PEOPLE, STREETS, CHESTNUTS, CLIMATE, SNOWBALL FIGHT,
#      POULTERERS' SHOPS, WICKER BASKETS, DINNERS, CARTS AND WAGONS
# [23] TOWN, LOW-BROWED SHOP, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS, RAGS,
#      BOTTLES, BONES, GREASY OFFAL, KEYS
# [24] BELLE, SCOURGE, MASTER OF THE HOUSE, HOUSE, SPIRIT OF CHRISTMAS YET TO
#      COME, CANDLES, COURT, SNOW, SNOWSTORMS
# [25] FIRE, BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO MEN, WATER, STORM-
#      BIRDS, SEA, CAVERN
# [26] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#      YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#      TEAM, J. B. LIPPINCOTT COMPANY
# [27] MOOR, FROST, OLD MAN, MINERS, CHEERFUL COMPANY, SETTING SUN, HUT,
#      CHRISTMAS SONG
# [28] BOB CRATCHIT, TIM CRATCHIT, CLOSET DOOR, PETER, CRATCHIT'S HOUSE,
#      CRATCHIT'S WIFE, GIRLS, COAL-SCUTTLE
# [29] FRED, GHOST OF CHRISTMAS PRESENT, CRATCHIT HOUSE, GOOD-HUMOUR, SISTER,
#      MULLED WINE, PLUMP SISTER, BLIND MAN
# [30] TINY TIM, CHRISTMAS DAY, CRATCHITS, PUDDING, CHIMNEY CORNER, SPIRITS,
#      TOTAL-ABSTINENCE PRINCIPLE, GLOBE
# [31] DINING-ROOM, NEPHEW, YES AND NO, GIRL, ANIMAL, MISTRESS, YOUNG
#      HOUSEKEEPERS
# [32] MERRY CHRISTMAS, MR. SCROOGE, THE CRATCHIT FAMILY, OFFICE, OLD GENTLEMAN,
#      GHOST OF CHRISTMAS, HAPPY END
# [33] HOLLY, UNEARTHLY VISITOR, FIGURE, LIGHT, TUNIC, SUMMER FLOWERS, BELT
# [34] BOB, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE,
#      NINE O'CLOCK
# [35] COUNTING-HOUSE, CORNHILL, CLERK, CANDLE, CAMDEN TOWN, MASTER, FIFTEEN
#      SHILLINGS
# [36] GHOST OF CHRISTMAS PAST, YOUNG GIRL, IDOL, COMELY MATRON, POVERTY, WEALTH
# [37] SELF, CHURCH, CLOCK, BED, UNKNOWN, MULTITUDES
# [38] FAN, FATHER, BOY, LITTLE FAN, POULTERER'S, COACH
# [39] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [40] MOTHER, CHAOS, DINNER, DAUGHTER, LAMPLIGHT, DESSERT
# [41] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [42] CHRISTMAS PARTY, MARTHA, HOLIDAY, MILLINER, COUNTESS, LORD
# [43] HOLLY SPRIGS, ANCIENT TOWER, MAIN STREET, GAS-PIPES
# [44] JOE, OLD SCRATCH, BED-CURTAINS, FIRST WOMAN
# [45] SHIP, HELMSMAN, LOOK-OUT, OFFICERS
# [46] GUTENBERG LITERARY ARCHIVE FOUNDATION, SALT LAKE CITY, INTERNAL REVENUE
#      SERVICE, MISSISSIPPI
# [47] DEATH, DECEASED MAN, HAMLET'S FATHER
# [48] BOYS, MARKET-TOWN, FARMERS
# [49] SULTAN'S GROOM, PRINCESS, GENII
# [50] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [51] ELECTRONIC WORKS, DERIVATIVE WORKS, FREE ACCESS
# [52] GENTLEMEN, POPULATION
# [53] GATEWAY, FOG AND FROST
# [54] VALENTINE, ORSON
# [55] SISTERS, GUESTS
# [56] WINDOWS, HOUSE-FRONTS
# [57] CHAMBERS, OFFICES
# [58] MEAGRE SERVANT, POSTBOY

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition2_4 = la.find_partition(igraph, la.RBConfigurationVertexPartition,resolution_parameter=10.0)
modularity_score_igraph2_4 = igraph.modularity(partition2_4)  
print(f"Modularity Score from RBConfigurationVertexPartition: {modularity_score_igraph2_4}")
# Out:
# Modularity Score from RBConfigurationVertexPartition: 0.46601738820666305

# %%
print(partition2_4)
# Out:
# Clustering with 610 elements and 180 clusters
# [  0] CHRISTMAS, POULTERERS, TAILOR, RAGGED MEN, BERRIES, IVY, THRONE, RED
#       BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES,
#       OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH
# [  1] FEZZIWIG, DICK, MRS. FEZZIWIG, WELSH WIG, EBENEZER, DANCE, COLD ROAST,
#       COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY,
#       DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL
# [  2] SPIRIT, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS, CHRISTMAS
#       HOLIDAYS, PAST, FUTURE, ALMSHOUSE, HOSPITAL, GAOL, IGNORANCE, WANT,
#       WORKHOUSES, MYSTERY
# [  3] PROJECT GUTENBERG, FULL LICENSE, TERMS OF THIS AGREEMENT, WORLD,
#       COPYRIGHT HOLDER, USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII,
#       COPYRIGHT, ROYALTY FEE, AGREEMENT, MICHAEL S. HART, EBOOK, VOLUNTEER,
#       DONATION
# [  4] GROCERS, CUSTOMERS, GROCER, FISH, ALMONDS, CINNAMON, RAISINS, TEA,
#       COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [  5] MISTLETOE, FRUITERERS, NORFOLK BIFFINS, SPANISH ONIONS, SHOPKEEPERS,
#       PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS,
#       VEGETABLES
# [  6] MARLEY, FIREPLACE, STAVE ONE, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF
#       MOURNER, BURIAL REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, DARK
#       CELLAR, DUTCH MERCHANT
# [  7] GHOST, DICK WILKINS, NIGHT, HAPPINESS, THREE SPIRITS, TWELVE, STAVE TWO,
#       BAKER'S, SURPLUS POPULATION, BLAZE, LAMPLIGHTER, TWELFTH-NIGHT PARTY,
#       SPIRIT'S ROBE
# [  8] OLD JOE, CORPSE, SPOIL, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS,
#       BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [  9] SCROOGE'S NIECE, UNCLE SCROOGE, TOPPER, SCROOGE'S NEPHEW, SCROOGE'S
#       NIECE'S SISTERS, SCROOGE'S NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL,
#       GAME OF HOW, WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF
# [ 10] PARTY, GENTLEMAN, POOR LAW, BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN,
#       FESTIVE SEASON, FUND, COMPANY, GAMES, GREAT FAT MAN, RED-FACED GENTLEMAN
# [ 11] EBENEZER SCROOGE, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF
#       JACOB MARLEY, FEZZIWIG'S BALL, THE THREE SPIRITS, HAMLET, SCROOGE'S
#       HOUSE, MONEY-CHANGING HOLE, FIRST OF EXCHANGE, CHURCHYARD, GRAVE
# [ 12] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#       PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, GHOSTS, WOMAN
#       WITH INFANT
# [ 13] PROJECT GUTENBERG LICENSE, ELECTRONIC WORK, PARAGRAPH 1.F.3, REFUND,
#       PERSON, ENTITY, DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN
#       EXPLANATION, DEFECTIVE WORK, PHYSICAL MEDIUM
# [ 14] MASTER SCROOGE, HALL, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP,
#       YOUNG PEOPLE, DECANTER, BLOCK OF CAKE
# [ 15] PHANTOM, PORCH, ROOM, COLD, WINTER FIRE, BODY, TERRORS, STAVE FOUR,
#       GLOOM, GRAVES
# [ 16] CHILDREN, FAMILY, DEVILS, ANGELS, BROWN-PAPER PARCELS, MARRIED SISTERS,
#       BROTHERS, COUSINS, UNCLES, AUNTS
# [ 17] TOWN, LOW-BROWED SHOP, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS, RAGS,
#       BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 18] FIRE, BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO MEN, WATER, STORM-
#       BIRDS, SEA, CAVERN
# [ 19] CAROLINE, HUSBAND, DEBT, MOTHER, CHAOS, DINNER, DAUGHTER, LAMPLIGHT,
#       DESSERT
# [ 20] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#       YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#       TEAM, J. B. LIPPINCOTT COMPANY
# [ 21] CRATCHIT FAMILY, CHRISTMAS PUDDING, YOUNGEST CRATCHITS, SAGE AND ONION,
#       HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY TIM, COPPER
# [ 22] BOB CRATCHIT, TIM CRATCHIT, CLOSET DOOR, PETER, CRATCHIT'S HOUSE,
#       CRATCHIT'S WIFE, GIRLS, COAL-SCUTTLE
# [ 23] MOOR, FROST, OLD MAN, MINERS, CHEERFUL COMPANY, SETTING SUN, HUT,
#       CHRISTMAS SONG
# [ 24] WINTER BALL, DANCE EVENT, BAKER, MISS FEZZIWIG, YOUNG FOLLOWERS,
#       HOUSEMAID, COOK, MILKMAN
# [ 25] TINY TIM, CHRISTMAS DAY, CRATCHITS, PUDDING, CHIMNEY CORNER, SPIRITS,
#       TOTAL-ABSTINENCE PRINCIPLE, GLOBE
# [ 26] GREAT BRITAIN, PEOPLE, CHESTNUTS, CLIMATE, SNOWBALL FIGHT, POULTERERS'
#       SHOPS, WICKER BASKETS, DINNERS
# [ 27] CHILD, WOMAN, MAN, CONTRACT, ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT
# [ 28] YOUNG CRATCHITS, BOB, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S
#       NEPHEW, GOOD WIFE, NINE O'CLOCK
# [ 29] MIST, STREETS, DARKNESS, WINTER DAY, FOG, FLOGGING LINKS, CARTS AND
#       WAGONS
# [ 30] DINING-ROOM, NEPHEW, YES AND NO, GIRL, ANIMAL, MISTRESS, YOUNG
#       HOUSEKEEPERS
# [ 31] SELF, CHURCH, CLOCK, BED, UNKNOWN, LIGHT, MULTITUDES
# [ 32] MERRY CHRISTMAS, MR. SCROOGE, THE CRATCHIT FAMILY, OFFICE, OLD
#       GENTLEMAN, GHOST OF CHRISTMAS, HAPPY END
# [ 33] PETER CRATCHIT, MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT,
#       CHRISTMAS DINNER, GOOSE, BELINDA
# [ 34] PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION, UNITED STATES,
#       WWW.GUTENBERG.ORG, ADDRESS, DONATIONS, U.S. FEDERAL LAWS, IRS
# [ 35] CHRISTMAS EVE, CORNHILL, CLERK, CANDLE, CAMDEN TOWN, MASTER, FIFTEEN
#       SHILLINGS
# [ 36] HOLLY, UNEARTHLY VISITOR, FIGURE, TUNIC, SUMMER FLOWERS, BELT
# [ 37] GHOST OF CHRISTMAS PAST, YOUNG GIRL, IDOL, COMELY MATRON, POVERTY,
#       WEALTH
# [ 38] COUNTING-HOUSE, CITY, CHANGE, MONEY, MERCHANTS, GOLD SEALS
# [ 39] COPYRIGHT LAW, FOUNDATION, TAX EXEMPT STATUS, PUBLIC DOMAIN, CHARITABLE
#       DONATIONS, COMPLIANCE REQUIREMENTS
# [ 40] FAN, FATHER, BOY, LITTLE FAN, POULTERER'S, COACH
# [ 41] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#       BLACK, SHOP, CHARCOAL STOVE
# [ 42] LAUGHTER, MRS. DILBER, LAUNDRESS, PARLOUR, CHARWOMAN, UNDERTAKER'S MAN
# [ 43] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [ 44] CHRISTMAS PARTY, MARTHA, HOLIDAY, MILLINER, COUNTESS, LORD
# [ 45] BELLE, MASTER OF THE HOUSE, HOUSE, SNOW, SNOWSTORMS
# [ 46] FRED, GOOD-HUMOUR, SISTER, MULLED WINE, BLIND MAN
# [ 47] SCOURGE, SPIRIT OF CHRISTMAS YET TO COME, CANDLES, COURT
# [ 48] HOLLY SPRIGS, ANCIENT TOWER, MAIN STREET, GAS-PIPES
# [ 49] GUTENBERG LITERARY ARCHIVE FOUNDATION, SALT LAKE CITY, INTERNAL REVENUE
#       SERVICE, MISSISSIPPI
# [ 50] JOE, OLD SCRATCH, BED-CURTAINS, FIRST WOMAN
# [ 51] SHIP, HELMSMAN, LOOK-OUT, OFFICERS
# [ 52] ELECTRONIC WORKS, DERIVATIVE WORKS, FREE ACCESS
# [ 53] JACOB MARLEY, CHAIN, SPECTRE
# [ 54] DEATH, DECEASED MAN, HAMLET'S FATHER
# [ 55] GHOST OF CHRISTMAS PRESENT, CRATCHIT HOUSE, PLUMP SISTER
# [ 56] LORD MAYOR, MANSION HOUSE, FIFTY COOKS AND BUTLERS
# [ 57] BOYS, MARKET-TOWN, FARMERS
# [ 58] SULTAN'S GROOM, PRINCESS, GENII
# [ 59] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [ 60] PORTER, FIDDLER
# [ 61] SCROOGE AND MARLEY, WAREHOUSE
# [ 62] HIGH DESK, STREET
# [ 63] GENTLEMEN, POPULATION
# [ 64] CHAMBERS, OFFICES
# [ 65] SISTERS, GUESTS
# [ 66] WINDOWS, HOUSE-FRONTS
# [ 67] GATEWAY, FOG AND FROST
# [ 68] VALENTINE, ORSON
# [ 69] MEAGRE SERVANT, POSTBOY
# [ 70] SCROOGE
# [ 71] PARTNERSHIP
# [ 72] WINTER WEATHER
# [ 73] UNCLE
# [ 74] WORLD OF FOOLS
# [ 75] HEART
# [ 76] PARLIAMENT
# [ 77] BEDLAM
# [ 78] UNION WORKHOUSES
# [ 79] TREADMILL
# [ 80] ST. DUNSTAN
# [ 81] HAT
# [ 82] TAVERN
# [ 83] DECEASED PARTNER
# [ 84] BANKER'S BOOK
# [ 85] CITY OF LONDON
# [ 86] KEY
# [ 87] WINE-MERCHANT
# [ 88] STAIRS
# [ 89] GRUEL
# [ 90] SITTING-ROOM
# [ 91] BEDROOM
# [ 92] LUMBER-ROOM
# [ 93] DRESSING-GOWN
# [ 94] SLIPPERS
# [ 95] CAINS
# [ 96] ABELS
# [ 97] PHARAOH'S DAUGHTERS
# [ 98] QUEENS OF SHEBA
# [ 99] ANGELIC MESSENGERS
# [100] ABRAHAMS
# [101] BELSHAZZARS
# [102] APOSTLES
# [103] BUTTER-BOATS
# [104] SENSES
# [105] BEEF
# [106] MUSTARD
# [107] CHEESE
# [108] POTATO
# [109] GRAVY
# [110] CHAIR
# [111] APPEARANCE
# [112] WARD
# [113] WISE MEN
# [114] POOR ABODE
# [115] CROWD
# [116] INVISIBLE WORLD
# [117] WINDOW
# [118] CHAMBER
# [119] TIME
# [120] THE VISITATION
# [121] THE CLOCK
# [122] THE CHIME
# [123] THE QUARTER
# [124] HOUR BELL
# [125] CURTAINS
# [126] WELFARE
# [127] BRIDGE
# [128] RIVER
# [129] MANSION
# [130] TRAVELLERS
# [131] HIGH-ROAD
# [132] LANE
# [133] MANSION OF DULL RED BRICK
# [134] ALI BABA
# [135] POPPLAR
# [136] DAMASCUS
# [137] ROBIN CRUSOE
# [138] FRIDAY
# [139] PARROT
# [140] CHRISTMAS CAROL
# [141] FAIR YOUNG GIRL
# [142] DOWERLESS GIRL
# [143] HEAVEN
# [144] BRAIDED HAIR
# [145] LITTLE SHOE
# [146] EXTINGUISHER-CAP
# [147] ONE
# [148] GHOSTLY LIGHT
# [149] TRANSFORMATION
# [150] GESE
# [151] PLUM-PUDDINGS
# [152] TWELFTH-CAKES
# [153] CITY STREETS
# [154] CHURCH AND CHAPEL
# [155] INCENSE
# [156] TORCH
# [157] POOR MAN'S CHILD
# [158] POOR CLERK
# [159] AROMATIC VINEGAR
# [160] MOLDY OLD OFFICE
# [161] DUSTY CHAMBERS
# [162] LONDON
# [163] BUSINESSMEN
# [164] SHADOW
# [165] HOUSES
# [166] FURNITURE
# [167] PRESENT
# [168] CHRISTMAS TIME
# [169] BEDPOST
# [170] WANDERING SPIRITS
# [171] LAOCOON
# [172] CHURCHES
# [173] CORNER
# [174] POULTERER
# [175] TURKEY
# [176] CAB
# [177] SCROOGE AND MARLEY'S
# [178] PORTLY GENTLEMAN
# [179] TANK

# %% [markdown]
# # When we increase the resolution_parameter, the modularity score will decrease and the number of clusters will increase. While we decrease the resolution_parameter under 1.0, the modularity score will also decrease but the number of clusters will decrease

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition2_5 = la.find_partition(igraph, la.RBConfigurationVertexPartition,resolution_parameter=0.5)
modularity_score_igraph2_5 = igraph.modularity(partition2_5)  
print(f"Modularity Score from RBConfigurationVertexPartition: {modularity_score_igraph2_5}")
# Out:
# Modularity Score from RBConfigurationVertexPartition: 0.637812488356517

# %%
print(partition2_5)
# Out:
# Clustering with 610 elements and 12 clusters
# [ 0] SCROOGE, FAN, MARLEY'S GHOST, BELL, PHANTOM, SHIP, SELF, DEATH, DINING-
#      ROOM, HOLLY, FATHER, BOY, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, NEPHEW, HAMLET'S
#      FATHER, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART,
#      PARLIAMENT, BEDLAM, GENTLEMEN, UNION WORKHOUSES, TREADMILL, CHURCH,
#      POPULATION, ANCIENT TOWER, ST. DUNSTAN, HAT, TAVERN, DECEASED PARTNER,
#      BANKER'S BOOK, CITY OF LONDON, GATEWAY, CHAMBERS, KEY, WINE-MERCHANT,
#      STAIRS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-ROOM, DRESSING-GOWN,
#      SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS OF SHEBA, ANGELIC
#      MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-BOATS, ROOM, SENSES,
#      BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE, WARD, WISE MEN,
#      POOR ABODE, CROWD, GHOSTS, INVISIBLE WORLD, WINDOW, CHAMBER, CLOCK, COLD,
#      TIME, THE VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL,
#      CURTAINS, BED, UNEARTHLY VISITOR, FIGURE, WELFARE, BRIDGE, RIVER,
#      MANSION, TRAVELLERS, HIGH-ROAD, LANE, MANSION OF DULL RED BRICK, ALI
#      BABA, POPPLAR, DAMASCUS, VALENTINE, ROBIN CRUSOE, FRIDAY, PARROT,
#      CHRISTMAS CAROL, LITTLE FAN, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN,
#      WINTER FIRE, BRAIDED HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY
#      LIGHT, TRANSFORMATION, GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS,
#      CHURCH AND CHAPEL, INCENSE, TORCH, POOR MAN'S CHILD, HELMSMAN, LOOK-OUT,
#      OFFICERS, POOR CLERK, AROMATIC VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS,
#      SISTERS, YES AND NO, LONDON, BUSINESSMEN, BODY, TERRORS, SHADOW, HOUSES,
#      FURNITURE, PRESENT, CHRISTMAS TIME, BEDPOST, WANDERING SPIRITS, LAOCOON,
#      CHURCHES, CORNER, POULTERER'S, POULTERER, TURKEY, CAB, SCROOGE AND
#      MARLEY'S, PORTLY GENTLEMAN, GIRL, TANK, STAVE FOUR, ANIMAL, MISTRESS,
#      MAIN STREET, GAS-PIPES, FOG AND FROST, OFFICES, UNKNOWN, LIGHT, GLOOM,
#      GRAVES, WOMAN WITH INFANT, TUNIC, SUMMER FLOWERS, BELT, COACH, ORSON,
#      GUESTS, YOUNG HOUSEKEEPERS
# [ 1] FRED, GHOST OF CHRISTMAS PRESENT, CHRISTMAS, SCROOGE'S NIECE, PARTY,
#      GOOD-HUMOUR, SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER,
#      SCROOGE'S NEPHEW, LORD MAYOR, MANSION HOUSE, POULTERERS, GROCERS, TAILOR,
#      RAGGED MEN, BOYS, HOLLY SPRIGS, BERRIES, PORTER, MISTLETOE, IVY, THRONE,
#      RED BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES,
#      OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, CUSTOMERS, GROCER, BAKERS' SHOPS,
#      GENTLEMAN, POOR LAW, MARKET-TOWN, SCROOGE'S NIECE'S SISTERS, BUSINESS
#      MEN, FUNERAL, MAN WITH LARGE CHIN, FRUITERERS, FESTIVE SEASON, FUND,
#      COMPANY, FIFTY COOKS AND BUTLERS, NORFOLK BIFFINS, FISH, ALMONDS,
#      CINNAMON, RAISINS, TEA, COFFEE, FARMERS, FIDDLER, SPANISH ONIONS,
#      SHOPKEEPERS, PEARS, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS,
#      VEGETABLES, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS,
#      SCROOGE'S NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW,
#      WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF, BLIND MAN, GAMES, GREAT FAT
#      MAN, RED-FACED GENTLEMAN
# [ 2] A CHRISTMAS CAROL, CHARLES DICKENS, EBENEZER SCROOGE, ARTHUR RACKHAM,
#      PHILADELPHIA, NEW YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE
#      DISTRIBUTED PROOFREADING TEAM, J. B. LIPPINCOTT COMPANY, GHOST, MR.
#      FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF JACOB MARLEY, DICK
#      WILKINS, CHRISTMAS EVE, FEZZIWIG'S BALL, JACOB MARLEY, THE THREE SPIRITS,
#      SCROOGE AND MARLEY, HAMLET, NIGHT, SCROOGE'S HOUSE, CHAIN, COUNTING-
#      HOUSE, MONEY-CHANGING HOLE, MARLEY, FIRST OF EXCHANGE, FEZZIWIG,
#      FIREPLACE, HAPPINESS, JACOB, THREE SPIRITS, TWELVE, STAVE TWO, DICK,
#      BAKER'S, SURPLUS POPULATION, BLAZE, LAMPLIGHTER, SPIRIT'S ROBE, PORCH,
#      MRS. FEZZIWIG, WAREHOUSE, WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT,
#      DANCE, COLD ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER
#      DE COVERLEY, DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, CLERK, STAVE
#      ONE, CANDLE, BAKER, CAMDEN TOWN, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF
#      MOURNER, BURIAL REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, MASTER,
#      FIFTEEN SHILLINGS, DARK CELLAR, DUTCH MERCHANT, MANKIND, CHARITY, MERCY,
#      FORBEARANCE, BENEVOLENCE, MISS FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID,
#      COOK, MILKMAN
# [ 3] GREAT BRITAIN, GHOST OF CHRISTMAS PAST, BELLE, SPIRIT, CHURCHYARD, GRAVE,
#      PEOPLE, MIST, SCOURGE, TWELFTH-NIGHT PARTY, CHILDREN, FAMILY, YOUNG GIRL,
#      IDOL, HIGH DESK, MASTER OF THE HOUSE, CITY, STREETS, MOOR, PRISONS,
#      DARKNESS, FROST, WINTER DAY, COUNTRY ROAD, FIELDS, HOUSE, COMELY MATRON,
#      MOTHER, CHAOS, CHESTNUTS, OLD MAN, CHRISTMAS HOLIDAYS, SPIRIT OF
#      CHRISTMAS YET TO COME, PAST, FUTURE, CANDLES, CHANGE, MONEY, MERCHANTS,
#      COURT, SNOW, CLIMATE, SNOWBALL FIGHT, POULTERERS' SHOPS, WICKER BASKETS,
#      DINNERS, FOG, FLOGGING LINKS, MINERS, CHEERFUL COMPANY, ALMSHOUSE,
#      HOSPITAL, GAOL, POVERTY, IGNORANCE, WANT, DEVILS, ANGELS, WORKHOUSES,
#      MYSTERY, STREET, SETTING SUN, WEALTH, DAUGHTER, BROWN-PAPER PARCELS,
#      MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS, SNOWSTORMS, CARTS AND
#      WAGONS, HUT, CHRISTMAS SONG, GOLD SEALS
# [ 4] BOB CRATCHIT, TINY TIM, SPECTRE, MERRY CHRISTMAS, CHILD, MR. SCROOGE,
#      PETER CRATCHIT, TIM CRATCHIT, MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA
#      CRATCHIT, CORNHILL, THE CRATCHIT FAMILY, CRATCHIT HOUSE, CRATCHIT FAMILY,
#      YOUNG CRATCHITS, CLOSET DOOR, CHRISTMAS DINNER, CHRISTMAS DAY, PETER,
#      CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS, OFFICE, COAL-SCUTTLE, GOOSE,
#      FIRE, BELINDA, CHRISTMAS PUDDING, BOB, CHRISTMAS PARTY, OLD GENTLEMAN,
#      BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO MEN, GHOST OF CHRISTMAS,
#      HAPPY END, APPLES, CRATCHITS, MARTHA, PUDDING, CHIMNEY CORNER, SPIRITS,
#      TOTAL-ABSTINENCE PRINCIPLE, GLOBE, YOUNGEST CRATCHITS, SAGE AND ONION,
#      HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY TIM, HOLIDAY, MILLINER,
#      COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW,
#      GOOD WIFE, NINE O'CLOCK, COPPER, WATER, STORM-BIRDS, SEA, CAVERN
# [ 5] TOWN, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, DINNER, CORPSE, SPOIL, CONTRACT, ASPIRATIONS, INDUSTRY,
#      BLANKETS, SHIRT, MULTITUDES, LAMPLIGHT, LOW-BROWED SHOP, INFAMOUS RESORT,
#      NARROW ALLEYS, ARCHWAYS, CHARWOMAN, UNDERTAKER'S MAN, DESSERT, RAGS,
#      BOTTLES, BONES, GREASY OFFAL, KEYS, GREY-HAIRED RASCAL, WOMAN WITH HEAVY
#      BUNDLE, SECOND WOMAN, MAN IN FADED BLACK, SHOP, CHARCOAL STOVE, BUNDLE,
#      SEAL, PENCIL-CASE, SLEEVE-BUTTONS, BROOCH, SHEETS, TOWELS, SILVER
#      TEASPOONS, SUGAR-TONGS, BOOTS
# [ 6] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 7] MASTER SCROOGE, HALL, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP,
#      YOUNG PEOPLE, DECANTER, BLOCK OF CAKE
# [ 8] SULTAN'S GROOM, PRINCESS, GENII
# [ 9] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [10] WINDOWS, HOUSE-FRONTS
# [11] MEAGRE SERVANT, POSTBOY

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition2_6 = la.find_partition(igraph, la.RBConfigurationVertexPartition,resolution_parameter=0.1)
modularity_score_igraph2_6 = igraph.modularity(partition2_6)  
print(f"Modularity Score from RBConfigurationVertexPartition: {modularity_score_igraph2_6}")
# Out:
# Modularity Score from RBConfigurationVertexPartition: 0.142837474702404

# %%
print(partition2_6)
# Out:
# Clustering with 610 elements and 8 clusters
# [0] A CHRISTMAS CAROL, CHARLES DICKENS, EBENEZER SCROOGE, ARTHUR RACKHAM,
#     PHILADELPHIA, NEW YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE
#     DISTRIBUTED PROOFREADING TEAM, J. B. LIPPINCOTT COMPANY, GHOST, GREAT
#     BRITAIN, SCROOGE, BOB CRATCHIT, MR. FEZZIWIG, FRED, GHOST OF CHRISTMAS
#     PAST, GHOST OF CHRISTMAS PRESENT, GHOST OF CHRISTMAS YET TO COME, GHOST OF
#     JACOB MARLEY, DICK WILKINS, BELLE, FAN, MARLEY'S GHOST, CHRISTMAS EVE,
#     FEZZIWIG'S BALL, JACOB MARLEY, THE THREE SPIRITS, CHRISTMAS, SCROOGE AND
#     MARLEY, HAMLET, NIGHT, SCROOGE'S HOUSE, CHAIN, COUNTING-HOUSE, MONEY-
#     CHANGING HOLE, MARLEY, BELL, FIRST OF EXCHANGE, FEZZIWIG, TINY TIM,
#     SPIRIT, CHURCHYARD, PHANTOM, GRAVE, PEOPLE, FIREPLACE, HAPPINESS, JACOB,
#     SPECTRE, THREE SPIRITS, TWELVE, STAVE TWO, MIST, MERRY CHRISTMAS, CHILD,
#     MASTER SCROOGE, DICK, MR. SCROOGE, BAKER'S, SURPLUS POPULATION, BLAZE,
#     LAMPLIGHTER, SCOURGE, SHIP, SCROOGE'S NIECE, PARTY, TWELFTH-NIGHT PARTY,
#     CHILDREN, SPIRIT'S ROBE, PORCH, TOWN, SELF, PETER CRATCHIT, TIM CRATCHIT,
#     MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, CORNHILL, THE CRATCHIT
#     FAMILY, CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR,
#     CHRISTMAS DINNER, CHRISTMAS DAY, PETER, DEATH, CRATCHIT'S HOUSE,
#     CRATCHIT'S WIFE, GIRLS, OFFICE, FAMILY, COAL-SCUTTLE, GOOSE, MRS.
#     FEZZIWIG, LAUGHTER, GOOD-HUMOUR, SISTER, MULLED WINE, DINING-ROOM, YOUNG
#     GIRL, IDOL, UNCLE SCROOGE, TOPPER, PLUMP SISTER, WAREHOUSE, HIGH DESK,
#     WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD ROAST, COLD
#     BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY, DOMESTIC
#     BALL, APPRENTICES, CHRISTMAS BALL, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN,
#     FIRST WOMAN, MASTER OF THE HOUSE, CAROLINE, HUSBAND, MAN, DEBT, FIRE,
#     BELINDA, CHRISTMAS PUDDING, HOLLY, BOB, MRS. DILBER, LAUNDRESS, PARLOUR,
#     DECEASED MAN, OLD JOE, FATHER, BOY, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE,
#     DOOR, PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CLERK,
#     NEPHEW, SCROOGE'S NEPHEW, LORD MAYOR, MANSION HOUSE, POULTERERS, GROCERS,
#     TAILOR, RAGGED MEN, BOYS, HOLLY SPRIGS, BERRIES, CITY, PORTER, MISTLETOE,
#     IVY, THRONE, RED BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT,
#     PIGS, SAUSAGES, OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, CUSTOMERS, GROCER,
#     BAKERS' SHOPS, STREETS, CHRISTMAS PARTY, MOOR, STAVE ONE, HAMLET'S FATHER,
#     PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART, PARLIAMENT,
#     BEDLAM, GENTLEMEN, GENTLEMAN, PRISONS, UNION WORKHOUSES, POOR LAW,
#     TREADMILL, CHURCH, POPULATION, ANCIENT TOWER, ST. DUNSTAN, CANDLE, HAT,
#     TAVERN, DECEASED PARTNER, BANKER'S BOOK, CITY OF LONDON, GATEWAY,
#     CHAMBERS, KEY, WINE-MERCHANT, HALL, STAIRS, DARKNESS, GRUEL, SITTING-ROOM,
#     BEDROOM, LUMBER-ROOM, DRESSING-GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S
#     DAUGHTERS, QUEENS OF SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS,
#     APOSTLES, BUTTER-BOATS, ROOM, SENSES, BEEF, MUSTARD, CHEESE, POTATO,
#     GRAVY, CHAIR, APPEARANCE, WARD, WISE MEN, POOR ABODE, CROWD, GHOSTS,
#     INVISIBLE WORLD, WINDOW, CHAMBER, CLOCK, FROST, COLD, TIME, THE
#     VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL, CURTAINS, BED,
#     UNEARTHLY VISITOR, FIGURE, WELFARE, WINTER DAY, COUNTRY ROAD, FIELDS,
#     MARKET-TOWN, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE, MANSION
#     OF DULL RED BRICK, ALI BABA, HOUSE, POPPLAR, DAMASCUS, VALENTINE, ROBIN
#     CRUSOE, FRIDAY, PARROT, CHRISTMAS CAROL, LITTLE FAN, FAIR YOUNG GIRL,
#     DOWERLESS GIRL, HEAVEN, COMELY MATRON, WINTER FIRE, MOTHER, CHAOS, BRAIDED
#     HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION,
#     GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CHESTNUTS, CITY STREETS, CHURCH AND
#     CHAPEL, BAKER, INCENSE, TORCH, DINNER, POOR MAN'S CHILD, OLD MAN,
#     HELMSMAN, LOOK-OUT, OFFICERS, SCROOGE'S NIECE'S SISTERS, POOR CLERK,
#     AROMATIC VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS, SISTERS, YES AND NO,
#     LONDON, CHRISTMAS HOLIDAYS, SPIRIT OF CHRISTMAS YET TO COME, BUSINESS MEN,
#     BUSINESSMEN, CORPSE, SPOIL, BODY, TERRORS, SHADOW, HOUSES, FURNITURE,
#     PAST, PRESENT, FUTURE, CHRISTMAS TIME, BEDPOST, WANDERING SPIRITS,
#     LAOCOON, CHURCHES, CORNER, POULTERER'S, POULTERER, CAMDEN TOWN, TURKEY,
#     KNOCKER, CAB, SCROOGE AND MARLEY'S, PORTLY GENTLEMAN, OLD GENTLEMAN, GIRL,
#     TANK, CONTRACT, ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, CLERGYMAN,
#     UNDERTAKER, CHIEF MOURNER, BURIAL REGISTER, FUNERAL, GHOSTLY SPECTACLES,
#     WAISTCOAT, PIGTAIL, MASTER, FIFTEEN SHILLINGS, STAVE FOUR, MAN WITH LARGE
#     CHIN, CANDLES, CHANGE, MONEY, MERCHANTS, COURT, SNOW, CLIMATE, SNOWBALL
#     FIGHT, POULTERERS' SHOPS, FRUITERERS, WICKER BASKETS, DINNERS, ANIMAL,
#     MISTRESS, FOG, FLOGGING LINKS, FESTIVE SEASON, FUND, COMPANY, MAIN STREET,
#     GAS-PIPES, BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO MEN, FIFTY COOKS
#     AND BUTLERS, NORFOLK BIFFINS, FISH, ALMONDS, CINNAMON, RAISINS, TEA,
#     COFFEE, FARMERS, FOG AND FROST, OFFICES, DARK CELLAR, ECHOES,
#     SCHOOLMASTER, DUTCH MERCHANT, UNKNOWN, LIGHT, MINERS, CHEERFUL COMPANY,
#     ALMSHOUSE, HOSPITAL, GAOL, POVERTY, IGNORANCE, WANT, DEVILS, ANGELS,
#     WORKHOUSES, MYSTERY, STREET, GLOOM, GRAVES, MANKIND, CHARITY, MERCY,
#     FORBEARANCE, BENEVOLENCE, WOMAN WITH INFANT, MULTITUDES, SETTING SUN,
#     TUNIC, SUMMER FLOWERS, BELT, COACH, ORSON, CHAIS, SCHOOL, GARDEN SWEEP,
#     YOUNG PEOPLE, DECANTER, BLOCK OF CAKE, MISS FEZZIWIG, YOUNG FOLLOWERS,
#     HOUSEMAID, COOK, MILKMAN, FIDDLER, WEALTH, DAUGHTER, BROWN-PAPER PARCELS,
#     MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS, GHOST OF CHRISTMAS,
#     HAPPY END, SNOWSTORMS, CARTS AND WAGONS, SPANISH ONIONS, SHOPKEEPERS,
#     PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS,
#     VEGETABLES, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS,
#     CRATCHITS, LAMPLIGHT, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS, MARTHA,
#     PUDDING, CHIMNEY CORNER, SPIRITS, TOTAL-ABSTINENCE PRINCIPLE, GLOBE,
#     YOUNGEST CRATCHITS, SAGE AND ONION, HEARTH, CLOTH, FIRST PARTING, SPIRIT
#     OF TINY TIM, HOLIDAY, MILLINER, COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN
#     PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE, NINE O'CLOCK, COPPER, HUT,
#     CHRISTMAS SONG, WATER, STORM-BIRDS, SEA, CAVERN, SCROOGE'S NIECE'S SISTER,
#     HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND WHERE, CHARWOMAN,
#     UNDERTAKER'S MAN, MUSIC, BLIND MAN'S-BUFF, DESSERT, BLIND MAN, GAMES,
#     GUESTS, GOLD SEALS, GREAT FAT MAN, RED-FACED GENTLEMAN, BUNDLE, SEAL,
#     PENCIL-CASE, SLEEVE-BUTTONS, BROOCH, SHEETS, TOWELS, SILVER TEASPOONS,
#     SUGAR-TONGS, BOOTS, YOUNG HOUSEKEEPERS
# [1] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#     FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#     WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK, USER,
#     GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE, COPYRIGHT
#     LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY ARCHIVE
#     FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#     DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#     U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#     DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#     DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#     REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [2] LOW-BROWED SHOP, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [3] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#     BLACK, SHOP, CHARCOAL STOVE
# [4] SULTAN'S GROOM, PRINCESS, GENII
# [5] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [6] WINDOWS, HOUSE-FRONTS
# [7] MEAGRE SERVANT, POSTBOY

# %%
import matplotlib.pyplot as plt
import numpy as np
resolution2= list(np.linspace(0, 10, 1000))
modularity = []

for resolution in resolution2:
    partition = leidenalg.find_partition(igraph, la.RBConfigurationVertexPartition,
                                         resolution_parameter=resolution)
    modularity_score = igraph.modularity(partition)
    modularity.append(modularity_score)
    
plt.figure(figsize=(10, 6))
plt.plot(resolution2, modularity, marker='o')
plt.title('Modularity Score vs. Resolution Parameter')
plt.xlabel('Resolution Parameter')
plt.ylabel('Modularity Score')
plt.xlim(0, 10)  
plt.ylim(min(modularity), max(modularity)+0.1)  
plt.grid(True)
plt.show()

# %%
max_modularity = max(modularity)
max_index = modularity.index(max_modularity)
optimal_resolution = resolution2[max_index]

print(f"Optimal Resolution Parameter: {optimal_resolution}")
print(f"Maximum Modularity Score: {max_modularity}")
max_index
# Out:
# Optimal Resolution Parameter: 0.8408408408408409
# Maximum Modularity Score: 0.657676610617402
# 84

# %% [markdown]
# # RBConfigurationVertexPartition -- optimal 19 clusters

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition2_optimal = la.find_partition(igraph, la.RBConfigurationVertexPartition,
                                 resolution_parameter=0.8408408408408409)
modularity_score_igraph2_optimal = igraph.modularity(partition2_optimal)  
print(f"Modularity Score from RBConfigurationVertexPartition: {modularity_score_igraph2_optimal}")
print(partition2_optimal)
# Out:
# Modularity Score from RBConfigurationVertexPartition: 0.6561703415391298
# Clustering with 610 elements and 19 clusters
# [ 0] SCROOGE, SHIP, DINING-ROOM, HOLLY, NEPHEW, PARTNERSHIP, WINTER WEATHER,
#      UNCLE, WORLD OF FOOLS, HEART, PARLIAMENT, BEDLAM, GENTLEMEN, UNION
#      WORKHOUSES, TREADMILL, POPULATION, ST. DUNSTAN, HAT, TAVERN, DECEASED
#      PARTNER, BANKER'S BOOK, CITY OF LONDON, GATEWAY, CHAMBERS, KEY, WINE-
#      MERCHANT, STAIRS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-ROOM, DRESSING-
#      GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS OF SHEBA,
#      ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-BOATS,
#      SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE, WARD,
#      WISE MEN, POOR ABODE, CROWD, INVISIBLE WORLD, WINDOW, CHAMBER, TIME, THE
#      VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL, CURTAINS,
#      UNEARTHLY VISITOR, WELFARE, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-
#      ROAD, LANE, MANSION OF DULL RED BRICK, ALI BABA, POPPLAR, DAMASCUS,
#      VALENTINE, ROBIN CRUSOE, FRIDAY, PARROT, CHRISTMAS CAROL, FAIR YOUNG
#      GIRL, DOWERLESS GIRL, HEAVEN, BRAIDED HAIR, LITTLE SHOE, EXTINGUISHER-
#      CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION, GESE, PLUM-PUDDINGS, TWELFTH-
#      CAKES, CITY STREETS, CHURCH AND CHAPEL, INCENSE, TORCH, POOR MAN'S CHILD,
#      HELMSMAN, LOOK-OUT, OFFICERS, POOR CLERK, AROMATIC VINEGAR, MOLDY OLD
#      OFFICE, DUSTY CHAMBERS, SISTERS, YES AND NO, LONDON, BUSINESSMEN, SHADOW,
#      HOUSES, FURNITURE, PRESENT, CHRISTMAS TIME, BEDPOST, WANDERING SPIRITS,
#      LAOCOON, CHURCHES, CORNER, POULTERER, TURKEY, CAB, SCROOGE AND MARLEY'S,
#      PORTLY GENTLEMAN, GIRL, TANK, ANIMAL, MISTRESS, FOG AND FROST, OFFICES,
#      ORSON, GUESTS, YOUNG HOUSEKEEPERS
# [ 1] FAN, CHRISTMAS, MASTER SCROOGE, FATHER, BOY, LORD MAYOR, MANSION HOUSE,
#      POULTERERS, GROCERS, TAILOR, RAGGED MEN, BOYS, BERRIES, IVY, THRONE, RED
#      BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES,
#      OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, CUSTOMERS, GROCER, HALL, MARKET-
#      TOWN, LITTLE FAN, POULTERER'S, FIFTY COOKS AND BUTLERS, FISH, ALMONDS,
#      CINNAMON, RAISINS, TEA, COFFEE, FARMERS, ECHOES, SCHOOLMASTER, COACH,
#      CHAIS, SCHOOL, GARDEN SWEEP, YOUNG PEOPLE, DECANTER, BLOCK OF CAKE,
#      SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 2] BOB CRATCHIT, TINY TIM, CHILD, MR. SCROOGE, PETER CRATCHIT, TIM CRATCHIT,
#      MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, THE CRATCHIT FAMILY,
#      CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR, CHRISTMAS
#      DINNER, CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS,
#      OFFICE, COAL-SCUTTLE, GOOSE, FIRE, BELINDA, CHRISTMAS PUDDING, BOB,
#      CHRISTMAS PARTY, OLD GENTLEMAN, BRAZIER, RAGGED MEN AND BOYS, GHOST OF
#      CHRISTMAS, HAPPY END, CRATCHITS, MARTHA, PUDDING, CHIMNEY CORNER,
#      SPIRITS, TOTAL-ABSTINENCE PRINCIPLE, GLOBE, YOUNGEST CRATCHITS, SAGE AND
#      ONION, HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY TIM, HOLIDAY,
#      MILLINER, COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S
#      NEPHEW, GOOD WIFE, NINE O'CLOCK, COPPER
# [ 3] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 4] GHOST OF CHRISTMAS PAST, BELLE, SPIRIT, CHURCHYARD, GRAVE, TWELFTH-NIGHT
#      PARTY, CHILDREN, FAMILY, YOUNG GIRL, IDOL, MASTER OF THE HOUSE, BAKERS'
#      SHOPS, PRISONS, COUNTRY ROAD, FIELDS, COMELY MATRON, MOTHER, CHAOS, OLD
#      MAN, CHRISTMAS HOLIDAYS, PAST, FUTURE, MINERS, CHEERFUL COMPANY,
#      ALMSHOUSE, HOSPITAL, GAOL, POVERTY, IGNORANCE, WANT, DEVILS, ANGELS,
#      WORKHOUSES, MYSTERY, WEALTH, DAUGHTER, BROWN-PAPER PARCELS, MARRIED
#      SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS, HUT, CHRISTMAS SONG
# [ 5] A CHRISTMAS CAROL, CHARLES DICKENS, EBENEZER SCROOGE, ARTHUR RACKHAM,
#      PHILADELPHIA, NEW YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE
#      DISTRIBUTED PROOFREADING TEAM, J. B. LIPPINCOTT COMPANY, GHOST, GHOST OF
#      CHRISTMAS YET TO COME, GHOST OF JACOB MARLEY, DICK WILKINS, FEZZIWIG'S
#      BALL, JACOB MARLEY, THE THREE SPIRITS, HAMLET, NIGHT, SCROOGE'S HOUSE,
#      CHAIN, MONEY-CHANGING HOLE, FIRST OF EXCHANGE, HAPPINESS, JACOB, SPECTRE,
#      THREE SPIRITS, TWELVE, STAVE TWO, MERRY CHRISTMAS, BAKER'S, SURPLUS
#      POPULATION, BLAZE, LAMPLIGHTER, SCOURGE, SPIRIT'S ROBE, HOUSE, SPIRIT OF
#      CHRISTMAS YET TO COME, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [ 6] DEATH, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, DINNER, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, LAMPLIGHT, CHARWOMAN,
#      UNDERTAKER'S MAN, DESSERT, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS,
#      BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 7] GREAT BRITAIN, COUNTING-HOUSE, PEOPLE, MIST, CITY, MISTLETOE, STREETS,
#      DARKNESS, WINTER DAY, CHESTNUTS, CANDLES, CHANGE, MONEY, MERCHANTS,
#      COURT, SNOW, CLIMATE, SNOWBALL FIGHT, POULTERERS' SHOPS, FRUITERERS,
#      WICKER BASKETS, DINNERS, FOG, FLOGGING LINKS, NORFOLK BIFFINS,
#      SNOWSTORMS, CARTS AND WAGONS, SPANISH ONIONS, SHOPKEEPERS, PEARS, APPLES,
#      GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS, VEGETABLES, GOLD
#      SEALS
# [ 8] PHANTOM, PORCH, TOWN, SELF, HOLLY SPRIGS, ANCIENT TOWER, ROOM, CLOCK,
#      COLD, BED, FIGURE, WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN STREET,
#      GAS-PIPES, UNKNOWN, LIGHT, GLOOM, GRAVES, MULTITUDES, TUNIC, SUMMER
#      FLOWERS, BELT, LOW-BROWED SHOP, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS,
#      RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 9] FRED, GHOST OF CHRISTMAS PRESENT, SCROOGE'S NIECE, PARTY, GOOD-HUMOUR,
#      SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER, SCROOGE'S
#      NEPHEW, GENTLEMAN, POOR LAW, SCROOGE'S NIECE'S SISTERS, BUSINESS MEN,
#      FUNERAL, MAN WITH LARGE CHIN, FESTIVE SEASON, FUND, COMPANY, SCROOGE'S
#      NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND
#      WHERE, MUSIC, BLIND MAN'S-BUFF, BLIND MAN, GAMES, GREAT FAT MAN, RED-
#      FACED GENTLEMAN
# [10] MR. FEZZIWIG, CHRISTMAS EVE, FEZZIWIG, DICK, MRS. FEZZIWIG, WAREHOUSE,
#      HIGH DESK, WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD
#      ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY,
#      DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, PORTER, BAKER, STREET, MISS
#      FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID, COOK, MILKMAN, FIDDLER
# [11] SCROOGE AND MARLEY, MARLEY, FIREPLACE, CORNHILL, CLERK, STAVE ONE,
#      CANDLE, CAMDEN TOWN, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF MOURNER,
#      BURIAL REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, MASTER, FIFTEEN
#      SHILLINGS, DARK CELLAR, DUTCH MERCHANT
# [12] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CHURCH, GHOSTS,
#      WOMAN WITH INFANT
# [13] MOOR, FROST, LIGHTHOUSE, TWO MEN, SETTING SUN, WATER, STORM-BIRDS, SEA,
#      CAVERN
# [14] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [15] SULTAN'S GROOM, PRINCESS, GENII
# [16] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [17] WINDOWS, HOUSE-FRONTS
# [18] MEAGRE SERVANT, POSTBOY

# %% [markdown]
# # (3): RBERVertexPartition -- 25 clusters
# # optimal modularity score: 0.6527620385659411 & 26 clusters
# ## Implements Reichardt and Bornholdt’s Potts model with an Erdős-Rényi null model. This quality function is well-defined only for positive edge weights. This quality function uses a linear resolution parameter.

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition3 = la.find_partition(igraph, la.RBERVertexPartition,resolution_parameter=1.0)
modularity_score_igraph3 = igraph.modularity(partition3)  
print(f"Modularity Score from RBERVertexPartition: {modularity_score_igraph3}")
# Out:
# Modularity Score from RBERVertexPartition: 0.6524548778127246

# %%
print(partition3)
# Out:
# Clustering with 610 elements and 25 clusters
# [ 0] SCROOGE, SHIP, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART,
#      PARLIAMENT, BEDLAM, GENTLEMEN, UNION WORKHOUSES, TREADMILL, POPULATION,
#      ST. DUNSTAN, HAT, TAVERN, DECEASED PARTNER, BANKER'S BOOK, CITY OF
#      LONDON, KEY, WINE-MERCHANT, STAIRS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-
#      ROOM, DRESSING-GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS
#      OF SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-
#      BOATS, SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE,
#      WARD, WISE MEN, POOR ABODE, CROWD, INVISIBLE WORLD, WINDOW, CHAMBER,
#      TIME, THE VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL,
#      CURTAINS, WELFARE, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE,
#      MANSION OF DULL RED BRICK, ALI BABA, POPPLAR, DAMASCUS, ROBIN CRUSOE,
#      FRIDAY, PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN,
#      BRAIDED HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT,
#      TRANSFORMATION, GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH
#      AND CHAPEL, INCENSE, TORCH, POOR MAN'S CHILD, HELMSMAN, LOOK-OUT,
#      OFFICERS, POOR CLERK, AROMATIC VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS,
#      LONDON, BUSINESSMEN, SHADOW, HOUSES, FURNITURE, PRESENT, CHRISTMAS TIME,
#      BEDPOST, WANDERING SPIRITS, LAOCOON, CHURCHES, CORNER, POULTERER, TURKEY,
#      CAB, SCROOGE AND MARLEY'S, PORTLY GENTLEMAN, TANK
# [ 1] BOB CRATCHIT, TINY TIM, CHILD, MR. SCROOGE, PETER CRATCHIT, TIM CRATCHIT,
#      MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, THE CRATCHIT FAMILY,
#      CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR, CHRISTMAS
#      DINNER, CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS,
#      OFFICE, COAL-SCUTTLE, GOOSE, FIRE, BELINDA, CHRISTMAS PUDDING, BOB,
#      CHRISTMAS PARTY, OLD GENTLEMAN, BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE,
#      TWO MEN, GHOST OF CHRISTMAS, HAPPY END, CRATCHITS, MARTHA, PUDDING,
#      CHIMNEY CORNER, SPIRITS, TOTAL-ABSTINENCE PRINCIPLE, GLOBE, YOUNGEST
#      CRATCHITS, SAGE AND ONION, HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY
#      TIM, HOLIDAY, MILLINER, COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN PLACE,
#      MR. SCROOGE'S NEPHEW, GOOD WIFE, NINE O'CLOCK, COPPER, WATER, STORM-
#      BIRDS, SEA, CAVERN
# [ 2] A CHRISTMAS CAROL, CHARLES DICKENS, EBENEZER SCROOGE, ARTHUR RACKHAM,
#      PHILADELPHIA, NEW YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE
#      DISTRIBUTED PROOFREADING TEAM, J. B. LIPPINCOTT COMPANY, GHOST, MR.
#      FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF JACOB MARLEY, DICK
#      WILKINS, CHRISTMAS EVE, FEZZIWIG'S BALL, JACOB MARLEY, THE THREE SPIRITS,
#      SCROOGE AND MARLEY, HAMLET, NIGHT, SCROOGE'S HOUSE, CHAIN, MONEY-CHANGING
#      HOLE, FIRST OF EXCHANGE, FEZZIWIG, CHURCHYARD, HAPPINESS, SPECTRE, THREE
#      SPIRITS, TWELVE, STAVE TWO, MERRY CHRISTMAS, DICK, BAKER'S, SURPLUS
#      POPULATION, BLAZE, LAMPLIGHTER, SPIRIT'S ROBE, MRS. FEZZIWIG, WAREHOUSE,
#      WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD ROAST, COLD
#      BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY, DOMESTIC
#      BALL, APPRENTICES, CHRISTMAS BALL, BAKER, MISS FEZZIWIG, YOUNG FOLLOWERS,
#      HOUSEMAID, COOK, MILKMAN
# [ 3] GREAT BRITAIN, GHOST OF CHRISTMAS PAST, BELLE, SPIRIT, GRAVE, PEOPLE,
#      SCOURGE, TWELFTH-NIGHT PARTY, CHILDREN, FAMILY, YOUNG GIRL, IDOL, HIGH
#      DESK, MASTER OF THE HOUSE, MOOR, PRISONS, FROST, COUNTRY ROAD, FIELDS,
#      HOUSE, COMELY MATRON, MOTHER, CHAOS, OLD MAN, CHRISTMAS HOLIDAYS, SPIRIT
#      OF CHRISTMAS YET TO COME, PAST, FUTURE, COURT, SNOW, CLIMATE, SNOWBALL
#      FIGHT, WICKER BASKETS, DINNERS, MINERS, CHEERFUL COMPANY, ALMSHOUSE,
#      HOSPITAL, GAOL, POVERTY, IGNORANCE, WANT, DEVILS, ANGELS, WORKHOUSES,
#      MYSTERY, STREET, SETTING SUN, WEALTH, DAUGHTER, BROWN-PAPER PARCELS,
#      MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS, SNOWSTORMS, HUT,
#      CHRISTMAS SONG
# [ 4] FRED, GHOST OF CHRISTMAS PRESENT, CHRISTMAS, SCROOGE'S NIECE, PARTY,
#      GOOD-HUMOUR, SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER,
#      SCROOGE'S NEPHEW, LORD MAYOR, MANSION HOUSE, POULTERERS, TAILOR, RAGGED
#      MEN, BOYS, BERRIES, PORTER, IVY, THRONE, RED BERRIES, TURKEYS, GEESE,
#      GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES, OYSTERS, PIES, PUDDINGS,
#      FRUIT, PUNCH, BAKERS' SHOPS, MARKET-TOWN, SCROOGE'S NIECE'S SISTERS,
#      FIFTY COOKS AND BUTLERS, FARMERS, FIDDLER, SCROOGE'S NIECE'S SISTER,
#      HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND WHERE, MUSIC, BLIND
#      MAN'S-BUFF, BLIND MAN, GAMES
# [ 5] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 6] DEATH, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, DINNER, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, LAMPLIGHT, CHARWOMAN,
#      UNDERTAKER'S MAN, DESSERT, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS,
#      BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 7] PHANTOM, PORCH, TOWN, SELF, HOLLY SPRIGS, ANCIENT TOWER, ROOM, CLOCK,
#      COLD, BED, WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN STREET, GAS-
#      PIPES, UNKNOWN, GLOOM, GRAVES, MULTITUDES, LOW-BROWED SHOP, INFAMOUS
#      RESORT, NARROW ALLEYS, ARCHWAYS, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 8] FAN, MASTER SCROOGE, DINING-ROOM, FATHER, BOY, NEPHEW, HALL, LITTLE FAN,
#      YES AND NO, POULTERER'S, GIRL, ANIMAL, MISTRESS, ECHOES, SCHOOLMASTER,
#      COACH, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG PEOPLE, DECANTER, BLOCK OF
#      CAKE, YOUNG HOUSEKEEPERS
# [ 9] MARLEY, FIREPLACE, STAVE ONE, GENTLEMAN, POOR LAW, BUSINESS MEN, KNOCKER,
#      CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL REGISTER, FUNERAL, GHOSTLY
#      SPECTACLES, WAISTCOAT, PIGTAIL, MAN WITH LARGE CHIN, FESTIVE SEASON,
#      FUND, COMPANY, DARK CELLAR, DUTCH MERCHANT, GREAT FAT MAN, RED-FACED
#      GENTLEMAN
# [10] COUNTING-HOUSE, MIST, CORNHILL, CLERK, CITY, STREETS, CANDLE, DARKNESS,
#      WINTER DAY, CAMDEN TOWN, MASTER, FIFTEEN SHILLINGS, CANDLES, CHANGE,
#      MONEY, MERCHANTS, FOG, FLOGGING LINKS, CARTS AND WAGONS, GOLD SEALS
# [11] GROCERS, CUSTOMERS, GROCER, NORFOLK BIFFINS, FISH, ALMONDS, CINNAMON,
#      RAISINS, TEA, COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH
#      PLUMS
# [12] MISTLETOE, CHESTNUTS, POULTERERS' SHOPS, FRUITERERS, SPANISH ONIONS,
#      SHOPKEEPERS, PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS,
#      FRUITS, VEGETABLES
# [13] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CHURCH, GHOSTS,
#      WOMAN WITH INFANT
# [14] HOLLY, UNEARTHLY VISITOR, FIGURE, LIGHT, TUNIC, SUMMER FLOWERS, BELT
# [15] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [16] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [17] SULTAN'S GROOM, PRINCESS, GENII
# [18] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [19] CHAMBERS, OFFICES
# [20] VALENTINE, ORSON
# [21] WINDOWS, HOUSE-FRONTS
# [22] GATEWAY, FOG AND FROST
# [23] MEAGRE SERVANT, POSTBOY
# [24] SISTERS, GUESTS

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition3_2 = la.find_partition(igraph, la.RBERVertexPartition,resolution_parameter=5.0)
modularity_score_igraph3_2 = igraph.modularity(partition3_2)  
print(f"Modularity Score from RBERVertexPartition: {modularity_score_igraph3_2}")
# Out:
# Modularity Score from RBERVertexPartition: 0.551365365898432

# %%
print(partition3_2)
# Out:
# Clustering with 610 elements and 139 clusters
# [  0] BOB CRATCHIT, TINY TIM, CHILD, PETER CRATCHIT, TIM CRATCHIT, MRS.
#       CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, CRATCHIT HOUSE, CRATCHIT
#       FAMILY, YOUNG CRATCHITS, CHRISTMAS DINNER, CHRISTMAS DAY, PETER,
#       CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS, COAL-SCUTTLE, GOOSE, BELINDA,
#       CHRISTMAS PUDDING, BOB, CHRISTMAS PARTY, CRATCHITS, MARTHA, PUDDING,
#       TOTAL-ABSTINENCE PRINCIPLE, CLOTH, FIRST PARTING, MILLINER, COUNTESS,
#       LORD, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW
# [  1] SCROOGE, SHIP, HEART, TREADMILL, ST. DUNSTAN, DECEASED PARTNER, KEY,
#       WINE-MERCHANT, LUMBER-ROOM, SLIPPERS, APOSTLES, SENSES, MUSTARD, GRAVY,
#       CHAIR, APPEARANCE, WARD, CROWD, CHAMBER, TIME, MANSION, ALI BABA,
#       PARROT, GHOSTLY LIGHT, TRANSFORMATION, PLUM-PUDDINGS, CHURCH AND CHAPEL,
#       INCENSE, POOR MAN'S CHILD, HELMSMAN, LOOK-OUT, OFFICERS, LONDON,
#       LAOCOON, CHURCHES, POULTERER
# [  2] DEATH, LAUGHTER, WOMAN, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED MAN,
#       OLD JOE, HAMLET'S FATHER, CORPSE, SPOIL, BLANKETS, SHIRT, CHARWOMAN,
#       UNDERTAKER'S MAN, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS, BROOCH,
#       SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [  3] CHRISTMAS, LORD MAYOR, MANSION HOUSE, POULTERERS, TAILOR, RAGGED MEN,
#       BERRIES, IVY, THRONE, RED BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN,
#       MEAT, PIGS, SAUSAGES, OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, FIFTY COOKS
#       AND BUTLERS
# [  4] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#       FOUNDATION, TERMS OF THIS AGREEMENT, UNITED STATES, WORLD, COPYRIGHT
#       HOLDER, USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY
#       FEE, AGREEMENT, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#       DONATION, ADDRESS, DONATIONS, U.S. FEDERAL LAWS, IRS
# [  5] FRED, GHOST OF CHRISTMAS PRESENT, SCROOGE'S NIECE, PARTY, GOOD-HUMOUR,
#       MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER, SCROOGE'S NEPHEW,
#       SCROOGE'S NIECE'S SISTERS, SCROOGE'S NIECE'S SISTER, HARP, LARGE CHAIR,
#       FOOTSTOOL, GAME OF HOW, WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF, GAMES
# [  6] GHOST OF CHRISTMAS PAST, BELLE, CHILDREN, FAMILY, YOUNG GIRL, IDOL,
#       MASTER OF THE HOUSE, COMELY MATRON, POVERTY, DEVILS, ANGELS, WEALTH,
#       BROWN-PAPER PARCELS, MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS
# [  7] CHRISTMAS EVE, FEZZIWIG, DICK, MRS. FEZZIWIG, WELSH WIG, EBENEZER,
#       DANCE, COLD ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER
#       DE COVERLEY, DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, PORTER, FIDDLER
# [  8] TOWN, CAROLINE, HUSBAND, MAN, DEBT, MOTHER, CHAOS, DINNER, CONTRACT,
#       ASPIRATIONS, INDUSTRY, MULTITUDES, DAUGHTER, LAMPLIGHT, INFAMOUS RESORT,
#       NARROW ALLEYS, ARCHWAYS, DESSERT
# [  9] GHOST, JACOB MARLEY, CHAIN, HAPPINESS, SPECTRE, THREE SPIRITS, TWELVE,
#       STAVE TWO, BAKER'S, SURPLUS POPULATION, BLAZE, LAMPLIGHTER, SCOURGE,
#       TWELFTH-NIGHT PARTY, SPIRIT'S ROBE, PORCH, HOUSE, SPIRIT OF CHRISTMAS
#       YET TO COME
# [ 10] PHANTOM, SELF, HOLLY SPRIGS, ANCIENT TOWER, ROOM, CLOCK, COLD, BED,
#       WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN STREET, GAS-PIPES, UNKNOWN,
#       GLOOM, GRAVES
# [ 11] SPIRIT, HIGH DESK, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS,
#       CHRISTMAS HOLIDAYS, PAST, FUTURE, ALMSHOUSE, HOSPITAL, GAOL, IGNORANCE,
#       WANT, WORKHOUSES, MYSTERY, STREET
# [ 12] GROCERS, CUSTOMERS, GROCER, FISH, ALMONDS, CINNAMON, RAISINS, TEA,
#       COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 13] EBENEZER SCROOGE, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF
#       JACOB MARLEY, DICK WILKINS, FEZZIWIG'S BALL, THE THREE SPIRITS, HAMLET,
#       NIGHT, SCROOGE'S HOUSE, MONEY-CHANGING HOLE, FIRST OF EXCHANGE,
#       CHURCHYARD, GRAVE
# [ 14] MISTLETOE, FRUITERERS, NORFOLK BIFFINS, SPANISH ONIONS, SHOPKEEPERS,
#       PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS,
#       VEGETABLES
# [ 15] MARLEY, FIREPLACE, STAVE ONE, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF
#       MOURNER, BURIAL REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, DARK
#       CELLAR, DUTCH MERCHANT
# [ 16] MIST, CITY, DARKNESS, WINTER DAY, CANDLES, CHANGE, MONEY, MERCHANTS,
#       COURT, FOG, FLOGGING LINKS, GOLD SEALS
# [ 17] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#       PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CHURCH, GHOSTS,
#       WOMAN WITH INFANT
# [ 18] PEOPLE, STREETS, CHESTNUTS, SNOW, CLIMATE, SNOWBALL FIGHT, POULTERERS'
#       SHOPS, WICKER BASKETS, DINNERS, SNOWSTORMS, CARTS AND WAGONS
# [ 19] PROJECT GUTENBERG LICENSE, ELECTRONIC WORK, PARAGRAPH 1.F.3, REFUND,
#       PERSON, ENTITY, DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN
#       EXPLANATION, DEFECTIVE WORK, PHYSICAL MEDIUM
# [ 20] MASTER SCROOGE, HALL, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP,
#       YOUNG PEOPLE, DECANTER, BLOCK OF CAKE
# [ 21] GENTLEMAN, POOR LAW, BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN, FESTIVE
#       SEASON, FUND, COMPANY, GREAT FAT MAN, RED-FACED GENTLEMAN
# [ 22] SCROOGE AND MARLEY, WAREHOUSE, WINTER BALL, DANCE EVENT, BAKER, MISS
#       FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID, COOK, MILKMAN
# [ 23] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#       YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#       TEAM, J. B. LIPPINCOTT COMPANY, GREAT BRITAIN
# [ 24] FIRE, BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO MEN, WATER, STORM-
#       BIRDS, SEA, CAVERN
# [ 25] MOOR, FROST, OLD MAN, MINERS, CHEERFUL COMPANY, SETTING SUN, HUT,
#       CHRISTMAS SONG
# [ 26] DINING-ROOM, NEPHEW, YES AND NO, GIRL, ANIMAL, MISTRESS, YOUNG
#       HOUSEKEEPERS
# [ 27] HOLLY, UNEARTHLY VISITOR, FIGURE, LIGHT, TUNIC, SUMMER FLOWERS, BELT
# [ 28] MERRY CHRISTMAS, MR. SCROOGE, THE CRATCHIT FAMILY, OFFICE, OLD
#       GENTLEMAN, GHOST OF CHRISTMAS, HAPPY END
# [ 29] COUNTING-HOUSE, CORNHILL, CLERK, CANDLE, CAMDEN TOWN, MASTER, FIFTEEN
#       SHILLINGS
# [ 30] FAN, FATHER, BOY, LITTLE FAN, POULTERER'S, COACH
# [ 31] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#       BLACK, SHOP, CHARCOAL STOVE
# [ 32] COPYRIGHT LAW, FOUNDATION, TAX EXEMPT STATUS, PUBLIC DOMAIN, CHARITABLE
#       DONATIONS, COMPLIANCE REQUIREMENTS
# [ 33] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [ 34] LOW-BROWED SHOP, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 35] JOE, OLD SCRATCH, BED-CURTAINS, FIRST WOMAN
# [ 36] GUTENBERG LITERARY ARCHIVE FOUNDATION, SALT LAKE CITY, INTERNAL REVENUE
#       SERVICE, MISSISSIPPI
# [ 37] ELECTRONIC WORKS, DERIVATIVE WORKS, FREE ACCESS
# [ 38] BOYS, MARKET-TOWN, FARMERS
# [ 39] SULTAN'S GROOM, PRINCESS, GENII
# [ 40] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [ 41] SISTER, BLIND MAN
# [ 42] GENTLEMEN, POPULATION
# [ 43] WINDOWS, HOUSE-FRONTS
# [ 44] GATEWAY, FOG AND FROST
# [ 45] CHAMBERS, OFFICES
# [ 46] VALENTINE, ORSON
# [ 47] MEAGRE SERVANT, POSTBOY
# [ 48] SISTERS, GUESTS
# [ 49] BEEF
# [ 50] PARTNERSHIP
# [ 51] WINTER WEATHER
# [ 52] UNCLE
# [ 53] WORLD OF FOOLS
# [ 54] PARLIAMENT
# [ 55] BEDLAM
# [ 56] UNION WORKHOUSES
# [ 57] HAT
# [ 58] TAVERN
# [ 59] CITY OF LONDON
# [ 60] STAIRS
# [ 61] GRUEL
# [ 62] BEDROOM
# [ 63] DRESSING-GOWN
# [ 64] CAINS
# [ 65] ABELS
# [ 66] PHARAOH'S DAUGHTERS
# [ 67] QUEENS OF SHEBA
# [ 68] ANGELIC MESSENGERS
# [ 69] ABRAHAMS
# [ 70] BELSHAZZARS
# [ 71] BUTTER-BOATS
# [ 72] CHEESE
# [ 73] POTATO
# [ 74] WISE MEN
# [ 75] POOR ABODE
# [ 76] INVISIBLE WORLD
# [ 77] WINDOW
# [ 78] THE VISITATION
# [ 79] THE CLOCK
# [ 80] THE CHIME
# [ 81] THE QUARTER
# [ 82] HOUR BELL
# [ 83] CURTAINS
# [ 84] WELFARE
# [ 85] BRIDGE
# [ 86] TRAVELLERS
# [ 87] HIGH-ROAD
# [ 88] LANE
# [ 89] MANSION OF DULL RED BRICK
# [ 90] POPPLAR
# [ 91] DAMASCUS
# [ 92] ROBIN CRUSOE
# [ 93] FRIDAY
# [ 94] CHRISTMAS CAROL
# [ 95] FAIR YOUNG GIRL
# [ 96] DOWERLESS GIRL
# [ 97] HEAVEN
# [ 98] BRAIDED HAIR
# [ 99] LITTLE SHOE
# [100] EXTINGUISHER-CAP
# [101] ONE
# [102] GESE
# [103] TWELFTH-CAKES
# [104] CITY STREETS
# [105] TORCH
# [106] POOR CLERK
# [107] AROMATIC VINEGAR
# [108] MOLDY OLD OFFICE
# [109] DUSTY CHAMBERS
# [110] BUSINESSMEN
# [111] SHADOW
# [112] HOUSES
# [113] FURNITURE
# [114] PRESENT
# [115] CHRISTMAS TIME
# [116] BEDPOST
# [117] WANDERING SPIRITS
# [118] CORNER
# [119] TURKEY
# [120] CAB
# [121] SCROOGE AND MARLEY'S
# [122] PORTLY GENTLEMAN
# [123] TANK
# [124] BANKER'S BOOK
# [125] RIVER
# [126] SITTING-ROOM
# [127] COPPER
# [128] NINE O'CLOCK
# [129] GOOD WIFE
# [130] YOUNGEST CRATCHITS
# [131] CLOSET DOOR
# [132] CHIMNEY CORNER
# [133] HEARTH
# [134] HOLIDAY
# [135] SPIRIT OF TINY TIM
# [136] GLOBE
# [137] SAGE AND ONION
# [138] SPIRITS

# %% [markdown]
# # The same pattern as the RBConfigurationVertexPartition when we change the resolution_parameter

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition3_3 = la.find_partition(igraph, la.RBERVertexPartition,resolution_parameter=0.5)
modularity_score_igraph3_3 = igraph.modularity(partition3_3)  
print(f"Modularity Score from RBERVertexPartition: {modularity_score_igraph3_3}")
# Out:
# Modularity Score from RBERVertexPartition: 0.5931156005856049

# %%
print(partition3_3)
# Out:
# Clustering with 610 elements and 21 clusters
# [ 0] EBENEZER SCROOGE, GHOST, SCROOGE, GHOST OF CHRISTMAS PAST, GHOST OF
#      CHRISTMAS YET TO COME, GHOST OF JACOB MARLEY, DICK WILKINS, BELLE, FAN,
#      MARLEY'S GHOST, CHRISTMAS EVE, FEZZIWIG'S BALL, JACOB MARLEY, THE THREE
#      SPIRITS, SCROOGE AND MARLEY, HAMLET, NIGHT, SCROOGE'S HOUSE, CHAIN,
#      COUNTING-HOUSE, MONEY-CHANGING HOLE, MARLEY, BELL, FIRST OF EXCHANGE,
#      SPIRIT, CHURCHYARD, PHANTOM, GRAVE, FIREPLACE, HAPPINESS, SPECTRE, THREE
#      SPIRITS, TWELVE, STAVE TWO, MIST, MERRY CHRISTMAS, BAKER'S, SURPLUS
#      POPULATION, BLAZE, LAMPLIGHTER, SCOURGE, SHIP, TWELFTH-NIGHT PARTY,
#      CHILDREN, SPIRIT'S ROBE, PORCH, TOWN, SELF, FAMILY, YOUNG GIRL, IDOL,
#      MASTER OF THE HOUSE, FATHER, BOY, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE,
#      DOOR, PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CLERK,
#      CITY, STAVE ONE, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS,
#      HEART, PARLIAMENT, BEDLAM, GENTLEMEN, PRISONS, UNION WORKHOUSES,
#      TREADMILL, CHURCH, POPULATION, ANCIENT TOWER, ST. DUNSTAN, CANDLE, HAT,
#      TAVERN, DECEASED PARTNER, BANKER'S BOOK, CITY OF LONDON, KEY, WINE-
#      MERCHANT, STAIRS, DARKNESS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-ROOM,
#      DRESSING-GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS OF
#      SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-BOATS,
#      ROOM, SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE,
#      WARD, WISE MEN, POOR ABODE, CROWD, GHOSTS, INVISIBLE WORLD, WINDOW,
#      CHAMBER, CLOCK, COLD, TIME, THE VISITATION, THE CLOCK, THE CHIME, THE
#      QUARTER, HOUR BELL, CURTAINS, BED, WELFARE, WINTER DAY, COUNTRY ROAD,
#      FIELDS, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE, MANSION OF
#      DULL RED BRICK, ALI BABA, HOUSE, POPPLAR, DAMASCUS, ROBIN CRUSOE, FRIDAY,
#      PARROT, CHRISTMAS CAROL, LITTLE FAN, FAIR YOUNG GIRL, DOWERLESS GIRL,
#      HEAVEN, COMELY MATRON, WINTER FIRE, MOTHER, CHAOS, BRAIDED HAIR, LITTLE
#      SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION, GESE, PLUM-
#      PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH AND CHAPEL, INCENSE, TORCH,
#      POOR MAN'S CHILD, HELMSMAN, LOOK-OUT, OFFICERS, POOR CLERK, AROMATIC
#      VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS, LONDON, CHRISTMAS HOLIDAYS,
#      SPIRIT OF CHRISTMAS YET TO COME, BUSINESSMEN, BODY, TERRORS, SHADOW,
#      HOUSES, FURNITURE, PAST, PRESENT, FUTURE, CHRISTMAS TIME, BEDPOST,
#      WANDERING SPIRITS, LAOCOON, CHURCHES, CORNER, POULTERER'S, POULTERER,
#      CAMDEN TOWN, TURKEY, KNOCKER, CAB, SCROOGE AND MARLEY'S, PORTLY
#      GENTLEMAN, TANK, CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL REGISTER,
#      GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, MASTER, FIFTEEN SHILLINGS, STAVE
#      FOUR, CANDLES, CHANGE, COURT, FOG, FLOGGING LINKS, MAIN STREET, GAS-
#      PIPES, DARK CELLAR, DUTCH MERCHANT, UNKNOWN, LIGHT, ALMSHOUSE, HOSPITAL,
#      GAOL, POVERTY, IGNORANCE, WANT, DEVILS, ANGELS, WORKHOUSES, MYSTERY,
#      GLOOM, GRAVES, WOMAN WITH INFANT, MULTITUDES, COACH, WEALTH, DAUGHTER,
#      BROWN-PAPER PARCELS, MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS,
#      INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS
# [ 1] FRED, GHOST OF CHRISTMAS PRESENT, CHRISTMAS, SCROOGE'S NIECE, PARTY,
#      GOOD-HUMOUR, SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER,
#      SCROOGE'S NEPHEW, LORD MAYOR, MANSION HOUSE, POULTERERS, GROCERS, TAILOR,
#      RAGGED MEN, BOYS, HOLLY SPRIGS, BERRIES, IVY, THRONE, RED BERRIES,
#      TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES, OYSTERS,
#      PIES, PUDDINGS, FRUIT, PUNCH, CUSTOMERS, GROCER, BAKERS' SHOPS,
#      GENTLEMAN, POOR LAW, MARKET-TOWN, SCROOGE'S NIECE'S SISTERS, BUSINESS
#      MEN, FUNERAL, MAN WITH LARGE CHIN, FESTIVE SEASON, FUND, COMPANY, FIFTY
#      COOKS AND BUTLERS, FISH, ALMONDS, CINNAMON, RAISINS, TEA, COFFEE,
#      FARMERS, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS, SCROOGE'S
#      NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND
#      WHERE, MUSIC, BLIND MAN'S-BUFF, BLIND MAN, GAMES, GREAT FAT MAN, RED-
#      FACED GENTLEMAN
# [ 2] BOB CRATCHIT, TINY TIM, CHILD, MR. SCROOGE, PETER CRATCHIT, TIM CRATCHIT,
#      MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, CORNHILL, THE CRATCHIT
#      FAMILY, CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR,
#      CHRISTMAS DINNER, CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S
#      WIFE, GIRLS, OFFICE, COAL-SCUTTLE, GOOSE, FIRE, BELINDA, CHRISTMAS
#      PUDDING, BOB, CHRISTMAS PARTY, OLD GENTLEMAN, BRAZIER, RAGGED MEN AND
#      BOYS, LIGHTHOUSE, TWO MEN, GHOST OF CHRISTMAS, HAPPY END, CRATCHITS,
#      MARTHA, PUDDING, CHIMNEY CORNER, SPIRITS, TOTAL-ABSTINENCE PRINCIPLE,
#      GLOBE, YOUNGEST CRATCHITS, SAGE AND ONION, HEARTH, CLOTH, FIRST PARTING,
#      SPIRIT OF TINY TIM, HOLIDAY, MILLINER, COUNTESS, LORD, WASH-HOUSE,
#      SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE, NINE O'CLOCK,
#      COPPER, WATER, STORM-BIRDS, SEA, CAVERN
# [ 3] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 4] DEATH, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, DINNER, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, LAMPLIGHT, CHARWOMAN,
#      UNDERTAKER'S MAN, DESSERT, GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE,
#      SECOND WOMAN, MAN IN FADED BLACK, SHOP, CHARCOAL STOVE, BUNDLE, SEAL,
#      PENCIL-CASE, SLEEVE-BUTTONS, BROOCH, SHEETS, TOWELS, SILVER TEASPOONS,
#      SUGAR-TONGS, BOOTS
# [ 5] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#      YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#      TEAM, J. B. LIPPINCOTT COMPANY, GREAT BRITAIN, PEOPLE, MISTLETOE,
#      STREETS, CHESTNUTS, SNOW, CLIMATE, SNOWBALL FIGHT, POULTERERS' SHOPS,
#      FRUITERERS, WICKER BASKETS, DINNERS, NORFOLK BIFFINS, SNOWSTORMS, CARTS
#      AND WAGONS, SPANISH ONIONS, SHOPKEEPERS, PEARS, APPLES, GRAPES, FILBERTS,
#      ORANGES, LEMONS, BASKETS, FRUITS, VEGETABLES
# [ 6] MR. FEZZIWIG, FEZZIWIG, DICK, MRS. FEZZIWIG, WAREHOUSE, HIGH DESK, WELSH
#      WIG, EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD ROAST, COLD BOILED,
#      MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY, DOMESTIC BALL,
#      APPRENTICES, CHRISTMAS BALL, PORTER, BAKER, STREET, MISS FEZZIWIG, YOUNG
#      FOLLOWERS, HOUSEMAID, COOK, MILKMAN, FIDDLER
# [ 7] MASTER SCROOGE, DINING-ROOM, NEPHEW, HALL, YES AND NO, GIRL, ANIMAL,
#      MISTRESS, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG
#      PEOPLE, DECANTER, BLOCK OF CAKE, YOUNG HOUSEKEEPERS
# [ 8] MOOR, FROST, OLD MAN, MINERS, CHEERFUL COMPANY, SETTING SUN, HUT,
#      CHRISTMAS SONG
# [ 9] HOLLY, UNEARTHLY VISITOR, FIGURE, TUNIC, SUMMER FLOWERS, BELT
# [10] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [11] LOW-BROWED SHOP, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [12] SULTAN'S GROOM, PRINCESS, GENII
# [13] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [14] MONEY, MERCHANTS, GOLD SEALS
# [15] WINDOWS, HOUSE-FRONTS
# [16] MEAGRE SERVANT, POSTBOY
# [17] CHAMBERS, OFFICES
# [18] VALENTINE, ORSON
# [19] GATEWAY, FOG AND FROST
# [20] SISTERS, GUESTS

# %%
import matplotlib.pyplot as plt
import numpy as np
resolution2= list(np.linspace(0, 10, 1000))
modularity2 = []

for resolution in resolution2:
    partition = leidenalg.find_partition(igraph, la.RBERVertexPartition,
                                         resolution_parameter=resolution)
    modularity_score = igraph.modularity(partition)
    modularity2.append(modularity_score)
    
plt.figure(figsize=(10, 6))
plt.plot(resolution2, modularity2, marker='o')
plt.title('Modularity Score vs. Resolution Parameter')
plt.xlabel('Resolution Parameter')
plt.ylabel('Modularity Score')
plt.xlim(0, 10)  
plt.ylim(min(modularity), max(modularity)+0.1)  
plt.grid(True)
plt.show()

# %%
max_modularity2 = max(modularity2)
max_index2 = modularity2.index(max_modularity2)
optimal_resolution2 = resolution2[max_index2]

print(f"Optimal Resolution Parameter: {optimal_resolution2}")
print(f"Maximum Modularity Score: {max_modularity2}")
# Out:
# Optimal Resolution Parameter: 1.0410410410410411
# Maximum Modularity Score: 0.6544636909635668

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition3_optimal = la.find_partition(igraph, la.RBERVertexPartition,resolution_parameter=1.0410410410410411)
modularity_score_igraph3_optimal = igraph.modularity(partition3_optimal)  
print(f"Modularity Score from optimal RBERVertexPartition: {modularity_score_igraph3_optimal}")
# Out:
# Modularity Score from optimal RBERVertexPartition: 0.6527620385659411

# %%
print(partition3_optimal)
# Out:
# Clustering with 610 elements and 26 clusters
# [ 0] SCROOGE, SHIP, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART,
#      PARLIAMENT, BEDLAM, GENTLEMEN, UNION WORKHOUSES, TREADMILL, POPULATION,
#      ST. DUNSTAN, HAT, TAVERN, DECEASED PARTNER, BANKER'S BOOK, CITY OF
#      LONDON, KEY, WINE-MERCHANT, STAIRS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-
#      ROOM, DRESSING-GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS
#      OF SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-
#      BOATS, SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE,
#      WARD, WISE MEN, POOR ABODE, CROWD, INVISIBLE WORLD, WINDOW, CHAMBER,
#      TIME, THE VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL,
#      CURTAINS, WELFARE, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE,
#      MANSION OF DULL RED BRICK, ALI BABA, POPPLAR, DAMASCUS, ROBIN CRUSOE,
#      FRIDAY, PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN,
#      BRAIDED HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT,
#      TRANSFORMATION, GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH
#      AND CHAPEL, INCENSE, TORCH, POOR MAN'S CHILD, HELMSMAN, LOOK-OUT,
#      OFFICERS, POOR CLERK, AROMATIC VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS,
#      LONDON, BUSINESSMEN, SHADOW, HOUSES, FURNITURE, PRESENT, CHRISTMAS TIME,
#      BEDPOST, WANDERING SPIRITS, LAOCOON, CHURCHES, CORNER, POULTERER, TURKEY,
#      CAB, SCROOGE AND MARLEY'S, PORTLY GENTLEMAN, TANK
# [ 1] A CHRISTMAS CAROL, CHARLES DICKENS, EBENEZER SCROOGE, ARTHUR RACKHAM,
#      PHILADELPHIA, NEW YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE
#      DISTRIBUTED PROOFREADING TEAM, J. B. LIPPINCOTT COMPANY, GHOST, GREAT
#      BRITAIN, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF JACOB
#      MARLEY, DICK WILKINS, CHRISTMAS EVE, FEZZIWIG'S BALL, JACOB MARLEY, THE
#      THREE SPIRITS, SCROOGE AND MARLEY, HAMLET, NIGHT, SCROOGE'S HOUSE, CHAIN,
#      MONEY-CHANGING HOLE, FIRST OF EXCHANGE, FEZZIWIG, HAPPINESS, THREE
#      SPIRITS, TWELVE, STAVE TWO, DICK, BAKER'S, SURPLUS POPULATION, BLAZE,
#      LAMPLIGHTER, SPIRIT'S ROBE, MRS. FEZZIWIG, WAREHOUSE, WELSH WIG,
#      EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD ROAST, COLD BOILED,
#      MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY, DOMESTIC BALL,
#      APPRENTICES, CHRISTMAS BALL, BAKER, MISS FEZZIWIG, YOUNG FOLLOWERS,
#      HOUSEMAID, COOK, MILKMAN
# [ 2] BOB CRATCHIT, TINY TIM, SPECTRE, MERRY CHRISTMAS, CHILD, MR. SCROOGE,
#      PETER CRATCHIT, TIM CRATCHIT, MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA
#      CRATCHIT, THE CRATCHIT FAMILY, CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG
#      CRATCHITS, CLOSET DOOR, CHRISTMAS DINNER, CHRISTMAS DAY, PETER,
#      CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS, OFFICE, COAL-SCUTTLE, GOOSE,
#      FIRE, BELINDA, CHRISTMAS PUDDING, BOB, CHRISTMAS PARTY, OLD GENTLEMAN,
#      BRAZIER, RAGGED MEN AND BOYS, GHOST OF CHRISTMAS, HAPPY END, CRATCHITS,
#      MARTHA, PUDDING, CHIMNEY CORNER, SPIRITS, TOTAL-ABSTINENCE PRINCIPLE,
#      GLOBE, YOUNGEST CRATCHITS, SAGE AND ONION, HEARTH, CLOTH, FIRST PARTING,
#      SPIRIT OF TINY TIM, HOLIDAY, MILLINER, COUNTESS, LORD, WASH-HOUSE,
#      SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE, NINE O'CLOCK,
#      COPPER
# [ 3] GHOST OF CHRISTMAS PAST, BELLE, SPIRIT, CHURCHYARD, GRAVE, TWELFTH-NIGHT
#      PARTY, CHILDREN, FAMILY, YOUNG GIRL, IDOL, HIGH DESK, MASTER OF THE
#      HOUSE, PORTER, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS, HOUSE,
#      COMELY MATRON, MOTHER, CHAOS, OLD MAN, CHRISTMAS HOLIDAYS, PAST, FUTURE,
#      MINERS, CHEERFUL COMPANY, ALMSHOUSE, HOSPITAL, GAOL, POVERTY, IGNORANCE,
#      WANT, DEVILS, ANGELS, WORKHOUSES, MYSTERY, STREET, FIDDLER, WEALTH,
#      DAUGHTER, BROWN-PAPER PARCELS, MARRIED SISTERS, BROTHERS, COUSINS,
#      UNCLES, AUNTS, HUT, CHRISTMAS SONG
# [ 4] FRED, GHOST OF CHRISTMAS PRESENT, CHRISTMAS, SCROOGE'S NIECE, PARTY,
#      GOOD-HUMOUR, SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER,
#      SCROOGE'S NEPHEW, LORD MAYOR, MANSION HOUSE, POULTERERS, TAILOR, RAGGED
#      MEN, BOYS, BERRIES, IVY, THRONE, RED BERRIES, TURKEYS, GEESE, GAME,
#      POULTRY, BRAWN, MEAT, PIGS, SAUSAGES, OYSTERS, PIES, PUDDINGS, FRUIT,
#      PUNCH, MARKET-TOWN, SCROOGE'S NIECE'S SISTERS, FIFTY COOKS AND BUTLERS,
#      FARMERS, SCROOGE'S NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF
#      HOW, WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF, BLIND MAN, GAMES
# [ 5] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 6] DEATH, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, DINNER, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, LAMPLIGHT, CHARWOMAN,
#      UNDERTAKER'S MAN, DESSERT, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS,
#      BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 7] PHANTOM, PORCH, TOWN, SELF, HOLLY SPRIGS, ANCIENT TOWER, ROOM, CLOCK,
#      COLD, BED, WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN STREET, GAS-
#      PIPES, UNKNOWN, GLOOM, GRAVES, MULTITUDES, LOW-BROWED SHOP, INFAMOUS
#      RESORT, NARROW ALLEYS, ARCHWAYS, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 8] FAN, MASTER SCROOGE, DINING-ROOM, FATHER, BOY, NEPHEW, HALL, LITTLE FAN,
#      YES AND NO, POULTERER'S, GIRL, ANIMAL, MISTRESS, ECHOES, SCHOOLMASTER,
#      COACH, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG PEOPLE, DECANTER, BLOCK OF
#      CAKE, YOUNG HOUSEKEEPERS
# [ 9] MARLEY, FIREPLACE, STAVE ONE, GENTLEMAN, POOR LAW, BUSINESS MEN, KNOCKER,
#      CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL REGISTER, FUNERAL, GHOSTLY
#      SPECTACLES, WAISTCOAT, PIGTAIL, MAN WITH LARGE CHIN, FESTIVE SEASON,
#      FUND, COMPANY, DARK CELLAR, DUTCH MERCHANT, GREAT FAT MAN, RED-FACED
#      GENTLEMAN
# [10] PEOPLE, MISTLETOE, CHESTNUTS, SNOW, CLIMATE, SNOWBALL FIGHT, POULTERERS'
#      SHOPS, FRUITERERS, WICKER BASKETS, DINNERS, SNOWSTORMS, SPANISH ONIONS,
#      SHOPKEEPERS, PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS,
#      FRUITS, VEGETABLES
# [11] COUNTING-HOUSE, MIST, CORNHILL, CLERK, CITY, STREETS, CANDLE, DARKNESS,
#      WINTER DAY, CAMDEN TOWN, MASTER, FIFTEEN SHILLINGS, CHANGE, MONEY,
#      MERCHANTS, FOG, FLOGGING LINKS, CARTS AND WAGONS, GOLD SEALS
# [12] GROCERS, CUSTOMERS, GROCER, NORFOLK BIFFINS, FISH, ALMONDS, CINNAMON,
#      RAISINS, TEA, COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH
#      PLUMS
# [13] SCOURGE, MOOR, FROST, SPIRIT OF CHRISTMAS YET TO COME, CANDLES, COURT,
#      LIGHTHOUSE, TWO MEN, SETTING SUN, WATER, STORM-BIRDS, SEA, CAVERN
# [14] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CHURCH, GHOSTS,
#      WOMAN WITH INFANT
# [15] HOLLY, UNEARTHLY VISITOR, FIGURE, LIGHT, TUNIC, SUMMER FLOWERS, BELT
# [16] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [17] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [18] SULTAN'S GROOM, PRINCESS, GENII
# [19] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [20] CHAMBERS, OFFICES
# [21] VALENTINE, ORSON
# [22] SISTERS, GUESTS
# [23] WINDOWS, HOUSE-FRONTS
# [24] GATEWAY, FOG AND FROST
# [25] MEAGRE SERVANT, POSTBOY

# %% [markdown]
# # (4): CPMVertexPartition Method
# # optimal modularity score:  0.6533204713554422 & 26 clusters
# ## Implements the Constant Potts Model (CPM). This quality function is well-defined for both positive and negative edge weights. This quality function uses a linear resolution parameter.

# %%
import leidenalg as la
import igraph as ig

igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition4 = la.find_partition(igraph, la.CPMVertexPartition,resolution_parameter=1)
modularity_score_igraph4 = igraph.modularity(partition4)  
print(f"Modularity Score from CPMVertexPartition: {modularity_score_igraph4}")
# Out:
# Modularity Score from CPMVertexPartition: -0.013834956529483163

# %%
print(partition4)
# Out:
# Clustering with 610 elements and 610 clusters
# [  0] PROJECT GUTENBERG
# [  1] A CHRISTMAS CAROL
# [  2] FULL LICENSE
# [  3] PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION
# [  4] ELECTRONIC WORKS
# [  5] TERMS OF THIS AGREEMENT
# [  6] UNITED STATES
# [  7] WORLD
# [  8] PROJECT GUTENBERG LICENSE
# [  9] COPYRIGHT HOLDER
# [ 10] ELECTRONIC WORK
# [ 11] USER
# [ 12] GUTENBERG LICENSE
# [ 13] PLAIN VANILLA ASCII
# [ 14] COPYRIGHT
# [ 15] ROYALTY FEE
# [ 16] COPYRIGHT LAW
# [ 17] PARAGRAPH 1.F.3
# [ 18] AGREEMENT
# [ 19] FOUNDATION
# [ 20] GUTENBERG LITERARY ARCHIVE FOUNDATION
# [ 21] MICHAEL S. HART
# [ 22] WWW.GUTENBERG.ORG
# [ 23] EBOOK
# [ 24] VOLUNTEER
# [ 25] DONATION
# [ 26] CHARLES DICKENS
# [ 27] EBENEZER SCROOGE
# [ 28] ARTHUR RACKHAM
# [ 29] PHILADELPHIA
# [ 30] NEW YORK
# [ 31] SUZANNE SHELL
# [ 32] JANET BLENKINSHIP
# [ 33] ONLINE DISTRIBUTED PROOFREADING TEAM
# [ 34] J. B. LIPPINCOTT COMPANY
# [ 35] GHOST
# [ 36] GREAT BRITAIN
# [ 37] SCROOGE
# [ 38] BOB CRATCHIT
# [ 39] MR. FEZZIWIG
# [ 40] FRED
# [ 41] GHOST OF CHRISTMAS PAST
# [ 42] GHOST OF CHRISTMAS PRESENT
# [ 43] GHOST OF CHRISTMAS YET TO COME
# [ 44] GHOST OF JACOB MARLEY
# [ 45] DICK WILKINS
# [ 46] BELLE
# [ 47] FAN
# [ 48] MARLEY'S GHOST
# [ 49] CHRISTMAS EVE
# [ 50] FEZZIWIG'S BALL
# [ 51] JACOB MARLEY
# [ 52] THE THREE SPIRITS
# [ 53] CHRISTMAS
# [ 54] SCROOGE AND MARLEY
# [ 55] HAMLET
# [ 56] NIGHT
# [ 57] SCROOGE'S HOUSE
# [ 58] CHAIN
# [ 59] COUNTING-HOUSE
# [ 60] MONEY-CHANGING HOLE
# [ 61] MARLEY
# [ 62] BELL
# [ 63] FIRST OF EXCHANGE
# [ 64] FEZZIWIG
# [ 65] TINY TIM
# [ 66] SPIRIT
# [ 67] CHURCHYARD
# [ 68] PHANTOM
# [ 69] GRAVE
# [ 70] PEOPLE
# [ 71] FIREPLACE
# [ 72] HAPPINESS
# [ 73] JACOB
# [ 74] SPECTRE
# [ 75] THREE SPIRITS
# [ 76] TWELVE
# [ 77] STAVE TWO
# [ 78] MIST
# [ 79] MERRY CHRISTMAS
# [ 80] CHILD
# [ 81] MASTER SCROOGE
# [ 82] DICK
# [ 83] MR. SCROOGE
# [ 84] BAKER'S
# [ 85] SURPLUS POPULATION
# [ 86] BLAZE
# [ 87] LAMPLIGHTER
# [ 88] SCOURGE
# [ 89] SHIP
# [ 90] SCROOGE'S NIECE
# [ 91] PARTY
# [ 92] TWELFTH-NIGHT PARTY
# [ 93] CHILDREN
# [ 94] SPIRIT'S ROBE
# [ 95] PORCH
# [ 96] TOWN
# [ 97] SELF
# [ 98] PETER CRATCHIT
# [ 99] TIM CRATCHIT
# [100] MRS. CRATCHIT
# [101] BELINDA CRATCHIT
# [102] MARTHA CRATCHIT
# [103] CORNHILL
# [104] THE CRATCHIT FAMILY
# [105] CRATCHIT HOUSE
# [106] CRATCHIT FAMILY
# [107] YOUNG CRATCHITS
# [108] CLOSET DOOR
# [109] CHRISTMAS DINNER
# [110] CHRISTMAS DAY
# [111] PETER
# [112] DEATH
# [113] CRATCHIT'S HOUSE
# [114] CRATCHIT'S WIFE
# [115] GIRLS
# [116] OFFICE
# [117] FAMILY
# [118] COAL-SCUTTLE
# [119] GOOSE
# [120] MRS. FEZZIWIG
# [121] LAUGHTER
# [122] GOOD-HUMOUR
# [123] SISTER
# [124] MULLED WINE
# [125] DINING-ROOM
# [126] YOUNG GIRL
# [127] IDOL
# [128] UNCLE SCROOGE
# [129] TOPPER
# [130] PLUMP SISTER
# [131] WAREHOUSE
# [132] HIGH DESK
# [133] WELSH WIG
# [134] EBENEZER
# [135] WINTER BALL
# [136] DANCE EVENT
# [137] DANCE
# [138] COLD ROAST
# [139] COLD BOILED
# [140] MINCE-PIES
# [141] BEER
# [142] FESTIVITIES
# [143] SIR ROGER DE COVERLEY
# [144] DOMESTIC BALL
# [145] APPRENTICES
# [146] CHRISTMAS BALL
# [147] JOE
# [148] OLD SCRATCH
# [149] BED-CURTAINS
# [150] WOMAN
# [151] FIRST WOMAN
# [152] MASTER OF THE HOUSE
# [153] CAROLINE
# [154] HUSBAND
# [155] MAN
# [156] DEBT
# [157] FIRE
# [158] BELINDA
# [159] CHRISTMAS PUDDING
# [160] HOLLY
# [161] BOB
# [162] MRS. DILBER
# [163] LAUNDRESS
# [164] PARLOUR
# [165] DECEASED MAN
# [166] OLD JOE
# [167] FATHER
# [168] BOY
# [169] WINE-MERCHANT'S CELLAR
# [170] HAUNTED HOUSE
# [171] DOOR
# [172] PHANTOMS
# [173] BLEAK, DARK NIGHT
# [174] GUILTY GOVERNMENTS
# [175] CHAINS
# [176] CLERK
# [177] NEPHEW
# [178] SCROOGE'S NEPHEW
# [179] LORD MAYOR
# [180] MANSION HOUSE
# [181] POULTERERS
# [182] GROCERS
# [183] TAILOR
# [184] RAGGED MEN
# [185] BOYS
# [186] HOLLY SPRIGS
# [187] BERRIES
# [188] CITY
# [189] PORTER
# [190] MISTLETOE
# [191] IVY
# [192] THRONE
# [193] RED BERRIES
# [194] TURKEYS
# [195] GEESE
# [196] GAME
# [197] POULTRY
# [198] BRAWN
# [199] MEAT
# [200] PIGS
# [201] SAUSAGES
# [202] OYSTERS
# [203] PIES
# [204] PUDDINGS
# [205] FRUIT
# [206] PUNCH
# [207] CUSTOMERS
# [208] GROCER
# [209] BAKERS' SHOPS
# [210] STREETS
# [211] CHRISTMAS PARTY
# [212] MOOR
# [213] STAVE ONE
# [214] HAMLET'S FATHER
# [215] PARTNERSHIP
# [216] WINTER WEATHER
# [217] UNCLE
# [218] WORLD OF FOOLS
# [219] HEART
# [220] PARLIAMENT
# [221] BEDLAM
# [222] GENTLEMEN
# [223] GENTLEMAN
# [224] PRISONS
# [225] UNION WORKHOUSES
# [226] POOR LAW
# [227] TREADMILL
# [228] CHURCH
# [229] POPULATION
# [230] ANCIENT TOWER
# [231] ST. DUNSTAN
# [232] CANDLE
# [233] HAT
# [234] TAVERN
# [235] DECEASED PARTNER
# [236] BANKER'S BOOK
# [237] CITY OF LONDON
# [238] GATEWAY
# [239] CHAMBERS
# [240] KEY
# [241] WINE-MERCHANT
# [242] HALL
# [243] STAIRS
# [244] DARKNESS
# [245] GRUEL
# [246] SITTING-ROOM
# [247] BEDROOM
# [248] LUMBER-ROOM
# [249] DRESSING-GOWN
# [250] SLIPPERS
# [251] CAINS
# [252] ABELS
# [253] PHARAOH'S DAUGHTERS
# [254] QUEENS OF SHEBA
# [255] ANGELIC MESSENGERS
# [256] ABRAHAMS
# [257] BELSHAZZARS
# [258] APOSTLES
# [259] BUTTER-BOATS
# [260] ROOM
# [261] SENSES
# [262] BEEF
# [263] MUSTARD
# [264] CHEESE
# [265] POTATO
# [266] GRAVY
# [267] CHAIR
# [268] APPEARANCE
# [269] WARD
# [270] WISE MEN
# [271] POOR ABODE
# [272] CROWD
# [273] GHOSTS
# [274] INVISIBLE WORLD
# [275] WINDOW
# [276] CHAMBER
# [277] CLOCK
# [278] FROST
# [279] COLD
# [280] TIME
# [281] THE VISITATION
# [282] THE CLOCK
# [283] THE CHIME
# [284] THE QUARTER
# [285] HOUR BELL
# [286] CURTAINS
# [287] BED
# [288] UNEARTHLY VISITOR
# [289] FIGURE
# [290] WELFARE
# [291] WINTER DAY
# [292] COUNTRY ROAD
# [293] FIELDS
# [294] MARKET-TOWN
# [295] BRIDGE
# [296] RIVER
# [297] MANSION
# [298] TRAVELLERS
# [299] HIGH-ROAD
# [300] LANE
# [301] MANSION OF DULL RED BRICK
# [302] ALI BABA
# [303] HOUSE
# [304] POPPLAR
# [305] DAMASCUS
# [306] VALENTINE
# [307] ROBIN CRUSOE
# [308] FRIDAY
# [309] PARROT
# [310] CHRISTMAS CAROL
# [311] LITTLE FAN
# [312] FAIR YOUNG GIRL
# [313] DOWERLESS GIRL
# [314] HEAVEN
# [315] COMELY MATRON
# [316] WINTER FIRE
# [317] MOTHER
# [318] CHAOS
# [319] BRAIDED HAIR
# [320] LITTLE SHOE
# [321] EXTINGUISHER-CAP
# [322] ONE
# [323] GHOSTLY LIGHT
# [324] TRANSFORMATION
# [325] GESE
# [326] PLUM-PUDDINGS
# [327] TWELFTH-CAKES
# [328] CHESTNUTS
# [329] CITY STREETS
# [330] CHURCH AND CHAPEL
# [331] BAKER
# [332] INCENSE
# [333] TORCH
# [334] DINNER
# [335] POOR MAN'S CHILD
# [336] OLD MAN
# [337] HELMSMAN
# [338] LOOK-OUT
# [339] OFFICERS
# [340] SCROOGE'S NIECE'S SISTERS
# [341] POOR CLERK
# [342] AROMATIC VINEGAR
# [343] MOLDY OLD OFFICE
# [344] DUSTY CHAMBERS
# [345] SISTERS
# [346] YES AND NO
# [347] LONDON
# [348] CHRISTMAS HOLIDAYS
# [349] SPIRIT OF CHRISTMAS YET TO COME
# [350] BUSINESS MEN
# [351] BUSINESSMEN
# [352] CORPSE
# [353] SPOIL
# [354] BODY
# [355] TERRORS
# [356] SHADOW
# [357] HOUSES
# [358] FURNITURE
# [359] PAST
# [360] PRESENT
# [361] FUTURE
# [362] CHRISTMAS TIME
# [363] BEDPOST
# [364] WANDERING SPIRITS
# [365] LAOCOON
# [366] CHURCHES
# [367] CORNER
# [368] POULTERER'S
# [369] POULTERER
# [370] ADDRESS
# [371] CAMDEN TOWN
# [372] TURKEY
# [373] KNOCKER
# [374] CAB
# [375] SCROOGE AND MARLEY'S
# [376] PORTLY GENTLEMAN
# [377] OLD GENTLEMAN
# [378] GIRL
# [379] TANK
# [380] CONTRACT
# [381] ASPIRATIONS
# [382] INDUSTRY
# [383] BLANKETS
# [384] SHIRT
# [385] CLERGYMAN
# [386] UNDERTAKER
# [387] CHIEF MOURNER
# [388] BURIAL REGISTER
# [389] FUNERAL
# [390] GHOSTLY SPECTACLES
# [391] WAISTCOAT
# [392] PIGTAIL
# [393] MASTER
# [394] FIFTEEN SHILLINGS
# [395] STAVE FOUR
# [396] MAN WITH LARGE CHIN
# [397] CANDLES
# [398] CHANGE
# [399] MONEY
# [400] MERCHANTS
# [401] COURT
# [402] SNOW
# [403] CLIMATE
# [404] SNOWBALL FIGHT
# [405] POULTERERS' SHOPS
# [406] FRUITERERS
# [407] WICKER BASKETS
# [408] DINNERS
# [409] ANIMAL
# [410] MISTRESS
# [411] WINDOWS
# [412] HOUSE-FRONTS
# [413] FOG
# [414] FLOGGING LINKS
# [415] FESTIVE SEASON
# [416] FUND
# [417] COMPANY
# [418] MAIN STREET
# [419] GAS-PIPES
# [420] BRAZIER
# [421] RAGGED MEN AND BOYS
# [422] LIGHTHOUSE
# [423] TWO MEN
# [424] FIFTY COOKS AND BUTLERS
# [425] NORFOLK BIFFINS
# [426] FISH
# [427] ALMONDS
# [428] CINNAMON
# [429] RAISINS
# [430] TEA
# [431] COFFEE
# [432] FARMERS
# [433] FOG AND FROST
# [434] OFFICES
# [435] DARK CELLAR
# [436] ECHOES
# [437] SCHOOLMASTER
# [438] DUTCH MERCHANT
# [439] UNKNOWN
# [440] LIGHT
# [441] MINERS
# [442] CHEERFUL COMPANY
# [443] ALMSHOUSE
# [444] HOSPITAL
# [445] GAOL
# [446] POVERTY
# [447] IGNORANCE
# [448] WANT
# [449] DEVILS
# [450] ANGELS
# [451] WORKHOUSES
# [452] MYSTERY
# [453] STREET
# [454] GLOOM
# [455] GRAVES
# [456] MANKIND
# [457] CHARITY
# [458] MERCY
# [459] FORBEARANCE
# [460] BENEVOLENCE
# [461] WOMAN WITH INFANT
# [462] MULTITUDES
# [463] SETTING SUN
# [464] TUNIC
# [465] SUMMER FLOWERS
# [466] BELT
# [467] COACH
# [468] SULTAN'S GROOM
# [469] PRINCESS
# [470] GENII
# [471] ORSON
# [472] CHAIS
# [473] SCHOOL
# [474] GARDEN SWEEP
# [475] YOUNG PEOPLE
# [476] DECANTER
# [477] BLOCK OF CAKE
# [478] MEAGRE SERVANT
# [479] POSTBOY
# [480] MISS FEZZIWIG
# [481] YOUNG FOLLOWERS
# [482] HOUSEMAID
# [483] COOK
# [484] MILKMAN
# [485] FIDDLER
# [486] WEALTH
# [487] DAUGHTER
# [488] BROWN-PAPER PARCELS
# [489] MARRIED SISTERS
# [490] BROTHERS
# [491] COUSINS
# [492] UNCLES
# [493] AUNTS
# [494] DOLL'S FRYING PAN
# [495] BABY
# [496] WOODEN PLATTER
# [497] GHOST OF CHRISTMAS
# [498] HAPPY END
# [499] SNOWSTORMS
# [500] CARTS AND WAGONS
# [501] SPANISH ONIONS
# [502] SHOPKEEPERS
# [503] PEARS
# [504] APPLES
# [505] GRAPES
# [506] FILBERTS
# [507] ORANGES
# [508] LEMONS
# [509] BASKETS
# [510] FRUITS
# [511] VEGETABLES
# [512] SPICES
# [513] CANISTERS
# [514] CANDIED FRUITS
# [515] FIGS
# [516] FRENCH PLUMS
# [517] CRATCHITS
# [518] LAMPLIGHT
# [519] LOW-BROWED SHOP
# [520] INFAMOUS RESORT
# [521] NARROW ALLEYS
# [522] ARCHWAYS
# [523] MARTHA
# [524] PUDDING
# [525] CHIMNEY CORNER
# [526] SPIRITS
# [527] TOTAL-ABSTINENCE PRINCIPLE
# [528] GLOBE
# [529] YOUNGEST CRATCHITS
# [530] SAGE AND ONION
# [531] HEARTH
# [532] CLOTH
# [533] FIRST PARTING
# [534] SPIRIT OF TINY TIM
# [535] HOLIDAY
# [536] MILLINER
# [537] COUNTESS
# [538] LORD
# [539] WASH-HOUSE
# [540] SUNDAY
# [541] GREEN PLACE
# [542] MR. SCROOGE'S NEPHEW
# [543] GOOD WIFE
# [544] NINE O'CLOCK
# [545] COPPER
# [546] HUT
# [547] CHRISTMAS SONG
# [548] WATER
# [549] STORM-BIRDS
# [550] SEA
# [551] CAVERN
# [552] SCROOGE'S NIECE'S SISTER
# [553] HARP
# [554] LARGE CHAIR
# [555] FOOTSTOOL
# [556] GAME OF HOW, WHEN, AND WHERE
# [557] CHARWOMAN
# [558] UNDERTAKER'S MAN
# [559] MUSIC
# [560] BLIND MAN'S-BUFF
# [561] DESSERT
# [562] BLIND MAN
# [563] GAMES
# [564] GUESTS
# [565] GOLD SEALS
# [566] GREAT FAT MAN
# [567] RED-FACED GENTLEMAN
# [568] RAGS
# [569] BOTTLES
# [570] BONES
# [571] GREASY OFFAL
# [572] KEYS
# [573] GREY-HAIRED RASCAL
# [574] WOMAN WITH HEAVY BUNDLE
# [575] SECOND WOMAN
# [576] MAN IN FADED BLACK
# [577] SHOP
# [578] CHARCOAL STOVE
# [579] BUNDLE
# [580] SEAL
# [581] PENCIL-CASE
# [582] SLEEVE-BUTTONS
# [583] BROOCH
# [584] SHEETS
# [585] TOWELS
# [586] SILVER TEASPOONS
# [587] SUGAR-TONGS
# [588] BOOTS
# [589] YOUNG HOUSEKEEPERS
# [590] DERIVATIVE WORKS
# [591] REFUND
# [592] PERSON
# [593] ENTITY
# [594] DONATIONS
# [595] U.S. FEDERAL LAWS
# [596] TAX EXEMPT STATUS
# [597] IRS
# [598] PUBLIC DOMAIN
# [599] FREE ACCESS
# [600] DEFECT IN ELECTRONIC WORK
# [601] REPLACEMENT COPY
# [602] WRITTEN EXPLANATION
# [603] DEFECTIVE WORK
# [604] PHYSICAL MEDIUM
# [605] CHARITABLE DONATIONS
# [606] COMPLIANCE REQUIREMENTS
# [607] SALT LAKE CITY
# [608] INTERNAL REVENUE SERVICE
# [609] MISSISSIPPI

# %%
import leidenalg as la
import igraph as ig

igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition4_2 = la.find_partition(igraph, la.CPMVertexPartition,resolution_parameter=0.1)
modularity_score_igraph4_2 = igraph.modularity(partition4_2)  
print(f"Modularity Score from CPMVertexPartition: {modularity_score_igraph4_2}")
# Out:
# Modularity Score from CPMVertexPartition: 0.44207429836941287

# %%
print(partition4_2)
# Out:
# Clustering with 610 elements and 229 clusters
# [  0] BOB CRATCHIT, TINY TIM, CHILD, PETER CRATCHIT, MRS. CRATCHIT, BELINDA
#       CRATCHIT, MARTHA CRATCHIT, THE CRATCHIT FAMILY, CRATCHIT HOUSE, CRATCHIT
#       FAMILY, YOUNG CRATCHITS, CHRISTMAS DINNER, CHRISTMAS DAY, PETER,
#       CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS, GOOSE, BELINDA, CHRISTMAS
#       PARTY, CRATCHITS
# [  1] WOMAN, CAROLINE, HUSBAND, MAN, DEBT, CORPSE, SPOIL, CONTRACT,
#       ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT
# [  2] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#       PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, GHOSTS, WOMAN
#       WITH INFANT
# [  3] MR. FEZZIWIG, CHRISTMAS EVE, FEZZIWIG, MRS. FEZZIWIG, HIGH DESK, COLD
#       ROAST, MINCE-PIES, FESTIVITIES, SIR ROGER DE COVERLEY, DOMESTIC BALL,
#       APPRENTICES
# [  4] SCROOGE, SHIP, WINE-MERCHANT, CHEESE, WISE MEN, HELMSMAN, LOOK-OUT,
#       OFFICERS, AROMATIC VINEGAR, SHADOW, CORNER
# [  5] GHOST, DICK WILKINS, JACOB MARLEY, NIGHT, CHAIN, SPECTRE, THREE SPIRITS,
#       STAVE TWO, BAKER'S, SURPLUS POPULATION, TWELFTH-NIGHT PARTY
# [  6] PROJECT GUTENBERG, FULL LICENSE, WORLD, USER, GUTENBERG LICENSE, PLAIN
#       VANILLA ASCII, COPYRIGHT, MICHAEL S. HART, EBOOK, VOLUNTEER, DONATION
# [  7] FRUITERERS, SPANISH ONIONS, SHOPKEEPERS, PEARS, APPLES, GRAPES, ORANGES,
#       LEMONS, BASKETS, FRUITS, VEGETABLES
# [  8] CHILDREN, FAMILY, WINTER FIRE, ANGELS, BROWN-PAPER PARCELS, MARRIED
#       SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS
# [  9] EBENEZER SCROOGE, GHOST OF CHRISTMAS YET TO COME, GHOST OF JACOB MARLEY,
#       FEZZIWIG'S BALL, THE THREE SPIRITS, HAMLET, SCROOGE'S HOUSE, MONEY-
#       CHANGING HOLE, FIRST OF EXCHANGE, GRAVE
# [ 10] CHRISTMAS, POULTERERS, TAILOR, RAGGED MEN, IVY, TURKEYS, POULTRY, FRUIT,
#       PUNCH, BAKERS' SHOPS
# [ 11] SPIRIT, PRISONS, COUNTRY ROAD, FIELDS, PAST, ALMSHOUSE, GAOL, DEVILS,
#       WORKHOUSES, STREET
# [ 12] OLD JOE, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS, BROOCH, TOWELS,
#       SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 13] PROJECT GUTENBERG LICENSE, ELECTRONIC WORK, REFUND, PERSON, ENTITY,
#       REPLACEMENT COPY, WRITTEN EXPLANATION, DEFECTIVE WORK, PHYSICAL MEDIUM
# [ 14] PHANTOM, PORCH, ROOM, COLD, BODY, TERRORS, STAVE FOUR, GLOOM, GRAVES
# [ 15] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#       YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#       TEAM, J. B. LIPPINCOTT COMPANY
# [ 16] MARLEY, STAVE ONE, CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL
#       REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL
# [ 17] GHOST OF CHRISTMAS PRESENT, PARTY, UNCLE SCROOGE, TOPPER, PLUMP SISTER,
#       MUSIC, BLIND MAN'S-BUFF, GAMES
# [ 18] MASTER SCROOGE, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG PEOPLE,
#       DECANTER, BLOCK OF CAKE
# [ 19] WINTER BALL, DANCE EVENT, BAKER, MISS FEZZIWIG, YOUNG FOLLOWERS,
#       HOUSEMAID, COOK, MILKMAN
# [ 20] SCROOGE'S NIECE, SCROOGE'S NEPHEW, SCROOGE'S NIECE'S SISTERS, SCROOGE'S
#       NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND
#       WHERE
# [ 21] GROCERS, NORFOLK BIFFINS, FISH, ALMONDS, CINNAMON, RAISINS, TEA, COFFEE
# [ 22] CUSTOMERS, GROCER, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 23] FIRE, BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO MEN, STORM-BIRDS,
#       SEA
# [ 24] BELLE, MERRY CHRISTMAS, MR. SCROOGE, OFFICE, OLD GENTLEMAN, GHOST OF
#       CHRISTMAS, HAPPY END
# [ 25] PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION, UNITED STATES,
#       WWW.GUTENBERG.ORG, ADDRESS, DONATIONS, U.S. FEDERAL LAWS, IRS
# [ 26] BOB, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE,
#       NINE O'CLOCK
# [ 27] BLAZE, LAMPLIGHTER, MASTER OF THE HOUSE, HOUSE, SNOW, SNOWSTORMS
# [ 28] MOTHER, CHAOS, DINNER, DAUGHTER, LAMPLIGHT, DESSERT
# [ 29] FAN, FATHER, BOY, LITTLE FAN, POULTERER'S, COACH
# [ 30] GHOST OF CHRISTMAS PAST, YOUNG GIRL, IDOL, COMELY MATRON, POVERTY,
#       WEALTH
# [ 31] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#       BLACK, SHOP, CHARCOAL STOVE
# [ 32] COUNTING-HOUSE, CITY, CHANGE, MONEY, MERCHANTS, GOLD SEALS
# [ 33] SELF, CHURCH, CLOCK, BED, UNKNOWN, MULTITUDES
# [ 34] COPYRIGHT LAW, FOUNDATION, TAX EXEMPT STATUS, PUBLIC DOMAIN, CHARITABLE
#       DONATIONS, COMPLIANCE REQUIREMENTS
# [ 35] LAUGHTER, MRS. DILBER, LAUNDRESS, PARLOUR, CHARWOMAN, UNDERTAKER'S MAN
# [ 36] CORNHILL, CLERK, CANDLE, CAMDEN TOWN, MASTER, FIFTEEN SHILLINGS
# [ 37] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [ 38] LOW-BROWED SHOP, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 39] GREAT BRITAIN, PEOPLE, CLIMATE, SNOWBALL FIGHT, WICKER BASKETS, DINNERS
# [ 40] BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN, GREAT FAT MAN, RED-FACED
#       GENTLEMAN
# [ 41] FRED, GOOD-HUMOUR, SISTER, MULLED WINE, BLIND MAN
# [ 42] GENTLEMAN, POOR LAW, FESTIVE SEASON, FUND, COMPANY
# [ 43] FIGURE, LIGHT, TUNIC, SUMMER FLOWERS, BELT
# [ 44] MARTHA, HOLIDAY, MILLINER, COUNTESS, LORD
# [ 45] SCOURGE, SPIRIT OF CHRISTMAS YET TO COME, CANDLES, COURT
# [ 46] OLD MAN, CHEERFUL COMPANY, HUT, CHRISTMAS SONG
# [ 47] DINING-ROOM, GIRL, MISTRESS, YOUNG HOUSEKEEPERS
# [ 48] MOOR, FROST, MINERS, SETTING SUN
# [ 49] DARKNESS, WINTER DAY, FOG, FLOGGING LINKS
# [ 50] GUTENBERG LITERARY ARCHIVE FOUNDATION, SALT LAKE CITY, INTERNAL REVENUE
#       SERVICE, MISSISSIPPI
# [ 51] TOWN, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS
# [ 52] JOE, OLD SCRATCH, BED-CURTAINS, FIRST WOMAN
# [ 53] HOLLY SPRIGS, ANCIENT TOWER, MAIN STREET, GAS-PIPES
# [ 54] MIST, STREETS, CARTS AND WAGONS
# [ 55] ELECTRONIC WORKS, DERIVATIVE WORKS, FREE ACCESS
# [ 56] NEPHEW, YES AND NO, ANIMAL
# [ 57] DANCE, PORTER, FIDDLER
# [ 58] LORD MAYOR, MANSION HOUSE, FIFTY COOKS AND BUTLERS
# [ 59] BOYS, MARKET-TOWN, FARMERS
# [ 60] SULTAN'S GROOM, PRINCESS, GENII
# [ 61] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [ 62] DEATH, DECEASED MAN, HAMLET'S FATHER
# [ 63] CHESTNUTS, POULTERERS' SHOPS
# [ 64] SCROOGE AND MARLEY, WAREHOUSE
# [ 65] WATER, CAVERN
# [ 66] PARAGRAPH 1.F.3, DEFECT IN ELECTRONIC WORK
# [ 67] FIREPLACE, DUTCH MERCHANT
# [ 68] CHRISTMAS PUDDING, COPPER
# [ 69] DICK, EBENEZER
# [ 70] HOLLY, UNEARTHLY VISITOR
# [ 71] GENTLEMEN, POPULATION
# [ 72] GATEWAY, FOG AND FROST
# [ 73] HALL, ECHOES
# [ 74] SISTERS, GUESTS
# [ 75] KNOCKER, DARK CELLAR
# [ 76] WINDOWS, HOUSE-FRONTS
# [ 77] CHAMBERS, OFFICES
# [ 78] IGNORANCE, WANT
# [ 79] VALENTINE, ORSON
# [ 80] MEAGRE SERVANT, POSTBOY
# [ 81] GLOBE
# [ 82] SPIRIT OF TINY TIM
# [ 83] COPYRIGHT HOLDER
# [ 84] TERMS OF THIS AGREEMENT
# [ 85] ROYALTY FEE
# [ 86] AGREEMENT
# [ 87] CHURCHYARD
# [ 88] HAPPINESS
# [ 89] TWELVE
# [ 90] BERRIES
# [ 91] MISTLETOE
# [ 92] THRONE
# [ 93] RED BERRIES
# [ 94] GEESE
# [ 95] GAME
# [ 96] BRAWN
# [ 97] MEAT
# [ 98] PIGS
# [ 99] SAUSAGES
# [100] OYSTERS
# [101] PIES
# [102] PUDDINGS
# [103] PARTNERSHIP
# [104] WINTER WEATHER
# [105] UNCLE
# [106] WORLD OF FOOLS
# [107] HEART
# [108] PARLIAMENT
# [109] BEDLAM
# [110] UNION WORKHOUSES
# [111] TREADMILL
# [112] ST. DUNSTAN
# [113] HAT
# [114] DECEASED PARTNER
# [115] BANKER'S BOOK
# [116] CITY OF LONDON
# [117] KEY
# [118] STAIRS
# [119] GRUEL
# [120] SITTING-ROOM
# [121] BEDROOM
# [122] LUMBER-ROOM
# [123] DRESSING-GOWN
# [124] SLIPPERS
# [125] CAINS
# [126] ABELS
# [127] PHARAOH'S DAUGHTERS
# [128] QUEENS OF SHEBA
# [129] ANGELIC MESSENGERS
# [130] ABRAHAMS
# [131] BELSHAZZARS
# [132] APOSTLES
# [133] BUTTER-BOATS
# [134] SENSES
# [135] BEEF
# [136] MUSTARD
# [137] POTATO
# [138] GRAVY
# [139] CHAIR
# [140] APPEARANCE
# [141] WARD
# [142] POOR ABODE
# [143] CROWD
# [144] INVISIBLE WORLD
# [145] WINDOW
# [146] CHAMBER
# [147] TIME
# [148] THE VISITATION
# [149] THE CLOCK
# [150] THE CHIME
# [151] THE QUARTER
# [152] HOUR BELL
# [153] CURTAINS
# [154] WELFARE
# [155] BRIDGE
# [156] RIVER
# [157] MANSION
# [158] TRAVELLERS
# [159] HIGH-ROAD
# [160] LANE
# [161] MANSION OF DULL RED BRICK
# [162] POPPLAR
# [163] DAMASCUS
# [164] ROBIN CRUSOE
# [165] FRIDAY
# [166] PARROT
# [167] CHRISTMAS CAROL
# [168] FAIR YOUNG GIRL
# [169] DOWERLESS GIRL
# [170] HEAVEN
# [171] BRAIDED HAIR
# [172] LITTLE SHOE
# [173] EXTINGUISHER-CAP
# [174] ONE
# [175] GHOSTLY LIGHT
# [176] TRANSFORMATION
# [177] GESE
# [178] PLUM-PUDDINGS
# [179] TWELFTH-CAKES
# [180] CITY STREETS
# [181] CHURCH AND CHAPEL
# [182] INCENSE
# [183] TORCH
# [184] POOR MAN'S CHILD
# [185] POOR CLERK
# [186] MOLDY OLD OFFICE
# [187] DUSTY CHAMBERS
# [188] LONDON
# [189] CHRISTMAS HOLIDAYS
# [190] BUSINESSMEN
# [191] HOUSES
# [192] FURNITURE
# [193] PRESENT
# [194] FUTURE
# [195] CHRISTMAS TIME
# [196] BEDPOST
# [197] WANDERING SPIRITS
# [198] LAOCOON
# [199] CHURCHES
# [200] POULTERER
# [201] TURKEY
# [202] CAB
# [203] SCROOGE AND MARLEY'S
# [204] PORTLY GENTLEMAN
# [205] TANK
# [206] HOSPITAL
# [207] MYSTERY
# [208] FILBERTS
# [209] SHEETS
# [210] TAVERN
# [211] ALI BABA
# [212] SPIRIT'S ROBE
# [213] BEER
# [214] COAL-SCUTTLE
# [215] COLD BOILED
# [216] CHRISTMAS BALL
# [217] WELSH WIG
# [218] TIM CRATCHIT
# [219] CLOSET DOOR
# [220] PUDDING
# [221] CHIMNEY CORNER
# [222] SPIRITS
# [223] TOTAL-ABSTINENCE PRINCIPLE
# [224] YOUNGEST CRATCHITS
# [225] SAGE AND ONION
# [226] HEARTH
# [227] CLOTH
# [228] FIRST PARTING

# %%
import leidenalg as la
import igraph as ig

igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition4_3 = la.find_partition(igraph, la.CPMVertexPartition,resolution_parameter=0.01)
modularity_score_igraph4_3 = igraph.modularity(partition4_3)  
print(f"Modularity Score from CPMVertexPartition: {modularity_score_igraph4_3}")
# Out:
# Modularity Score from CPMVertexPartition: 0.6384418043967609

# %%
print(partition4_3)
# Out:
# Clustering with 610 elements and 45 clusters
# [ 0] SCROOGE, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART,
#      PARLIAMENT, BEDLAM, UNION WORKHOUSES, TREADMILL, HAT, TAVERN, DECEASED
#      PARTNER, BANKER'S BOOK, CITY OF LONDON, KEY, WINE-MERCHANT, STAIRS,
#      GRUEL, BEDROOM, LUMBER-ROOM, DRESSING-GOWN, CAINS, ABELS, PHARAOH'S
#      DAUGHTERS, QUEENS OF SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS,
#      APOSTLES, BUTTER-BOATS, SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY,
#      CHAIR, APPEARANCE, WARD, WISE MEN, POOR ABODE, CROWD, WINDOW, CHAMBER,
#      TIME, THE VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL,
#      CURTAINS, WELFARE, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE,
#      MANSION OF DULL RED BRICK, DAMASCUS, ROBIN CRUSOE, FRIDAY, PARROT,
#      CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN, BRAIDED HAIR,
#      LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION, GESE,
#      TWELFTH-CAKES, CHURCH AND CHAPEL, INCENSE, TORCH, POOR MAN'S CHILD, POOR
#      CLERK, AROMATIC VINEGAR, DUSTY CHAMBERS, LONDON, BUSINESSMEN, SHADOW,
#      HOUSES, PRESENT, CHRISTMAS TIME, BEDPOST, WANDERING SPIRITS, LAOCOON,
#      CHURCHES, CORNER, POULTERER, TURKEY, CAB, SCROOGE AND MARLEY'S, PORTLY
#      GENTLEMAN, TANK
# [ 1] BOB CRATCHIT, TINY TIM, CHILD, MR. SCROOGE, PETER CRATCHIT, TIM CRATCHIT,
#      MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, THE CRATCHIT FAMILY,
#      CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR, CHRISTMAS
#      DINNER, CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS,
#      OFFICE, COAL-SCUTTLE, GOOSE, FIRE, BELINDA, CHRISTMAS PUDDING, BOB,
#      CHRISTMAS PARTY, OLD GENTLEMAN, BRAZIER, RAGGED MEN AND BOYS, GHOST OF
#      CHRISTMAS, HAPPY END, CRATCHITS, MARTHA, PUDDING, CHIMNEY CORNER,
#      SPIRITS, TOTAL-ABSTINENCE PRINCIPLE, GLOBE, YOUNGEST CRATCHITS, SAGE AND
#      ONION, HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY TIM, HOLIDAY,
#      MILLINER, COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S
#      NEPHEW, GOOD WIFE, NINE O'CLOCK, COPPER
# [ 2] EBENEZER SCROOGE, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF
#      JACOB MARLEY, DICK WILKINS, CHRISTMAS EVE, FEZZIWIG'S BALL, THE THREE
#      SPIRITS, SCROOGE AND MARLEY, HAMLET, SCROOGE'S HOUSE, MONEY-CHANGING
#      HOLE, FIRST OF EXCHANGE, FEZZIWIG, CHURCHYARD, GRAVE, DICK, MRS.
#      FEZZIWIG, WAREHOUSE, HIGH DESK, WELSH WIG, EBENEZER, WINTER BALL, DANCE
#      EVENT, DANCE, COLD ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR
#      ROGER DE COVERLEY, DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, PORTER,
#      BAKER, STREET, MISS FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID, COOK, MILKMAN,
#      FIDDLER
# [ 3] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, TERMS OF THIS AGREEMENT, UNITED STATES, WORLD, PROJECT
#      GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK, USER, GUTENBERG
#      LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE, COPYRIGHT LAW,
#      PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, MICHAEL S. HART,
#      WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER, DONATION, ADDRESS, REFUND, PERSON,
#      ENTITY, DONATIONS, U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC
#      DOMAIN, DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS
# [ 4] GHOST OF CHRISTMAS PAST, BELLE, SPIRIT, CHILDREN, FAMILY, YOUNG GIRL,
#      IDOL, MASTER OF THE HOUSE, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS,
#      COMELY MATRON, MOTHER, CHAOS, CHRISTMAS HOLIDAYS, PAST, FUTURE,
#      ALMSHOUSE, HOSPITAL, GAOL, POVERTY, IGNORANCE, WANT, DEVILS, ANGELS,
#      WORKHOUSES, MYSTERY, WEALTH, DAUGHTER, BROWN-PAPER PARCELS, MARRIED
#      SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS
# [ 5] DEATH, LAUGHTER, WOMAN, CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER,
#      LAUNDRESS, PARLOUR, DECEASED MAN, OLD JOE, HAMLET'S FATHER, DINNER,
#      CORPSE, SPOIL, CONTRACT, ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT,
#      LAMPLIGHT, CHARWOMAN, UNDERTAKER'S MAN, DESSERT, BUNDLE, SEAL, PENCIL-
#      CASE, SLEEVE-BUTTONS, BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-
#      TONGS, BOOTS
# [ 6] FAN, CHRISTMAS, FATHER, BOY, LORD MAYOR, MANSION HOUSE, POULTERERS,
#      TAILOR, RAGGED MEN, BOYS, BERRIES, IVY, THRONE, RED BERRIES, TURKEYS,
#      GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES, OYSTERS, PIES,
#      PUDDINGS, FRUIT, PUNCH, MARKET-TOWN, LITTLE FAN, POULTERER'S, FIFTY COOKS
#      AND BUTLERS, FARMERS, COACH
# [ 7] PHANTOM, PORCH, TOWN, SELF, HOLLY SPRIGS, ANCIENT TOWER, ROOM, CLOCK,
#      COLD, BED, WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN STREET, GAS-
#      PIPES, UNKNOWN, GLOOM, GRAVES, MULTITUDES, INFAMOUS RESORT, NARROW
#      ALLEYS, ARCHWAYS
# [ 8] GHOST, JACOB MARLEY, NIGHT, CHAIN, HAPPINESS, SPECTRE, THREE SPIRITS,
#      TWELVE, STAVE TWO, MERRY CHRISTMAS, BAKER'S, SURPLUS POPULATION, BLAZE,
#      LAMPLIGHTER, SCOURGE, SHIP, TWELFTH-NIGHT PARTY, SPIRIT'S ROBE, HOUSE,
#      HELMSMAN, LOOK-OUT, OFFICERS, SPIRIT OF CHRISTMAS YET TO COME
# [ 9] PEOPLE, MISTLETOE, CHESTNUTS, SNOW, CLIMATE, SNOWBALL FIGHT, POULTERERS'
#      SHOPS, FRUITERERS, WICKER BASKETS, DINNERS, SNOWSTORMS, SPANISH ONIONS,
#      SHOPKEEPERS, PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS,
#      FRUITS, VEGETABLES
# [10] FRED, GHOST OF CHRISTMAS PRESENT, SCROOGE'S NIECE, PARTY, GOOD-HUMOUR,
#      SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER, SCROOGE'S
#      NEPHEW, SCROOGE'S NIECE'S SISTERS, SCROOGE'S NIECE'S SISTER, HARP, LARGE
#      CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF,
#      BLIND MAN, GAMES
# [11] MARLEY, FIREPLACE, CORNHILL, CLERK, STAVE ONE, CANDLE, CAMDEN TOWN,
#      KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL REGISTER, GHOSTLY
#      SPECTACLES, WAISTCOAT, PIGTAIL, MASTER, FIFTEEN SHILLINGS, DARK CELLAR,
#      DUTCH MERCHANT
# [12] MASTER SCROOGE, DINING-ROOM, NEPHEW, HALL, YES AND NO, GIRL, ANIMAL,
#      MISTRESS, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG
#      PEOPLE, DECANTER, BLOCK OF CAKE, YOUNG HOUSEKEEPERS
# [13] COUNTING-HOUSE, MIST, CITY, STREETS, DARKNESS, WINTER DAY, CANDLES,
#      CHANGE, MONEY, MERCHANTS, COURT, FOG, FLOGGING LINKS, CARTS AND WAGONS,
#      GOLD SEALS
# [14] GROCERS, CUSTOMERS, GROCER, NORFOLK BIFFINS, FISH, ALMONDS, CINNAMON,
#      RAISINS, TEA, COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH
#      PLUMS
# [15] MOOR, FROST, OLD MAN, LIGHTHOUSE, TWO MEN, MINERS, CHEERFUL COMPANY,
#      SETTING SUN, HUT, CHRISTMAS SONG, WATER, STORM-BIRDS, SEA, CAVERN
# [16] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CHURCH, GHOSTS,
#      WOMAN WITH INFANT
# [17] GENTLEMAN, POOR LAW, BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN, FESTIVE
#      SEASON, FUND, COMPANY, GREAT FAT MAN, RED-FACED GENTLEMAN
# [18] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#      YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#      TEAM, J. B. LIPPINCOTT COMPANY, GREAT BRITAIN
# [19] HOLLY, UNEARTHLY VISITOR, FIGURE, LIGHT, TUNIC, SUMMER FLOWERS, BELT
# [20] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [21] LOW-BROWED SHOP, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [22] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [23] GUTENBERG LITERARY ARCHIVE FOUNDATION, SALT LAKE CITY, INTERNAL REVENUE
#      SERVICE, MISSISSIPPI
# [24] JOE, OLD SCRATCH, BED-CURTAINS, FIRST WOMAN
# [25] SULTAN'S GROOM, PRINCESS, GENII
# [26] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [27] ELECTRONIC WORKS, DERIVATIVE WORKS, FREE ACCESS
# [28] GENTLEMEN, POPULATION
# [29] CHAMBERS, OFFICES
# [30] VALENTINE, ORSON
# [31] SISTERS, GUESTS
# [32] WINDOWS, HOUSE-FRONTS
# [33] GATEWAY, FOG AND FROST
# [34] MEAGRE SERVANT, POSTBOY
# [35] ST. DUNSTAN
# [36] SITTING-ROOM
# [37] SLIPPERS
# [38] INVISIBLE WORLD
# [39] ALI BABA
# [40] POPPLAR
# [41] PLUM-PUDDINGS
# [42] CITY STREETS
# [43] MOLDY OLD OFFICE
# [44] FURNITURE

# %%
import leidenalg as la
import igraph as ig

igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition4_4 = la.find_partition(igraph, la.CPMVertexPartition,resolution_parameter=0.001)
modularity_score_igraph4_4 = igraph.modularity(partition4_4)  
print(f"Modularity Score from CPMVertexPartition: {modularity_score_igraph4_4}")
# Out:
# Modularity Score from CPMVertexPartition: 0.21068228763877914

# %%
print(partition4_4)
# Out:
# Clustering with 610 elements and 12 clusters
# [ 0] A CHRISTMAS CAROL, CHARLES DICKENS, EBENEZER SCROOGE, ARTHUR RACKHAM,
#      PHILADELPHIA, NEW YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE
#      DISTRIBUTED PROOFREADING TEAM, J. B. LIPPINCOTT COMPANY, GHOST, GREAT
#      BRITAIN, SCROOGE, BOB CRATCHIT, MR. FEZZIWIG, FRED, GHOST OF CHRISTMAS
#      PAST, GHOST OF CHRISTMAS PRESENT, GHOST OF CHRISTMAS YET TO COME, GHOST
#      OF JACOB MARLEY, DICK WILKINS, BELLE, FAN, MARLEY'S GHOST, CHRISTMAS EVE,
#      FEZZIWIG'S BALL, JACOB MARLEY, THE THREE SPIRITS, CHRISTMAS, SCROOGE AND
#      MARLEY, HAMLET, NIGHT, SCROOGE'S HOUSE, CHAIN, COUNTING-HOUSE, MONEY-
#      CHANGING HOLE, MARLEY, BELL, FIRST OF EXCHANGE, FEZZIWIG, TINY TIM,
#      SPIRIT, CHURCHYARD, PHANTOM, GRAVE, PEOPLE, FIREPLACE, HAPPINESS,
#      SPECTRE, THREE SPIRITS, TWELVE, STAVE TWO, MIST, MERRY CHRISTMAS, CHILD,
#      MASTER SCROOGE, DICK, MR. SCROOGE, BAKER'S, SURPLUS POPULATION, BLAZE,
#      LAMPLIGHTER, SCOURGE, SHIP, SCROOGE'S NIECE, PARTY, TWELFTH-NIGHT PARTY,
#      CHILDREN, SPIRIT'S ROBE, PORCH, TOWN, SELF, PETER CRATCHIT, TIM CRATCHIT,
#      MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, CORNHILL, THE CRATCHIT
#      FAMILY, CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR,
#      CHRISTMAS DINNER, CHRISTMAS DAY, PETER, DEATH, CRATCHIT'S HOUSE,
#      CRATCHIT'S WIFE, GIRLS, OFFICE, FAMILY, COAL-SCUTTLE, GOOSE, MRS.
#      FEZZIWIG, LAUGHTER, GOOD-HUMOUR, SISTER, MULLED WINE, DINING-ROOM, YOUNG
#      GIRL, IDOL, UNCLE SCROOGE, TOPPER, PLUMP SISTER, WAREHOUSE, HIGH DESK,
#      WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD ROAST, COLD
#      BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY, DOMESTIC
#      BALL, APPRENTICES, CHRISTMAS BALL, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN,
#      FIRST WOMAN, MASTER OF THE HOUSE, CAROLINE, HUSBAND, MAN, DEBT, FIRE,
#      BELINDA, CHRISTMAS PUDDING, HOLLY, BOB, MRS. DILBER, LAUNDRESS, PARLOUR,
#      DECEASED MAN, OLD JOE, FATHER, BOY, WINE-MERCHANT'S CELLAR, HAUNTED
#      HOUSE, DOOR, PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS,
#      CLERK, NEPHEW, SCROOGE'S NEPHEW, LORD MAYOR, MANSION HOUSE, POULTERERS,
#      TAILOR, RAGGED MEN, BOYS, HOLLY SPRIGS, BERRIES, CITY, PORTER, MISTLETOE,
#      IVY, THRONE, RED BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT,
#      PIGS, SAUSAGES, OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, BAKERS' SHOPS,
#      STREETS, CHRISTMAS PARTY, MOOR, STAVE ONE, HAMLET'S FATHER, PARTNERSHIP,
#      WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART, PARLIAMENT, BEDLAM,
#      GENTLEMEN, GENTLEMAN, PRISONS, UNION WORKHOUSES, POOR LAW, TREADMILL,
#      CHURCH, POPULATION, ANCIENT TOWER, ST. DUNSTAN, CANDLE, HAT, TAVERN,
#      DECEASED PARTNER, BANKER'S BOOK, CITY OF LONDON, GATEWAY, KEY, WINE-
#      MERCHANT, STAIRS, DARKNESS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-ROOM,
#      DRESSING-GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS OF
#      SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-BOATS,
#      ROOM, SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE,
#      WARD, WISE MEN, POOR ABODE, CROWD, GHOSTS, INVISIBLE WORLD, WINDOW,
#      CHAMBER, CLOCK, FROST, COLD, TIME, THE VISITATION, THE CLOCK, THE CHIME,
#      THE QUARTER, HOUR BELL, CURTAINS, BED, UNEARTHLY VISITOR, FIGURE,
#      WELFARE, WINTER DAY, COUNTRY ROAD, FIELDS, MARKET-TOWN, BRIDGE, RIVER,
#      MANSION, TRAVELLERS, HIGH-ROAD, LANE, MANSION OF DULL RED BRICK, ALI
#      BABA, HOUSE, POPPLAR, DAMASCUS, VALENTINE, ROBIN CRUSOE, FRIDAY, PARROT,
#      CHRISTMAS CAROL, LITTLE FAN, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN,
#      COMELY MATRON, WINTER FIRE, MOTHER, CHAOS, BRAIDED HAIR, LITTLE SHOE,
#      EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION, GESE, PLUM-
#      PUDDINGS, TWELFTH-CAKES, CHESTNUTS, CITY STREETS, CHURCH AND CHAPEL,
#      BAKER, INCENSE, TORCH, DINNER, POOR MAN'S CHILD, OLD MAN, HELMSMAN, LOOK-
#      OUT, OFFICERS, SCROOGE'S NIECE'S SISTERS, POOR CLERK, AROMATIC VINEGAR,
#      MOLDY OLD OFFICE, DUSTY CHAMBERS, SISTERS, YES AND NO, LONDON, CHRISTMAS
#      HOLIDAYS, SPIRIT OF CHRISTMAS YET TO COME, BUSINESS MEN, BUSINESSMEN,
#      CORPSE, SPOIL, BODY, TERRORS, SHADOW, HOUSES, FURNITURE, PAST, PRESENT,
#      FUTURE, CHRISTMAS TIME, BEDPOST, WANDERING SPIRITS, LAOCOON, CHURCHES,
#      CORNER, POULTERER'S, POULTERER, CAMDEN TOWN, TURKEY, KNOCKER, CAB,
#      SCROOGE AND MARLEY'S, PORTLY GENTLEMAN, OLD GENTLEMAN, GIRL, TANK,
#      CONTRACT, ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, CLERGYMAN, UNDERTAKER,
#      CHIEF MOURNER, BURIAL REGISTER, FUNERAL, GHOSTLY SPECTACLES, WAISTCOAT,
#      PIGTAIL, MASTER, FIFTEEN SHILLINGS, STAVE FOUR, MAN WITH LARGE CHIN,
#      CANDLES, CHANGE, MONEY, MERCHANTS, COURT, SNOW, CLIMATE, SNOWBALL FIGHT,
#      POULTERERS' SHOPS, WICKER BASKETS, DINNERS, ANIMAL, MISTRESS, FOG,
#      FLOGGING LINKS, FESTIVE SEASON, FUND, COMPANY, MAIN STREET, GAS-PIPES,
#      BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO MEN, FIFTY COOKS AND
#      BUTLERS, FARMERS, FOG AND FROST, DARK CELLAR, DUTCH MERCHANT, UNKNOWN,
#      LIGHT, MINERS, CHEERFUL COMPANY, ALMSHOUSE, HOSPITAL, GAOL, POVERTY,
#      IGNORANCE, WANT, DEVILS, ANGELS, WORKHOUSES, MYSTERY, STREET, GLOOM,
#      GRAVES, WOMAN WITH INFANT, MULTITUDES, SETTING SUN, TUNIC, SUMMER
#      FLOWERS, BELT, COACH, ORSON, SCHOOL, MISS FEZZIWIG, YOUNG FOLLOWERS,
#      HOUSEMAID, COOK, MILKMAN, FIDDLER, WEALTH, DAUGHTER, BROWN-PAPER PARCELS,
#      MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS, GHOST OF CHRISTMAS,
#      HAPPY END, SNOWSTORMS, CARTS AND WAGONS, APPLES, ORANGES, CRATCHITS,
#      LAMPLIGHT, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS, MARTHA, PUDDING,
#      CHIMNEY CORNER, SPIRITS, TOTAL-ABSTINENCE PRINCIPLE, GLOBE, YOUNGEST
#      CRATCHITS, SAGE AND ONION, HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY
#      TIM, HOLIDAY, MILLINER, COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN PLACE,
#      MR. SCROOGE'S NEPHEW, GOOD WIFE, NINE O'CLOCK, COPPER, HUT, CHRISTMAS
#      SONG, WATER, STORM-BIRDS, SEA, CAVERN, SCROOGE'S NIECE'S SISTER, HARP,
#      LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND WHERE, CHARWOMAN,
#      UNDERTAKER'S MAN, MUSIC, BLIND MAN'S-BUFF, DESSERT, BLIND MAN, GAMES,
#      GUESTS, GOLD SEALS, GREAT FAT MAN, RED-FACED GENTLEMAN, BUNDLE, SEAL,
#      PENCIL-CASE, SLEEVE-BUTTONS, BROOCH, SHEETS, TOWELS, SILVER TEASPOONS,
#      SUGAR-TONGS, BOOTS, YOUNG HOUSEKEEPERS
# [ 1] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 2] GROCERS, CUSTOMERS, GROCER, FRUITERERS, NORFOLK BIFFINS, FISH, ALMONDS,
#      CINNAMON, RAISINS, TEA, COFFEE, SPANISH ONIONS, SHOPKEEPERS, PEARS,
#      GRAPES, FILBERTS, LEMONS, BASKETS, FRUITS, VEGETABLES, SPICES, CANISTERS,
#      CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 3] HALL, ECHOES, SCHOOLMASTER, CHAIS, GARDEN SWEEP, YOUNG PEOPLE, DECANTER,
#      BLOCK OF CAKE
# [ 4] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [ 5] LOW-BROWED SHOP, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 6] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [ 7] SULTAN'S GROOM, PRINCESS, GENII
# [ 8] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [ 9] WINDOWS, HOUSE-FRONTS
# [10] MEAGRE SERVANT, POSTBOY
# [11] CHAMBERS, OFFICES

# %%
import leidenalg as la
import igraph as ig
igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition4_5 = la.find_partition(igraph, la.CPMVertexPartition,resolution_parameter=0.005)
modularity_score_igraph4_5 = igraph.modularity(partition4_5)  
print(f"Modularity Score from CPMVertexPartition: {modularity_score_igraph4_5}")
# Out:
# Modularity Score from CPMVertexPartition: 0.6510022255523215

# %%
print(partition4_5)
# Out:
# Clustering with 610 elements and 25 clusters
# [ 0] SCROOGE, SHIP, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART,
#      PARLIAMENT, BEDLAM, GENTLEMEN, UNION WORKHOUSES, TREADMILL, POPULATION,
#      ST. DUNSTAN, HAT, TAVERN, DECEASED PARTNER, BANKER'S BOOK, CITY OF
#      LONDON, KEY, WINE-MERCHANT, STAIRS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-
#      ROOM, DRESSING-GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS
#      OF SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-
#      BOATS, SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE,
#      WARD, WISE MEN, POOR ABODE, CROWD, INVISIBLE WORLD, WINDOW, CHAMBER,
#      TIME, THE VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL,
#      CURTAINS, WELFARE, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE,
#      MANSION OF DULL RED BRICK, ALI BABA, POPPLAR, DAMASCUS, ROBIN CRUSOE,
#      FRIDAY, PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN,
#      BRAIDED HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT,
#      TRANSFORMATION, GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH
#      AND CHAPEL, INCENSE, TORCH, POOR MAN'S CHILD, HELMSMAN, LOOK-OUT,
#      OFFICERS, POOR CLERK, AROMATIC VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS,
#      LONDON, BUSINESSMEN, SHADOW, HOUSES, FURNITURE, PRESENT, CHRISTMAS TIME,
#      BEDPOST, WANDERING SPIRITS, LAOCOON, CHURCHES, CORNER, POULTERER, TURKEY,
#      CAB, SCROOGE AND MARLEY'S, PORTLY GENTLEMAN, TANK
# [ 1] A CHRISTMAS CAROL, CHARLES DICKENS, EBENEZER SCROOGE, ARTHUR RACKHAM,
#      PHILADELPHIA, NEW YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE
#      DISTRIBUTED PROOFREADING TEAM, J. B. LIPPINCOTT COMPANY, GHOST, GREAT
#      BRITAIN, GHOST OF CHRISTMAS YET TO COME, GHOST OF JACOB MARLEY, DICK
#      WILKINS, MARLEY'S GHOST, FEZZIWIG'S BALL, JACOB MARLEY, THE THREE
#      SPIRITS, SCROOGE AND MARLEY, HAMLET, NIGHT, SCROOGE'S HOUSE, CHAIN,
#      MONEY-CHANGING HOLE, MARLEY, BELL, FIRST OF EXCHANGE, FIREPLACE,
#      HAPPINESS, SPECTRE, THREE SPIRITS, TWELVE, STAVE TWO, MERRY CHRISTMAS,
#      BAKER'S, SURPLUS POPULATION, BLAZE, LAMPLIGHTER, TWELFTH-NIGHT PARTY,
#      SPIRIT'S ROBE, CORNHILL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CLERK, STAVE
#      ONE, CANDLE, GHOSTS, CAMDEN TOWN, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF
#      MOURNER, BURIAL REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, MASTER,
#      FIFTEEN SHILLINGS, DARK CELLAR, DUTCH MERCHANT, WOMAN WITH INFANT
# [ 2] GHOST OF CHRISTMAS PAST, BELLE, COUNTING-HOUSE, SPIRIT, CHURCHYARD,
#      GRAVE, PEOPLE, MIST, CHILDREN, FAMILY, YOUNG GIRL, IDOL, MASTER OF THE
#      HOUSE, CITY, BAKERS' SHOPS, STREETS, PRISONS, DARKNESS, WINTER DAY,
#      COUNTRY ROAD, FIELDS, HOUSE, COMELY MATRON, MOTHER, CHAOS, OLD MAN,
#      CHRISTMAS HOLIDAYS, PAST, FUTURE, CANDLES, CHANGE, MONEY, MERCHANTS,
#      COURT, SNOW, CLIMATE, SNOWBALL FIGHT, WICKER BASKETS, DINNERS, FOG,
#      FLOGGING LINKS, MINERS, CHEERFUL COMPANY, ALMSHOUSE, HOSPITAL, GAOL,
#      POVERTY, IGNORANCE, WANT, DEVILS, ANGELS, WORKHOUSES, MYSTERY, WEALTH,
#      DAUGHTER, BROWN-PAPER PARCELS, MARRIED SISTERS, BROTHERS, COUSINS,
#      UNCLES, AUNTS, SNOWSTORMS, CARTS AND WAGONS, HUT, CHRISTMAS SONG, GOLD
#      SEALS
# [ 3] FRED, GHOST OF CHRISTMAS PRESENT, FAN, CHRISTMAS, MASTER SCROOGE,
#      SCROOGE'S NIECE, PARTY, GOOD-HUMOUR, SISTER, MULLED WINE, DINING-ROOM,
#      UNCLE SCROOGE, TOPPER, PLUMP SISTER, FATHER, BOY, NEPHEW, SCROOGE'S
#      NEPHEW, LORD MAYOR, MANSION HOUSE, POULTERERS, TAILOR, RAGGED MEN, BOYS,
#      BERRIES, IVY, THRONE, RED BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN,
#      MEAT, PIGS, SAUSAGES, OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, MARKET-TOWN,
#      LITTLE FAN, SCROOGE'S NIECE'S SISTERS, YES AND NO, POULTERER'S, ANIMAL,
#      MISTRESS, FIFTY COOKS AND BUTLERS, FARMERS, COACH, SCHOOL, SCROOGE'S
#      NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND
#      WHERE, MUSIC, BLIND MAN'S-BUFF, BLIND MAN, GAMES, YOUNG HOUSEKEEPERS
# [ 4] BOB CRATCHIT, TINY TIM, CHILD, MR. SCROOGE, PETER CRATCHIT, TIM CRATCHIT,
#      MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA CRATCHIT, THE CRATCHIT FAMILY,
#      CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG CRATCHITS, CLOSET DOOR, CHRISTMAS
#      DINNER, CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS,
#      OFFICE, COAL-SCUTTLE, GOOSE, FIRE, BELINDA, CHRISTMAS PUDDING, BOB,
#      CHRISTMAS PARTY, OLD GENTLEMAN, BRAZIER, RAGGED MEN AND BOYS, GHOST OF
#      CHRISTMAS, HAPPY END, CRATCHITS, MARTHA, PUDDING, CHIMNEY CORNER,
#      SPIRITS, TOTAL-ABSTINENCE PRINCIPLE, GLOBE, YOUNGEST CRATCHITS, SAGE AND
#      ONION, HEARTH, CLOTH, FIRST PARTING, SPIRIT OF TINY TIM, HOLIDAY,
#      MILLINER, COUNTESS, LORD, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S
#      NEPHEW, GOOD WIFE, NINE O'CLOCK, COPPER
# [ 5] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 6] DEATH, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, DINNER, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, LAMPLIGHT, CHARWOMAN,
#      UNDERTAKER'S MAN, DESSERT, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS,
#      BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 7] MR. FEZZIWIG, CHRISTMAS EVE, FEZZIWIG, DICK, MRS. FEZZIWIG, WAREHOUSE,
#      HIGH DESK, WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT, DANCE, COLD
#      ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY,
#      DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, PORTER, BAKER, GIRL, STREET,
#      MISS FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID, COOK, MILKMAN, FIDDLER
# [ 8] PHANTOM, PORCH, TOWN, SELF, HOLLY SPRIGS, CHURCH, ANCIENT TOWER, ROOM,
#      CLOCK, COLD, BED, WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN STREET,
#      GAS-PIPES, UNKNOWN, GLOOM, GRAVES, MULTITUDES, LOW-BROWED SHOP, INFAMOUS
#      RESORT, NARROW ALLEYS, ARCHWAYS, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 9] GROCERS, CUSTOMERS, GROCER, NORFOLK BIFFINS, FISH, ALMONDS, CINNAMON,
#      RAISINS, TEA, COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH
#      PLUMS
# [10] MISTLETOE, CHESTNUTS, POULTERERS' SHOPS, FRUITERERS, SPANISH ONIONS,
#      SHOPKEEPERS, PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS,
#      FRUITS, VEGETABLES
# [11] SCOURGE, MOOR, FROST, SPIRIT OF CHRISTMAS YET TO COME, LIGHTHOUSE, TWO
#      MEN, SETTING SUN, WATER, STORM-BIRDS, SEA, CAVERN
# [12] GENTLEMAN, POOR LAW, BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN, FESTIVE
#      SEASON, FUND, COMPANY, GREAT FAT MAN, RED-FACED GENTLEMAN
# [13] HALL, ECHOES, SCHOOLMASTER, CHAIS, GARDEN SWEEP, YOUNG PEOPLE, DECANTER,
#      BLOCK OF CAKE
# [14] HOLLY, UNEARTHLY VISITOR, FIGURE, LIGHT, TUNIC, SUMMER FLOWERS, BELT
# [15] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [16] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [17] SULTAN'S GROOM, PRINCESS, GENII
# [18] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [19] CHAMBERS, OFFICES
# [20] SISTERS, GUESTS
# [21] WINDOWS, HOUSE-FRONTS
# [22] GATEWAY, FOG AND FROST
# [23] VALENTINE, ORSON
# [24] MEAGRE SERVANT, POSTBOY

# %%
import matplotlib.pyplot as plt
resolution_parameters = list(np.linspace(0, 1, 1000))
modularity_scores = []

for resolution in resolution_parameters:
    partition = leidenalg.find_partition(igraph, la.CPMVertexPartition,
                                         resolution_parameter=resolution)
    modularity_score = igraph.modularity(partition)
    modularity_scores.append(modularity_score)
    
plt.figure(figsize=(10, 6))
plt.plot(resolution_parameters, modularity_scores, marker='o')
plt.title('Modularity Score vs. Resolution Parameter')
plt.xlabel('Resolution Parameter')
plt.ylabel('Modularity Score')
plt.xlim(0, 1)  
plt.ylim(min(modularity_scores), max(modularity_scores))  
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
resolution_parameters = list(np.linspace(0, 0.05, 1000))
modularity_scores = []

for resolution in resolution_parameters:
    partition = leidenalg.find_partition(igraph, la.CPMVertexPartition,
                                         resolution_parameter=resolution)
    modularity_score = igraph.modularity(partition)
    modularity_scores.append(modularity_score)
    
plt.figure(figsize=(10, 6))
plt.plot(resolution_parameters, modularity_scores, marker='o')
plt.title('Modularity Score vs. Resolution Parameter')
plt.xlabel('Resolution Parameter')
plt.ylabel('Modularity Score')
plt.xlim(0, 0.05)  
plt.ylim(min(modularity_scores), max(modularity_scores)+0.1)  
plt.grid(True)
plt.show()

# %%
max_modularity3 = max(modularity_scores)
max_index3 = modularity_scores.index(max_modularity3)
optimal_resolution3 = resolution_parameters[max_index3]

print(f"Optimal Resolution Parameter: {optimal_resolution3}")
print(f"Maximum Modularity Score: {max_modularity3}")
# Out:
# Optimal Resolution Parameter: 0.005605605605605606
# Maximum Modularity Score: 0.6539888640595564

# %%
import leidenalg as la
import igraph as ig

igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition4_optimal = la.find_partition(igraph, la.CPMVertexPartition,resolution_parameter=0.005605605605605606)
modularity_score_igraph4_optimal = igraph.modularity(partition4_optimal)  
print(f"Modularity Score from CPMVertexPartition: {modularity_score_igraph4_optimal}")
# Out:
# Modularity Score from CPMVertexPartition: 0.6533204713554422

# %%
print(partition4_optimal)
# Out:
# Clustering with 610 elements and 26 clusters
# [ 0] SCROOGE, SHIP, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, HEART,
#      PARLIAMENT, BEDLAM, GENTLEMEN, UNION WORKHOUSES, TREADMILL, POPULATION,
#      ST. DUNSTAN, HAT, TAVERN, DECEASED PARTNER, BANKER'S BOOK, CITY OF
#      LONDON, KEY, WINE-MERCHANT, STAIRS, GRUEL, SITTING-ROOM, BEDROOM, LUMBER-
#      ROOM, DRESSING-GOWN, SLIPPERS, CAINS, ABELS, PHARAOH'S DAUGHTERS, QUEENS
#      OF SHEBA, ANGELIC MESSENGERS, ABRAHAMS, BELSHAZZARS, APOSTLES, BUTTER-
#      BOATS, SENSES, BEEF, MUSTARD, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE,
#      WARD, WISE MEN, POOR ABODE, CROWD, INVISIBLE WORLD, WINDOW, CHAMBER,
#      TIME, THE VISITATION, THE CLOCK, THE CHIME, THE QUARTER, HOUR BELL,
#      CURTAINS, WELFARE, BRIDGE, RIVER, MANSION, TRAVELLERS, HIGH-ROAD, LANE,
#      MANSION OF DULL RED BRICK, ALI BABA, POPPLAR, DAMASCUS, ROBIN CRUSOE,
#      FRIDAY, PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL, DOWERLESS GIRL, HEAVEN,
#      BRAIDED HAIR, LITTLE SHOE, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT,
#      TRANSFORMATION, GESE, PLUM-PUDDINGS, TWELFTH-CAKES, CITY STREETS, CHURCH
#      AND CHAPEL, INCENSE, TORCH, POOR MAN'S CHILD, HELMSMAN, LOOK-OUT,
#      OFFICERS, POOR CLERK, AROMATIC VINEGAR, MOLDY OLD OFFICE, DUSTY CHAMBERS,
#      LONDON, BUSINESSMEN, SHADOW, HOUSES, FURNITURE, PRESENT, CHRISTMAS TIME,
#      BEDPOST, WANDERING SPIRITS, LAOCOON, CHURCHES, CORNER, POULTERER, TURKEY,
#      CAB, SCROOGE AND MARLEY'S, PORTLY GENTLEMAN, TANK
# [ 1] EBENEZER SCROOGE, GHOST, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME,
#      GHOST OF JACOB MARLEY, DICK WILKINS, CHRISTMAS EVE, FEZZIWIG'S BALL,
#      JACOB MARLEY, THE THREE SPIRITS, SCROOGE AND MARLEY, HAMLET, NIGHT,
#      SCROOGE'S HOUSE, CHAIN, MONEY-CHANGING HOLE, MARLEY, FIRST OF EXCHANGE,
#      FEZZIWIG, FIREPLACE, HAPPINESS, THREE SPIRITS, TWELVE, STAVE TWO, DICK,
#      BAKER'S, SURPLUS POPULATION, BLAZE, LAMPLIGHTER, SPIRIT'S ROBE, MRS.
#      FEZZIWIG, WAREHOUSE, WELSH WIG, EBENEZER, WINTER BALL, DANCE EVENT,
#      DANCE, COLD ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER
#      DE COVERLEY, DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL, STAVE ONE,
#      BAKER, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL REGISTER,
#      GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, DARK CELLAR, DUTCH MERCHANT, MISS
#      FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID, COOK, MILKMAN
# [ 2] BOB CRATCHIT, TINY TIM, SPECTRE, MERRY CHRISTMAS, CHILD, MR. SCROOGE,
#      PETER CRATCHIT, TIM CRATCHIT, MRS. CRATCHIT, BELINDA CRATCHIT, MARTHA
#      CRATCHIT, THE CRATCHIT FAMILY, CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG
#      CRATCHITS, CLOSET DOOR, CHRISTMAS DINNER, CHRISTMAS DAY, PETER,
#      CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS, OFFICE, COAL-SCUTTLE, GOOSE,
#      FIRE, BELINDA, CHRISTMAS PUDDING, BOB, CHRISTMAS PARTY, OLD GENTLEMAN,
#      BRAZIER, RAGGED MEN AND BOYS, GHOST OF CHRISTMAS, HAPPY END, CRATCHITS,
#      MARTHA, PUDDING, CHIMNEY CORNER, SPIRITS, TOTAL-ABSTINENCE PRINCIPLE,
#      GLOBE, YOUNGEST CRATCHITS, SAGE AND ONION, HEARTH, CLOTH, FIRST PARTING,
#      SPIRIT OF TINY TIM, HOLIDAY, MILLINER, COUNTESS, LORD, WASH-HOUSE,
#      SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE, NINE O'CLOCK,
#      COPPER
# [ 3] GHOST OF CHRISTMAS PAST, BELLE, SPIRIT, CHURCHYARD, GRAVE, PEOPLE,
#      SCOURGE, TWELFTH-NIGHT PARTY, CHILDREN, FAMILY, YOUNG GIRL, IDOL, HIGH
#      DESK, MASTER OF THE HOUSE, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS,
#      HOUSE, COMELY MATRON, MOTHER, CHAOS, CHRISTMAS HOLIDAYS, SPIRIT OF
#      CHRISTMAS YET TO COME, PAST, FUTURE, CANDLES, COURT, SNOW, CLIMATE,
#      SNOWBALL FIGHT, WICKER BASKETS, DINNERS, ALMSHOUSE, HOSPITAL, GAOL,
#      POVERTY, IGNORANCE, WANT, DEVILS, ANGELS, WORKHOUSES, MYSTERY, STREET,
#      WEALTH, DAUGHTER, BROWN-PAPER PARCELS, MARRIED SISTERS, BROTHERS,
#      COUSINS, UNCLES, AUNTS, SNOWSTORMS
# [ 4] FAN, CHRISTMAS, FATHER, BOY, LORD MAYOR, MANSION HOUSE, POULTERERS,
#      GROCERS, TAILOR, RAGGED MEN, BOYS, BERRIES, PORTER, IVY, THRONE, RED
#      BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES,
#      OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH, CUSTOMERS, GROCER, MARKET-TOWN,
#      LITTLE FAN, POULTERER'S, FIFTY COOKS AND BUTLERS, FISH, ALMONDS,
#      CINNAMON, RAISINS, TEA, COFFEE, FARMERS, COACH, FIDDLER, SPICES,
#      CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 5] PROJECT GUTENBERG, FULL LICENSE, PROJECT GUTENBERG LITERARY ARCHIVE
#      FOUNDATION, ELECTRONIC WORKS, TERMS OF THIS AGREEMENT, UNITED STATES,
#      WORLD, PROJECT GUTENBERG LICENSE, COPYRIGHT HOLDER, ELECTRONIC WORK,
#      USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII, COPYRIGHT, ROYALTY FEE,
#      COPYRIGHT LAW, PARAGRAPH 1.F.3, AGREEMENT, FOUNDATION, GUTENBERG LITERARY
#      ARCHIVE FOUNDATION, MICHAEL S. HART, WWW.GUTENBERG.ORG, EBOOK, VOLUNTEER,
#      DONATION, ADDRESS, DERIVATIVE WORKS, REFUND, PERSON, ENTITY, DONATIONS,
#      U.S. FEDERAL LAWS, TAX EXEMPT STATUS, IRS, PUBLIC DOMAIN, FREE ACCESS,
#      DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN EXPLANATION,
#      DEFECTIVE WORK, PHYSICAL MEDIUM, CHARITABLE DONATIONS, COMPLIANCE
#      REQUIREMENTS, SALT LAKE CITY, INTERNAL REVENUE SERVICE, MISSISSIPPI
# [ 6] DEATH, LAUGHTER, JOE, OLD SCRATCH, BED-CURTAINS, WOMAN, FIRST WOMAN,
#      CAROLINE, HUSBAND, MAN, DEBT, MRS. DILBER, LAUNDRESS, PARLOUR, DECEASED
#      MAN, OLD JOE, HAMLET'S FATHER, DINNER, CORPSE, SPOIL, CONTRACT,
#      ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT, LAMPLIGHT, CHARWOMAN,
#      UNDERTAKER'S MAN, DESSERT, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS,
#      BROOCH, SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [ 7] FRED, GHOST OF CHRISTMAS PRESENT, SCROOGE'S NIECE, PARTY, GOOD-HUMOUR,
#      SISTER, MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER, SCROOGE'S
#      NEPHEW, GENTLEMAN, POOR LAW, SCROOGE'S NIECE'S SISTERS, BUSINESS MEN,
#      FUNERAL, MAN WITH LARGE CHIN, FESTIVE SEASON, FUND, COMPANY, SCROOGE'S
#      NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL, GAME OF HOW, WHEN, AND
#      WHERE, MUSIC, BLIND MAN'S-BUFF, BLIND MAN, GAMES, GREAT FAT MAN, RED-
#      FACED GENTLEMAN
# [ 8] PHANTOM, PORCH, TOWN, SELF, HOLLY SPRIGS, ANCIENT TOWER, ROOM, CLOCK,
#      COLD, BED, WINTER FIRE, BODY, TERRORS, STAVE FOUR, MAIN STREET, GAS-
#      PIPES, UNKNOWN, GLOOM, GRAVES, MULTITUDES, LOW-BROWED SHOP, INFAMOUS
#      RESORT, NARROW ALLEYS, ARCHWAYS, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 9] COUNTING-HOUSE, MIST, CORNHILL, CLERK, CITY, STREETS, CANDLE, DARKNESS,
#      WINTER DAY, CAMDEN TOWN, MASTER, FIFTEEN SHILLINGS, CHANGE, MONEY,
#      MERCHANTS, FOG, FLOGGING LINKS, CARTS AND WAGONS, GOLD SEALS
# [10] MASTER SCROOGE, DINING-ROOM, NEPHEW, HALL, YES AND NO, GIRL, ANIMAL,
#      MISTRESS, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG
#      PEOPLE, DECANTER, BLOCK OF CAKE, YOUNG HOUSEKEEPERS
# [11] MISTLETOE, CHESTNUTS, POULTERERS' SHOPS, FRUITERERS, NORFOLK BIFFINS,
#      SPANISH ONIONS, SHOPKEEPERS, PEARS, APPLES, GRAPES, FILBERTS, ORANGES,
#      LEMONS, BASKETS, FRUITS, VEGETABLES
# [12] MOOR, FROST, OLD MAN, LIGHTHOUSE, TWO MEN, MINERS, CHEERFUL COMPANY,
#      SETTING SUN, HUT, CHRISTMAS SONG, WATER, STORM-BIRDS, SEA, CAVERN
# [13] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#      PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, CHURCH, GHOSTS,
#      WOMAN WITH INFANT
# [14] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#      YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#      TEAM, J. B. LIPPINCOTT COMPANY, GREAT BRITAIN
# [15] HOLLY, UNEARTHLY VISITOR, FIGURE, LIGHT, TUNIC, SUMMER FLOWERS, BELT
# [16] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#      BLACK, SHOP, CHARCOAL STOVE
# [17] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [18] SULTAN'S GROOM, PRINCESS, GENII
# [19] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [20] GATEWAY, FOG AND FROST
# [21] VALENTINE, ORSON
# [22] WINDOWS, HOUSE-FRONTS
# [23] CHAMBERS, OFFICES
# [24] MEAGRE SERVANT, POSTBOY
# [25] SISTERS, GUESTS

# %% [markdown]
# # When resolution_parameter is 1.0, it treats every node as one community, when we decrease the parameter, the number of classes will decrease and the modularity score will increase first and decrease after achieve the maximum

# %%
import leidenalg as la
import igraph as ig

igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition4_6 = la.find_partition(igraph, la.CPMVertexPartition,resolution_parameter=3)
modularity_score_igraph4_6 = igraph.modularity(partition4_6)  
print(f"Modularity Score from CPMVertexPartition: {modularity_score_igraph4_6}")
# Out:
# Modularity Score from CPMVertexPartition: -0.013834956529483163

# %%
print(partition4_6)
# Out:
# Clustering with 610 elements and 610 clusters
# [  0] PROJECT GUTENBERG
# [  1] A CHRISTMAS CAROL
# [  2] FULL LICENSE
# [  3] PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION
# [  4] ELECTRONIC WORKS
# [  5] TERMS OF THIS AGREEMENT
# [  6] UNITED STATES
# [  7] WORLD
# [  8] PROJECT GUTENBERG LICENSE
# [  9] COPYRIGHT HOLDER
# [ 10] ELECTRONIC WORK
# [ 11] USER
# [ 12] GUTENBERG LICENSE
# [ 13] PLAIN VANILLA ASCII
# [ 14] COPYRIGHT
# [ 15] ROYALTY FEE
# [ 16] COPYRIGHT LAW
# [ 17] PARAGRAPH 1.F.3
# [ 18] AGREEMENT
# [ 19] FOUNDATION
# [ 20] GUTENBERG LITERARY ARCHIVE FOUNDATION
# [ 21] MICHAEL S. HART
# [ 22] WWW.GUTENBERG.ORG
# [ 23] EBOOK
# [ 24] VOLUNTEER
# [ 25] DONATION
# [ 26] CHARLES DICKENS
# [ 27] EBENEZER SCROOGE
# [ 28] ARTHUR RACKHAM
# [ 29] PHILADELPHIA
# [ 30] NEW YORK
# [ 31] SUZANNE SHELL
# [ 32] JANET BLENKINSHIP
# [ 33] ONLINE DISTRIBUTED PROOFREADING TEAM
# [ 34] J. B. LIPPINCOTT COMPANY
# [ 35] GHOST
# [ 36] GREAT BRITAIN
# [ 37] SCROOGE
# [ 38] BOB CRATCHIT
# [ 39] MR. FEZZIWIG
# [ 40] FRED
# [ 41] GHOST OF CHRISTMAS PAST
# [ 42] GHOST OF CHRISTMAS PRESENT
# [ 43] GHOST OF CHRISTMAS YET TO COME
# [ 44] GHOST OF JACOB MARLEY
# [ 45] DICK WILKINS
# [ 46] BELLE
# [ 47] FAN
# [ 48] MARLEY'S GHOST
# [ 49] CHRISTMAS EVE
# [ 50] FEZZIWIG'S BALL
# [ 51] JACOB MARLEY
# [ 52] THE THREE SPIRITS
# [ 53] CHRISTMAS
# [ 54] SCROOGE AND MARLEY
# [ 55] HAMLET
# [ 56] NIGHT
# [ 57] SCROOGE'S HOUSE
# [ 58] CHAIN
# [ 59] COUNTING-HOUSE
# [ 60] MONEY-CHANGING HOLE
# [ 61] MARLEY
# [ 62] BELL
# [ 63] FIRST OF EXCHANGE
# [ 64] FEZZIWIG
# [ 65] TINY TIM
# [ 66] SPIRIT
# [ 67] CHURCHYARD
# [ 68] PHANTOM
# [ 69] GRAVE
# [ 70] PEOPLE
# [ 71] FIREPLACE
# [ 72] HAPPINESS
# [ 73] JACOB
# [ 74] SPECTRE
# [ 75] THREE SPIRITS
# [ 76] TWELVE
# [ 77] STAVE TWO
# [ 78] MIST
# [ 79] MERRY CHRISTMAS
# [ 80] CHILD
# [ 81] MASTER SCROOGE
# [ 82] DICK
# [ 83] MR. SCROOGE
# [ 84] BAKER'S
# [ 85] SURPLUS POPULATION
# [ 86] BLAZE
# [ 87] LAMPLIGHTER
# [ 88] SCOURGE
# [ 89] SHIP
# [ 90] SCROOGE'S NIECE
# [ 91] PARTY
# [ 92] TWELFTH-NIGHT PARTY
# [ 93] CHILDREN
# [ 94] SPIRIT'S ROBE
# [ 95] PORCH
# [ 96] TOWN
# [ 97] SELF
# [ 98] PETER CRATCHIT
# [ 99] TIM CRATCHIT
# [100] MRS. CRATCHIT
# [101] BELINDA CRATCHIT
# [102] MARTHA CRATCHIT
# [103] CORNHILL
# [104] THE CRATCHIT FAMILY
# [105] CRATCHIT HOUSE
# [106] CRATCHIT FAMILY
# [107] YOUNG CRATCHITS
# [108] CLOSET DOOR
# [109] CHRISTMAS DINNER
# [110] CHRISTMAS DAY
# [111] PETER
# [112] DEATH
# [113] CRATCHIT'S HOUSE
# [114] CRATCHIT'S WIFE
# [115] GIRLS
# [116] OFFICE
# [117] FAMILY
# [118] COAL-SCUTTLE
# [119] GOOSE
# [120] MRS. FEZZIWIG
# [121] LAUGHTER
# [122] GOOD-HUMOUR
# [123] SISTER
# [124] MULLED WINE
# [125] DINING-ROOM
# [126] YOUNG GIRL
# [127] IDOL
# [128] UNCLE SCROOGE
# [129] TOPPER
# [130] PLUMP SISTER
# [131] WAREHOUSE
# [132] HIGH DESK
# [133] WELSH WIG
# [134] EBENEZER
# [135] WINTER BALL
# [136] DANCE EVENT
# [137] DANCE
# [138] COLD ROAST
# [139] COLD BOILED
# [140] MINCE-PIES
# [141] BEER
# [142] FESTIVITIES
# [143] SIR ROGER DE COVERLEY
# [144] DOMESTIC BALL
# [145] APPRENTICES
# [146] CHRISTMAS BALL
# [147] JOE
# [148] OLD SCRATCH
# [149] BED-CURTAINS
# [150] WOMAN
# [151] FIRST WOMAN
# [152] MASTER OF THE HOUSE
# [153] CAROLINE
# [154] HUSBAND
# [155] MAN
# [156] DEBT
# [157] FIRE
# [158] BELINDA
# [159] CHRISTMAS PUDDING
# [160] HOLLY
# [161] BOB
# [162] MRS. DILBER
# [163] LAUNDRESS
# [164] PARLOUR
# [165] DECEASED MAN
# [166] OLD JOE
# [167] FATHER
# [168] BOY
# [169] WINE-MERCHANT'S CELLAR
# [170] HAUNTED HOUSE
# [171] DOOR
# [172] PHANTOMS
# [173] BLEAK, DARK NIGHT
# [174] GUILTY GOVERNMENTS
# [175] CHAINS
# [176] CLERK
# [177] NEPHEW
# [178] SCROOGE'S NEPHEW
# [179] LORD MAYOR
# [180] MANSION HOUSE
# [181] POULTERERS
# [182] GROCERS
# [183] TAILOR
# [184] RAGGED MEN
# [185] BOYS
# [186] HOLLY SPRIGS
# [187] BERRIES
# [188] CITY
# [189] PORTER
# [190] MISTLETOE
# [191] IVY
# [192] THRONE
# [193] RED BERRIES
# [194] TURKEYS
# [195] GEESE
# [196] GAME
# [197] POULTRY
# [198] BRAWN
# [199] MEAT
# [200] PIGS
# [201] SAUSAGES
# [202] OYSTERS
# [203] PIES
# [204] PUDDINGS
# [205] FRUIT
# [206] PUNCH
# [207] CUSTOMERS
# [208] GROCER
# [209] BAKERS' SHOPS
# [210] STREETS
# [211] CHRISTMAS PARTY
# [212] MOOR
# [213] STAVE ONE
# [214] HAMLET'S FATHER
# [215] PARTNERSHIP
# [216] WINTER WEATHER
# [217] UNCLE
# [218] WORLD OF FOOLS
# [219] HEART
# [220] PARLIAMENT
# [221] BEDLAM
# [222] GENTLEMEN
# [223] GENTLEMAN
# [224] PRISONS
# [225] UNION WORKHOUSES
# [226] POOR LAW
# [227] TREADMILL
# [228] CHURCH
# [229] POPULATION
# [230] ANCIENT TOWER
# [231] ST. DUNSTAN
# [232] CANDLE
# [233] HAT
# [234] TAVERN
# [235] DECEASED PARTNER
# [236] BANKER'S BOOK
# [237] CITY OF LONDON
# [238] GATEWAY
# [239] CHAMBERS
# [240] KEY
# [241] WINE-MERCHANT
# [242] HALL
# [243] STAIRS
# [244] DARKNESS
# [245] GRUEL
# [246] SITTING-ROOM
# [247] BEDROOM
# [248] LUMBER-ROOM
# [249] DRESSING-GOWN
# [250] SLIPPERS
# [251] CAINS
# [252] ABELS
# [253] PHARAOH'S DAUGHTERS
# [254] QUEENS OF SHEBA
# [255] ANGELIC MESSENGERS
# [256] ABRAHAMS
# [257] BELSHAZZARS
# [258] APOSTLES
# [259] BUTTER-BOATS
# [260] ROOM
# [261] SENSES
# [262] BEEF
# [263] MUSTARD
# [264] CHEESE
# [265] POTATO
# [266] GRAVY
# [267] CHAIR
# [268] APPEARANCE
# [269] WARD
# [270] WISE MEN
# [271] POOR ABODE
# [272] CROWD
# [273] GHOSTS
# [274] INVISIBLE WORLD
# [275] WINDOW
# [276] CHAMBER
# [277] CLOCK
# [278] FROST
# [279] COLD
# [280] TIME
# [281] THE VISITATION
# [282] THE CLOCK
# [283] THE CHIME
# [284] THE QUARTER
# [285] HOUR BELL
# [286] CURTAINS
# [287] BED
# [288] UNEARTHLY VISITOR
# [289] FIGURE
# [290] WELFARE
# [291] WINTER DAY
# [292] COUNTRY ROAD
# [293] FIELDS
# [294] MARKET-TOWN
# [295] BRIDGE
# [296] RIVER
# [297] MANSION
# [298] TRAVELLERS
# [299] HIGH-ROAD
# [300] LANE
# [301] MANSION OF DULL RED BRICK
# [302] ALI BABA
# [303] HOUSE
# [304] POPPLAR
# [305] DAMASCUS
# [306] VALENTINE
# [307] ROBIN CRUSOE
# [308] FRIDAY
# [309] PARROT
# [310] CHRISTMAS CAROL
# [311] LITTLE FAN
# [312] FAIR YOUNG GIRL
# [313] DOWERLESS GIRL
# [314] HEAVEN
# [315] COMELY MATRON
# [316] WINTER FIRE
# [317] MOTHER
# [318] CHAOS
# [319] BRAIDED HAIR
# [320] LITTLE SHOE
# [321] EXTINGUISHER-CAP
# [322] ONE
# [323] GHOSTLY LIGHT
# [324] TRANSFORMATION
# [325] GESE
# [326] PLUM-PUDDINGS
# [327] TWELFTH-CAKES
# [328] CHESTNUTS
# [329] CITY STREETS
# [330] CHURCH AND CHAPEL
# [331] BAKER
# [332] INCENSE
# [333] TORCH
# [334] DINNER
# [335] POOR MAN'S CHILD
# [336] OLD MAN
# [337] HELMSMAN
# [338] LOOK-OUT
# [339] OFFICERS
# [340] SCROOGE'S NIECE'S SISTERS
# [341] POOR CLERK
# [342] AROMATIC VINEGAR
# [343] MOLDY OLD OFFICE
# [344] DUSTY CHAMBERS
# [345] SISTERS
# [346] YES AND NO
# [347] LONDON
# [348] CHRISTMAS HOLIDAYS
# [349] SPIRIT OF CHRISTMAS YET TO COME
# [350] BUSINESS MEN
# [351] BUSINESSMEN
# [352] CORPSE
# [353] SPOIL
# [354] BODY
# [355] TERRORS
# [356] SHADOW
# [357] HOUSES
# [358] FURNITURE
# [359] PAST
# [360] PRESENT
# [361] FUTURE
# [362] CHRISTMAS TIME
# [363] BEDPOST
# [364] WANDERING SPIRITS
# [365] LAOCOON
# [366] CHURCHES
# [367] CORNER
# [368] POULTERER'S
# [369] POULTERER
# [370] ADDRESS
# [371] CAMDEN TOWN
# [372] TURKEY
# [373] KNOCKER
# [374] CAB
# [375] SCROOGE AND MARLEY'S
# [376] PORTLY GENTLEMAN
# [377] OLD GENTLEMAN
# [378] GIRL
# [379] TANK
# [380] CONTRACT
# [381] ASPIRATIONS
# [382] INDUSTRY
# [383] BLANKETS
# [384] SHIRT
# [385] CLERGYMAN
# [386] UNDERTAKER
# [387] CHIEF MOURNER
# [388] BURIAL REGISTER
# [389] FUNERAL
# [390] GHOSTLY SPECTACLES
# [391] WAISTCOAT
# [392] PIGTAIL
# [393] MASTER
# [394] FIFTEEN SHILLINGS
# [395] STAVE FOUR
# [396] MAN WITH LARGE CHIN
# [397] CANDLES
# [398] CHANGE
# [399] MONEY
# [400] MERCHANTS
# [401] COURT
# [402] SNOW
# [403] CLIMATE
# [404] SNOWBALL FIGHT
# [405] POULTERERS' SHOPS
# [406] FRUITERERS
# [407] WICKER BASKETS
# [408] DINNERS
# [409] ANIMAL
# [410] MISTRESS
# [411] WINDOWS
# [412] HOUSE-FRONTS
# [413] FOG
# [414] FLOGGING LINKS
# [415] FESTIVE SEASON
# [416] FUND
# [417] COMPANY
# [418] MAIN STREET
# [419] GAS-PIPES
# [420] BRAZIER
# [421] RAGGED MEN AND BOYS
# [422] LIGHTHOUSE
# [423] TWO MEN
# [424] FIFTY COOKS AND BUTLERS
# [425] NORFOLK BIFFINS
# [426] FISH
# [427] ALMONDS
# [428] CINNAMON
# [429] RAISINS
# [430] TEA
# [431] COFFEE
# [432] FARMERS
# [433] FOG AND FROST
# [434] OFFICES
# [435] DARK CELLAR
# [436] ECHOES
# [437] SCHOOLMASTER
# [438] DUTCH MERCHANT
# [439] UNKNOWN
# [440] LIGHT
# [441] MINERS
# [442] CHEERFUL COMPANY
# [443] ALMSHOUSE
# [444] HOSPITAL
# [445] GAOL
# [446] POVERTY
# [447] IGNORANCE
# [448] WANT
# [449] DEVILS
# [450] ANGELS
# [451] WORKHOUSES
# [452] MYSTERY
# [453] STREET
# [454] GLOOM
# [455] GRAVES
# [456] MANKIND
# [457] CHARITY
# [458] MERCY
# [459] FORBEARANCE
# [460] BENEVOLENCE
# [461] WOMAN WITH INFANT
# [462] MULTITUDES
# [463] SETTING SUN
# [464] TUNIC
# [465] SUMMER FLOWERS
# [466] BELT
# [467] COACH
# [468] SULTAN'S GROOM
# [469] PRINCESS
# [470] GENII
# [471] ORSON
# [472] CHAIS
# [473] SCHOOL
# [474] GARDEN SWEEP
# [475] YOUNG PEOPLE
# [476] DECANTER
# [477] BLOCK OF CAKE
# [478] MEAGRE SERVANT
# [479] POSTBOY
# [480] MISS FEZZIWIG
# [481] YOUNG FOLLOWERS
# [482] HOUSEMAID
# [483] COOK
# [484] MILKMAN
# [485] FIDDLER
# [486] WEALTH
# [487] DAUGHTER
# [488] BROWN-PAPER PARCELS
# [489] MARRIED SISTERS
# [490] BROTHERS
# [491] COUSINS
# [492] UNCLES
# [493] AUNTS
# [494] DOLL'S FRYING PAN
# [495] BABY
# [496] WOODEN PLATTER
# [497] GHOST OF CHRISTMAS
# [498] HAPPY END
# [499] SNOWSTORMS
# [500] CARTS AND WAGONS
# [501] SPANISH ONIONS
# [502] SHOPKEEPERS
# [503] PEARS
# [504] APPLES
# [505] GRAPES
# [506] FILBERTS
# [507] ORANGES
# [508] LEMONS
# [509] BASKETS
# [510] FRUITS
# [511] VEGETABLES
# [512] SPICES
# [513] CANISTERS
# [514] CANDIED FRUITS
# [515] FIGS
# [516] FRENCH PLUMS
# [517] CRATCHITS
# [518] LAMPLIGHT
# [519] LOW-BROWED SHOP
# [520] INFAMOUS RESORT
# [521] NARROW ALLEYS
# [522] ARCHWAYS
# [523] MARTHA
# [524] PUDDING
# [525] CHIMNEY CORNER
# [526] SPIRITS
# [527] TOTAL-ABSTINENCE PRINCIPLE
# [528] GLOBE
# [529] YOUNGEST CRATCHITS
# [530] SAGE AND ONION
# [531] HEARTH
# [532] CLOTH
# [533] FIRST PARTING
# [534] SPIRIT OF TINY TIM
# [535] HOLIDAY
# [536] MILLINER
# [537] COUNTESS
# [538] LORD
# [539] WASH-HOUSE
# [540] SUNDAY
# [541] GREEN PLACE
# [542] MR. SCROOGE'S NEPHEW
# [543] GOOD WIFE
# [544] NINE O'CLOCK
# [545] COPPER
# [546] HUT
# [547] CHRISTMAS SONG
# [548] WATER
# [549] STORM-BIRDS
# [550] SEA
# [551] CAVERN
# [552] SCROOGE'S NIECE'S SISTER
# [553] HARP
# [554] LARGE CHAIR
# [555] FOOTSTOOL
# [556] GAME OF HOW, WHEN, AND WHERE
# [557] CHARWOMAN
# [558] UNDERTAKER'S MAN
# [559] MUSIC
# [560] BLIND MAN'S-BUFF
# [561] DESSERT
# [562] BLIND MAN
# [563] GAMES
# [564] GUESTS
# [565] GOLD SEALS
# [566] GREAT FAT MAN
# [567] RED-FACED GENTLEMAN
# [568] RAGS
# [569] BOTTLES
# [570] BONES
# [571] GREASY OFFAL
# [572] KEYS
# [573] GREY-HAIRED RASCAL
# [574] WOMAN WITH HEAVY BUNDLE
# [575] SECOND WOMAN
# [576] MAN IN FADED BLACK
# [577] SHOP
# [578] CHARCOAL STOVE
# [579] BUNDLE
# [580] SEAL
# [581] PENCIL-CASE
# [582] SLEEVE-BUTTONS
# [583] BROOCH
# [584] SHEETS
# [585] TOWELS
# [586] SILVER TEASPOONS
# [587] SUGAR-TONGS
# [588] BOOTS
# [589] YOUNG HOUSEKEEPERS
# [590] DERIVATIVE WORKS
# [591] REFUND
# [592] PERSON
# [593] ENTITY
# [594] DONATIONS
# [595] U.S. FEDERAL LAWS
# [596] TAX EXEMPT STATUS
# [597] IRS
# [598] PUBLIC DOMAIN
# [599] FREE ACCESS
# [600] DEFECT IN ELECTRONIC WORK
# [601] REPLACEMENT COPY
# [602] WRITTEN EXPLANATION
# [603] DEFECTIVE WORK
# [604] PHYSICAL MEDIUM
# [605] CHARITABLE DONATIONS
# [606] COMPLIANCE REQUIREMENTS
# [607] SALT LAKE CITY
# [608] INTERNAL REVENUE SERVICE
# [609] MISSISSIPPI

# %% [markdown]
# # (5): SignificanceVertexPartition
# # 149 clusters; not suitable for weighted graphs
# ## Implements Significance. This quality function is well-defined only for unweighted graphs.

# %%
import leidenalg as la
import igraph as ig

igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition5 = la.find_partition(igraph, la.SignificanceVertexPartition)
modularity_score_igraph5 = igraph.modularity(partition5)  
print(f"Modularity Score from SignificanceVertexPartition: {modularity_score_igraph5}")
# Out:
# Modularity Score from SignificanceVertexPartition: 0.5119997164669967

# %%
print(partition5)
# Out:
# Clustering with 610 elements and 149 clusters
# [  0] SCROOGE, PARTNERSHIP, WINTER WEATHER, UNCLE, WORLD OF FOOLS, BEDLAM, ST.
#       DUNSTAN, TAVERN, BANKER'S BOOK, WINE-MERCHANT, STAIRS, SITTING-ROOM,
#       BEDROOM, DRESSING-GOWN, CAINS, ABELS, QUEENS OF SHEBA, ABRAHAMS, BUTTER-
#       BOATS, SENSES, CHEESE, POTATO, GRAVY, CHAIR, APPEARANCE, WARD, WISE MEN,
#       POOR ABODE, CROWD, INVISIBLE WORLD, WINDOW, CHAMBER, THE VISITATION,
#       HOUR BELL, CURTAINS, WELFARE, BRIDGE, RIVER, MANSION, HIGH-ROAD, ALI
#       BABA, POPPLAR, DAMASCUS, PARROT, CHRISTMAS CAROL, FAIR YOUNG GIRL,
#       HEAVEN, EXTINGUISHER-CAP, ONE, GHOSTLY LIGHT, TRANSFORMATION, PLUM-
#       PUDDINGS, CITY STREETS, CHURCH AND CHAPEL, INCENSE, TORCH, AROMATIC
#       VINEGAR, MOLDY OLD OFFICE, LONDON, SHADOW, FURNITURE, PRESENT, CHRISTMAS
#       TIME, BEDPOST, LAOCOON, CHURCHES, POULTERER, TURKEY, CAB, PORTLY
#       GENTLEMAN, TANK
# [  1] CHRISTMAS, POULTERERS, TAILOR, RAGGED MEN, BERRIES, IVY, THRONE, RED
#       BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES,
#       OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH
# [  2] BOB CRATCHIT, TINY TIM, PETER CRATCHIT, MRS. CRATCHIT, BELINDA CRATCHIT,
#       MARTHA CRATCHIT, CRATCHIT FAMILY, YOUNG CRATCHITS, CHRISTMAS DINNER,
#       CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE, CRATCHIT'S WIFE, GIRLS, GOOSE,
#       BELINDA, CHRISTMAS PARTY, CRATCHITS
# [  3] SPIRIT, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS, CHRISTMAS
#       HOLIDAYS, PAST, FUTURE, ALMSHOUSE, HOSPITAL, GAOL, IGNORANCE, WANT,
#       DEVILS, ANGELS, WORKHOUSES, MYSTERY
# [  4] PROJECT GUTENBERG, FULL LICENSE, TERMS OF THIS AGREEMENT, WORLD, PROJECT
#       GUTENBERG LICENSE, COPYRIGHT HOLDER, USER, GUTENBERG LICENSE, PLAIN
#       VANILLA ASCII, COPYRIGHT, ROYALTY FEE, AGREEMENT, MICHAEL S. HART,
#       EBOOK, VOLUNTEER, DONATION
# [  5] GHOST, JACOB MARLEY, CHAIN, HAPPINESS, SPECTRE, THREE SPIRITS, TWELVE,
#       STAVE TWO, BAKER'S, SURPLUS POPULATION, BLAZE, LAMPLIGHTER, TWELFTH-
#       NIGHT PARTY, SPIRIT'S ROBE
# [  6] CHRISTMAS EVE, FEZZIWIG, MRS. FEZZIWIG, WELSH WIG, DANCE, COLD ROAST,
#       COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER DE COVERLEY,
#       DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL
# [  7] EBENEZER SCROOGE, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF
#       JACOB MARLEY, DICK WILKINS, FEZZIWIG'S BALL, THE THREE SPIRITS, HAMLET,
#       NIGHT, SCROOGE'S HOUSE, MONEY-CHANGING HOLE, FIRST OF EXCHANGE,
#       CHURCHYARD, GRAVE
# [  8] MISTLETOE, FRUITERERS, SPANISH ONIONS, SHOPKEEPERS, PEARS, APPLES,
#       GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS, VEGETABLES
# [  9] SCROOGE'S NIECE, UNCLE SCROOGE, TOPPER, SCROOGE'S NEPHEW, SCROOGE'S
#       NIECE'S SISTERS, SCROOGE'S NIECE'S SISTER, HARP, LARGE CHAIR, FOOTSTOOL,
#       GAME OF HOW, WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF
# [ 10] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#       PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, GHOSTS, WOMAN
#       WITH INFANT
# [ 11] PHANTOM, PORCH, ROOM, COLD, WINTER FIRE, BODY, TERRORS, STAVE FOUR,
#       GLOOM, GRAVES
# [ 12] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#       YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#       TEAM, J. B. LIPPINCOTT COMPANY
# [ 13] MARLEY, STAVE ONE, CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL
#       REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL
# [ 14] CHILD, WOMAN, CORPSE, SPOIL, CONTRACT, ASPIRATIONS, INDUSTRY, BLANKETS,
#       SHIRT
# [ 15] FRED, GHOST OF CHRISTMAS PRESENT, PARTY, CRATCHIT HOUSE, GOOD-HUMOUR,
#       MULLED WINE, PLUMP SISTER, GAMES
# [ 16] MASTER SCROOGE, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP, YOUNG PEOPLE,
#       DECANTER, BLOCK OF CAKE
# [ 17] ELECTRONIC WORK, REFUND, PERSON, ENTITY, REPLACEMENT COPY, WRITTEN
#       EXPLANATION, DEFECTIVE WORK, PHYSICAL MEDIUM
# [ 18] WINTER BALL, DANCE EVENT, BAKER, MISS FEZZIWIG, YOUNG FOLLOWERS,
#       HOUSEMAID, COOK, MILKMAN
# [ 19] CHILDREN, FAMILY, BROWN-PAPER PARCELS, MARRIED SISTERS, BROTHERS,
#       COUSINS, UNCLES, AUNTS
# [ 20] GROCERS, NORFOLK BIFFINS, FISH, ALMONDS, CINNAMON, RAISINS, TEA, COFFEE
# [ 21] FIRE, BRAZIER, RAGGED MEN AND BOYS, LIGHTHOUSE, TWO MEN, STORM-BIRDS,
#       SEA
# [ 22] LAUGHTER, MRS. DILBER, LAUNDRESS, PARLOUR, OLD JOE, CHARWOMAN,
#       UNDERTAKER'S MAN
# [ 23] MERRY CHRISTMAS, MR. SCROOGE, THE CRATCHIT FAMILY, OFFICE, OLD
#       GENTLEMAN, GHOST OF CHRISTMAS, HAPPY END
# [ 24] CUSTOMERS, GROCER, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 25] PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION, UNITED STATES,
#       WWW.GUTENBERG.ORG, ADDRESS, DONATIONS, U.S. FEDERAL LAWS, IRS
# [ 26] BOB, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE,
#       NINE O'CLOCK
# [ 27] COUNTING-HOUSE, CORNHILL, CLERK, CANDLE, CAMDEN TOWN, MASTER, FIFTEEN
#       SHILLINGS
# [ 28] GHOST OF CHRISTMAS PAST, YOUNG GIRL, IDOL, COMELY MATRON, POVERTY,
#       WEALTH
# [ 29] FAN, FATHER, BOY, LITTLE FAN, POULTERER'S, COACH
# [ 30] GREAT BRITAIN, PEOPLE, CLIMATE, SNOWBALL FIGHT, WICKER BASKETS, DINNERS
# [ 31] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [ 32] LOW-BROWED SHOP, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 33] CITY, CHANGE, MONEY, MERCHANTS, GOLD SEALS
# [ 34] BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN, GREAT FAT MAN, RED-FACED
#       GENTLEMAN
# [ 35] BELLE, MASTER OF THE HOUSE, HOUSE, SNOW, SNOWSTORMS
# [ 36] GENTLEMAN, POOR LAW, FESTIVE SEASON, FUND, COMPANY
# [ 37] MARTHA, HOLIDAY, MILLINER, COUNTESS, LORD
# [ 38] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#       BLACK, SHOP
# [ 39] MIST, STREETS, WINTER DAY, CARTS AND WAGONS
# [ 40] JOE, OLD SCRATCH, BED-CURTAINS, FIRST WOMAN
# [ 41] MOOR, FROST, MINERS, SETTING SUN
# [ 42] DINING-ROOM, GIRL, MISTRESS, YOUNG HOUSEKEEPERS
# [ 43] OLD MAN, CHEERFUL COMPANY, HUT, CHRISTMAS SONG
# [ 44] SHIP, HELMSMAN, LOOK-OUT, OFFICERS
# [ 45] TOWN, INFAMOUS RESORT, NARROW ALLEYS, ARCHWAYS
# [ 46] CAROLINE, HUSBAND, MAN, DEBT
# [ 47] SELF, CHURCH, CLOCK, MULTITUDES
# [ 48] FIGURE, TUNIC, SUMMER FLOWERS, BELT
# [ 49] HOLLY SPRIGS, ANCIENT TOWER, MAIN STREET, GAS-PIPES
# [ 50] FOUNDATION, TAX EXEMPT STATUS, CHARITABLE DONATIONS, COMPLIANCE
#       REQUIREMENTS
# [ 51] GUTENBERG LITERARY ARCHIVE FOUNDATION, SALT LAKE CITY, INTERNAL REVENUE
#       SERVICE, MISSISSIPPI
# [ 52] SCOURGE, SPIRIT OF CHRISTMAS YET TO COME, CANDLES, COURT
# [ 53] LORD MAYOR, MANSION HOUSE, FIFTY COOKS AND BUTLERS
# [ 54] NEPHEW, YES AND NO, ANIMAL
# [ 55] ELECTRONIC WORKS, DERIVATIVE WORKS, FREE ACCESS
# [ 56] DEATH, DECEASED MAN, HAMLET'S FATHER
# [ 57] BOYS, MARKET-TOWN, FARMERS
# [ 58] DARKNESS, FOG, FLOGGING LINKS
# [ 59] BED, UNKNOWN, LIGHT
# [ 60] SULTAN'S GROOM, PRINCESS, GENII
# [ 61] MOTHER, CHAOS, DAUGHTER
# [ 62] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [ 63] DINNER, LAMPLIGHT, DESSERT
# [ 64] PORTER, FIDDLER
# [ 65] DICK, EBENEZER
# [ 66] PARAGRAPH 1.F.3, DEFECT IN ELECTRONIC WORK
# [ 67] SCROOGE AND MARLEY, WAREHOUSE
# [ 68] HOLLY, UNEARTHLY VISITOR
# [ 69] HIGH DESK, STREET
# [ 70] CHRISTMAS PUDDING, COPPER
# [ 71] GENTLEMEN, POPULATION
# [ 72] CHAMBERS, OFFICES
# [ 73] VALENTINE, ORSON
# [ 74] CHESTNUTS, POULTERERS' SHOPS
# [ 75] WINDOWS, HOUSE-FRONTS
# [ 76] GATEWAY, FOG AND FROST
# [ 77] KNOCKER, DARK CELLAR
# [ 78] HALL, ECHOES
# [ 79] FIREPLACE, DUTCH MERCHANT
# [ 80] MEAGRE SERVANT, POSTBOY
# [ 81] WATER, CAVERN
# [ 82] SISTERS, GUESTS
# [ 83] COPYRIGHT LAW, PUBLIC DOMAIN
# [ 84] SISTER, BLIND MAN
# [ 85] CLOSET DOOR
# [ 86] YOUNGEST CRATCHITS
# [ 87] TIM CRATCHIT
# [ 88] FIRST PARTING
# [ 89] CLOTH
# [ 90] PENCIL-CASE
# [ 91] HEART
# [ 92] PARLIAMENT
# [ 93] UNION WORKHOUSES
# [ 94] TREADMILL
# [ 95] HAT
# [ 96] DECEASED PARTNER
# [ 97] CITY OF LONDON
# [ 98] KEY
# [ 99] GRUEL
# [100] LUMBER-ROOM
# [101] SLIPPERS
# [102] PHARAOH'S DAUGHTERS
# [103] ANGELIC MESSENGERS
# [104] BELSHAZZARS
# [105] APOSTLES
# [106] BEEF
# [107] MUSTARD
# [108] TIME
# [109] THE CLOCK
# [110] THE CHIME
# [111] THE QUARTER
# [112] TRAVELLERS
# [113] LANE
# [114] MANSION OF DULL RED BRICK
# [115] ROBIN CRUSOE
# [116] FRIDAY
# [117] DOWERLESS GIRL
# [118] BRAIDED HAIR
# [119] LITTLE SHOE
# [120] GESE
# [121] TWELFTH-CAKES
# [122] POOR MAN'S CHILD
# [123] POOR CLERK
# [124] DUSTY CHAMBERS
# [125] BUSINESSMEN
# [126] HOUSES
# [127] WANDERING SPIRITS
# [128] CORNER
# [129] SCROOGE AND MARLEY'S
# [130] GLOBE
# [131] SAGE AND ONION
# [132] HEARTH
# [133] SPIRIT OF TINY TIM
# [134] CHARCOAL STOVE
# [135] BUNDLE
# [136] SEAL
# [137] SLEEVE-BUTTONS
# [138] BROOCH
# [139] SHEETS
# [140] TOWELS
# [141] SILVER TEASPOONS
# [142] SUGAR-TONGS
# [143] BOOTS
# [144] COAL-SCUTTLE
# [145] PUDDING
# [146] SPIRITS
# [147] CHIMNEY CORNER
# [148] TOTAL-ABSTINENCE PRINCIPLE

# %% [markdown]
# # (6): SurpriseVertexPartition -- 171 clusters
# ## Implements (asymptotic) Surprise. This quality function is well-defined only for positive edge weights.

# %%
import leidenalg as la
import igraph as ig

igraph = ig.Graph.TupleList(G.edges(data=True), directed=False)
partition6 = la.find_partition(igraph, la.SurpriseVertexPartition)
modularity_score_igraph6 = igraph.modularity(partition6)  
print(f"Modularity Score from SignificanceVertexPartition: {modularity_score_igraph6}")
# Out:
# Modularity Score from SignificanceVertexPartition: 0.5103089691848702

# %%
print(partition6)
# Out:
# Clustering with 610 elements and 171 clusters
# [  0] SCROOGE, SHIP, PARTNERSHIP, WORLD OF FOOLS, GENTLEMEN, POPULATION, BEEF,
#       CROWD, INVISIBLE WORLD, BRIDGE, MANSION OF DULL RED BRICK, DOWERLESS
#       GIRL, LITTLE SHOE, PLUM-PUDDINGS, CITY STREETS, HELMSMAN, LOOK-OUT,
#       OFFICERS, POOR CLERK, LONDON, BEDPOST, TURKEY
# [  1] CHRISTMAS, POULTERERS, TAILOR, RAGGED MEN, BERRIES, IVY, THRONE, RED
#       BERRIES, TURKEYS, GEESE, GAME, POULTRY, BRAWN, MEAT, PIGS, SAUSAGES,
#       OYSTERS, PIES, PUDDINGS, FRUIT, PUNCH
# [  2] BOB CRATCHIT, TINY TIM, CHILD, PETER CRATCHIT, MRS. CRATCHIT, BELINDA
#       CRATCHIT, MARTHA CRATCHIT, CRATCHIT HOUSE, CRATCHIT FAMILY, YOUNG
#       CRATCHITS, CHRISTMAS DINNER, CHRISTMAS DAY, PETER, CRATCHIT'S HOUSE,
#       CRATCHIT'S WIFE, GIRLS, GOOSE, FIRE, BELINDA, CHRISTMAS PARTY, CRATCHITS
# [  3] FRED, GHOST OF CHRISTMAS PRESENT, SCROOGE'S NIECE, PARTY, GOOD-HUMOUR,
#       MULLED WINE, UNCLE SCROOGE, TOPPER, PLUMP SISTER, SCROOGE'S NEPHEW,
#       SCROOGE'S NIECE'S SISTERS, SCROOGE'S NIECE'S SISTER, HARP, LARGE CHAIR,
#       FOOTSTOOL, GAME OF HOW, WHEN, AND WHERE, MUSIC, BLIND MAN'S-BUFF, GAMES
# [  4] LAUGHTER, MRS. DILBER, LAUNDRESS, PARLOUR, OLD JOE, CHARWOMAN,
#       UNDERTAKER'S MAN, BUNDLE, SEAL, PENCIL-CASE, SLEEVE-BUTTONS, BROOCH,
#       SHEETS, TOWELS, SILVER TEASPOONS, SUGAR-TONGS, BOOTS
# [  5] CHRISTMAS EVE, FEZZIWIG, DICK, MRS. FEZZIWIG, WELSH WIG, EBENEZER,
#       DANCE, COLD ROAST, COLD BOILED, MINCE-PIES, BEER, FESTIVITIES, SIR ROGER
#       DE COVERLEY, DOMESTIC BALL, APPRENTICES, CHRISTMAS BALL
# [  6] GHOST, DICK WILKINS, JACOB MARLEY, CHAIN, HAPPINESS, SPECTRE, THREE
#       SPIRITS, TWELVE, STAVE TWO, BAKER'S, SURPLUS POPULATION, BLAZE,
#       LAMPLIGHTER, TWELFTH-NIGHT PARTY, SPIRIT'S ROBE
# [  7] SPIRIT, BAKERS' SHOPS, PRISONS, COUNTRY ROAD, FIELDS, CHRISTMAS
#       HOLIDAYS, PAST, FUTURE, ALMSHOUSE, HOSPITAL, GAOL, IGNORANCE, WANT,
#       WORKHOUSES, MYSTERY
# [  8] PROJECT GUTENBERG, FULL LICENSE, TERMS OF THIS AGREEMENT, WORLD,
#       COPYRIGHT HOLDER, USER, GUTENBERG LICENSE, PLAIN VANILLA ASCII,
#       COPYRIGHT, ROYALTY FEE, AGREEMENT, MICHAEL S. HART, EBOOK, VOLUNTEER,
#       DONATION
# [  9] GROCERS, CUSTOMERS, GROCER, FISH, ALMONDS, CINNAMON, RAISINS, TEA,
#       COFFEE, SPICES, CANISTERS, CANDIED FRUITS, FIGS, FRENCH PLUMS
# [ 10] MISTLETOE, FRUITERERS, NORFOLK BIFFINS, SPANISH ONIONS, SHOPKEEPERS,
#       PEARS, APPLES, GRAPES, FILBERTS, ORANGES, LEMONS, BASKETS, FRUITS,
#       VEGETABLES
# [ 11] EBENEZER SCROOGE, MR. FEZZIWIG, GHOST OF CHRISTMAS YET TO COME, GHOST OF
#       JACOB MARLEY, FEZZIWIG'S BALL, THE THREE SPIRITS, HAMLET, NIGHT,
#       SCROOGE'S HOUSE, MONEY-CHANGING HOLE, FIRST OF EXCHANGE, CHURCHYARD,
#       GRAVE
# [ 12] PHANTOM, PORCH, DEATH, HAMLET'S FATHER, ROOM, COLD, WINTER FIRE, BODY,
#       TERRORS, STAVE FOUR, GLOOM, GRAVES
# [ 13] CHILDREN, FAMILY, PORTER, DEVILS, ANGELS, FIDDLER, BROWN-PAPER PARCELS,
#       MARRIED SISTERS, BROTHERS, COUSINS, UNCLES, AUNTS
# [ 14] WOMAN, CAROLINE, MAN, DEBT, DECEASED MAN, CORPSE, SPOIL, CONTRACT,
#       ASPIRATIONS, INDUSTRY, BLANKETS, SHIRT
# [ 15] MARLEY, STAVE ONE, KNOCKER, CLERGYMAN, UNDERTAKER, CHIEF MOURNER, BURIAL
#       REGISTER, GHOSTLY SPECTACLES, WAISTCOAT, PIGTAIL, DARK CELLAR
# [ 16] PROJECT GUTENBERG LICENSE, ELECTRONIC WORK, PARAGRAPH 1.F.3, REFUND,
#       PERSON, ENTITY, DEFECT IN ELECTRONIC WORK, REPLACEMENT COPY, WRITTEN
#       EXPLANATION, DEFECTIVE WORK, PHYSICAL MEDIUM
# [ 17] MARLEY'S GHOST, BELL, WINE-MERCHANT'S CELLAR, HAUNTED HOUSE, DOOR,
#       PHANTOMS, BLEAK, DARK NIGHT, GUILTY GOVERNMENTS, CHAINS, GHOSTS, WOMAN
#       WITH INFANT
# [ 18] TOWN, HUSBAND, MOTHER, CHAOS, DINNER, DAUGHTER, LAMPLIGHT, INFAMOUS
#       RESORT, NARROW ALLEYS, ARCHWAYS, DESSERT
# [ 19] MIST, CITY, DARKNESS, WINTER DAY, CHANGE, MONEY, MERCHANTS, FOG,
#       FLOGGING LINKS, GOLD SEALS
# [ 20] MASTER SCROOGE, HALL, ECHOES, SCHOOLMASTER, CHAIS, SCHOOL, GARDEN SWEEP,
#       YOUNG PEOPLE, DECANTER, BLOCK OF CAKE
# [ 21] GENTLEMAN, POOR LAW, BUSINESS MEN, FUNERAL, MAN WITH LARGE CHIN, FESTIVE
#       SEASON, FUND, COMPANY, GREAT FAT MAN, RED-FACED GENTLEMAN
# [ 22] SCROOGE AND MARLEY, WAREHOUSE, WINTER BALL, DANCE EVENT, BAKER, MISS
#       FEZZIWIG, YOUNG FOLLOWERS, HOUSEMAID, COOK, MILKMAN
# [ 23] GREAT BRITAIN, PEOPLE, STREETS, CHESTNUTS, CLIMATE, SNOWBALL FIGHT,
#       POULTERERS' SHOPS, WICKER BASKETS, DINNERS, CARTS AND WAGONS
# [ 24] A CHRISTMAS CAROL, CHARLES DICKENS, ARTHUR RACKHAM, PHILADELPHIA, NEW
#       YORK, SUZANNE SHELL, JANET BLENKINSHIP, ONLINE DISTRIBUTED PROOFREADING
#       TEAM, J. B. LIPPINCOTT COMPANY
# [ 25] DINING-ROOM, NEPHEW, YES AND NO, GIRL, ANIMAL, MISTRESS, YOUNG
#       HOUSEKEEPERS
# [ 26] SCOURGE, MOOR, FROST, SPIRIT OF CHRISTMAS YET TO COME, CANDLES, COURT,
#       SETTING SUN
# [ 27] MERRY CHRISTMAS, MR. SCROOGE, THE CRATCHIT FAMILY, OFFICE, OLD
#       GENTLEMAN, GHOST OF CHRISTMAS, HAPPY END
# [ 28] SELF, CHURCH, CLOCK, BED, UNKNOWN, LIGHT, MULTITUDES
# [ 29] PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION, UNITED STATES,
#       WWW.GUTENBERG.ORG, ADDRESS, DONATIONS, U.S. FEDERAL LAWS, IRS
# [ 30] BOB, WASH-HOUSE, SUNDAY, GREEN PLACE, MR. SCROOGE'S NEPHEW, GOOD WIFE,
#       NINE O'CLOCK
# [ 31] COUNTING-HOUSE, CORNHILL, CLERK, CANDLE, CAMDEN TOWN, MASTER, FIFTEEN
#       SHILLINGS
# [ 32] LIGHTHOUSE, TWO MEN, WATER, STORM-BIRDS, SEA, CAVERN
# [ 33] FAN, FATHER, BOY, LITTLE FAN, POULTERER'S, COACH
# [ 34] GHOST OF CHRISTMAS PAST, YOUNG GIRL, IDOL, COMELY MATRON, POVERTY,
#       WEALTH
# [ 35] GREY-HAIRED RASCAL, WOMAN WITH HEAVY BUNDLE, SECOND WOMAN, MAN IN FADED
#       BLACK, SHOP, CHARCOAL STOVE
# [ 36] COPYRIGHT LAW, FOUNDATION, TAX EXEMPT STATUS, PUBLIC DOMAIN, CHARITABLE
#       DONATIONS, COMPLIANCE REQUIREMENTS
# [ 37] HOLLY, UNEARTHLY VISITOR, FIGURE, TUNIC, SUMMER FLOWERS, BELT
# [ 38] JACOB, MANKIND, CHARITY, MERCY, FORBEARANCE, BENEVOLENCE
# [ 39] LOW-BROWED SHOP, RAGS, BOTTLES, BONES, GREASY OFFAL, KEYS
# [ 40] BELLE, MASTER OF THE HOUSE, HOUSE, SNOW, SNOWSTORMS
# [ 41] OLD MAN, MINERS, CHEERFUL COMPANY, HUT, CHRISTMAS SONG
# [ 42] MARTHA, HOLIDAY, MILLINER, COUNTESS, LORD
# [ 43] GUTENBERG LITERARY ARCHIVE FOUNDATION, SALT LAKE CITY, INTERNAL REVENUE
#       SERVICE, MISSISSIPPI
# [ 44] JOE, OLD SCRATCH, BED-CURTAINS, FIRST WOMAN
# [ 45] HOLLY SPRIGS, ANCIENT TOWER, MAIN STREET, GAS-PIPES
# [ 46] LORD MAYOR, MANSION HOUSE, FIFTY COOKS AND BUTLERS
# [ 47] BOYS, MARKET-TOWN, FARMERS
# [ 48] SULTAN'S GROOM, PRINCESS, GENII
# [ 49] DOLL'S FRYING PAN, BABY, WOODEN PLATTER
# [ 50] ELECTRONIC WORKS, DERIVATIVE WORKS, FREE ACCESS
# [ 51] SISTER, BLIND MAN
# [ 52] HIGH DESK, STREET
# [ 53] CHRISTMAS PUDDING, COPPER
# [ 54] GATEWAY, FOG AND FROST
# [ 55] VALENTINE, ORSON
# [ 56] SISTERS, GUESTS
# [ 57] WINDOWS, HOUSE-FRONTS
# [ 58] CHAMBERS, OFFICES
# [ 59] MEAGRE SERVANT, POSTBOY
# [ 60] FIREPLACE, DUTCH MERCHANT
# [ 61] LAOCOON
# [ 62] WINTER WEATHER
# [ 63] UNCLE
# [ 64] HEART
# [ 65] PARLIAMENT
# [ 66] BEDLAM
# [ 67] UNION WORKHOUSES
# [ 68] TREADMILL
# [ 69] ST. DUNSTAN
# [ 70] HAT
# [ 71] TAVERN
# [ 72] DECEASED PARTNER
# [ 73] BANKER'S BOOK
# [ 74] CITY OF LONDON
# [ 75] KEY
# [ 76] WINE-MERCHANT
# [ 77] STAIRS
# [ 78] GRUEL
# [ 79] SITTING-ROOM
# [ 80] BEDROOM
# [ 81] LUMBER-ROOM
# [ 82] DRESSING-GOWN
# [ 83] SLIPPERS
# [ 84] CAINS
# [ 85] ABELS
# [ 86] PHARAOH'S DAUGHTERS
# [ 87] QUEENS OF SHEBA
# [ 88] ANGELIC MESSENGERS
# [ 89] ABRAHAMS
# [ 90] BELSHAZZARS
# [ 91] APOSTLES
# [ 92] BUTTER-BOATS
# [ 93] SENSES
# [ 94] MUSTARD
# [ 95] CHEESE
# [ 96] POTATO
# [ 97] CHAIR
# [ 98] APPEARANCE
# [ 99] WARD
# [100] WISE MEN
# [101] POOR ABODE
# [102] WINDOW
# [103] TIME
# [104] THE VISITATION
# [105] THE CLOCK
# [106] THE CHIME
# [107] THE QUARTER
# [108] HOUR BELL
# [109] CURTAINS
# [110] WELFARE
# [111] RIVER
# [112] MANSION
# [113] TRAVELLERS
# [114] HIGH-ROAD
# [115] LANE
# [116] ALI BABA
# [117] POPPLAR
# [118] DAMASCUS
# [119] ROBIN CRUSOE
# [120] FRIDAY
# [121] PARROT
# [122] CHRISTMAS CAROL
# [123] FAIR YOUNG GIRL
# [124] HEAVEN
# [125] BRAIDED HAIR
# [126] EXTINGUISHER-CAP
# [127] ONE
# [128] GHOSTLY LIGHT
# [129] TRANSFORMATION
# [130] GESE
# [131] TWELFTH-CAKES
# [132] CHURCH AND CHAPEL
# [133] INCENSE
# [134] TORCH
# [135] POOR MAN'S CHILD
# [136] AROMATIC VINEGAR
# [137] MOLDY OLD OFFICE
# [138] DUSTY CHAMBERS
# [139] BUSINESSMEN
# [140] SHADOW
# [141] FURNITURE
# [142] PRESENT
# [143] CHRISTMAS TIME
# [144] WANDERING SPIRITS
# [145] CHURCHES
# [146] CORNER
# [147] POULTERER
# [148] CAB
# [149] SCROOGE AND MARLEY'S
# [150] PORTLY GENTLEMAN
# [151] TANK
# [152] PUDDING
# [153] SAGE AND ONION
# [154] CHAMBER
# [155] FIRST PARTING
# [156] COAL-SCUTTLE
# [157] YOUNGEST CRATCHITS
# [158] CLOSET DOOR
# [159] BRAZIER
# [160] GLOBE
# [161] GRAVY
# [162] SPIRIT OF TINY TIM
# [163] CHIMNEY CORNER
# [164] HEARTH
# [165] TOTAL-ABSTINENCE PRINCIPLE
# [166] SPIRITS
# [167] RAGGED MEN AND BOYS
# [168] TIM CRATCHIT
# [169] CLOTH
# [170] HOUSES
